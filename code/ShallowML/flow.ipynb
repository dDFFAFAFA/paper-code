# %% [markdown]
# # Description
# process pcap data for get traditional baseline
# label/flow.pcap -> feature alignment Matrix/csv

# %%
import os
import logging
import scapy.all as scapy
from multiprocessing import Pool, cpu_count
import csv
import pandas as pd

os.chdir('LLM4Traffic/code/Traditional')

logging.basicConfig(       
    level=logging.INFO,            
    format='%(asctime)s - %(name)s - %(levelname)s - %(message)s',  
    handlers=[
        logging.FileHandler('logs/flow.log', mode='w'),  
        logging.StreamHandler()          
    ],
    force=True
)

logger = logging.getLogger()

# %%
num_of_pkts = 7 # the first number of packets to be considered in a flow

# dataset_path = '/share/smartdata/external_pcaps/ISCX-VPN-2016/Filtered/App/flow'
dataset_path = 'external_pcaps/CSTNET-TLS1.3/Filtered/flow'
output_path = f'LLM4Traffic/code/Traditional/datasets/flow/tls-{num_of_pkts}'

# %%
def get_key_val(line):
    layer = None
    sublayer = None
    key = None
    val = None

    if '###' in line:             
        if '|###' in line:                
            sublayer = line.strip('|#[] ')  
            print(f'sublayer {sublayer}')    
        else:                
            layer = line.strip('#[] ')      

    if '=' in line:            
        if '|' in line and 'sublayer' in locals():                
            key, val = line.strip('| ').split('=', 1)        
            key, val = key.strip(), val.strip('\' ')          
            print(f'sublayer {sublayer}')  
        else:                 
            key, val = line.split('=', 1)   
            key, val = key.strip(), val.strip('\' ')    
            
    return layer, sublayer, key, val

def clean_packet(packet):
    if packet.haslayer(scapy.Ether):
        packet = packet[scapy.Ether].payload

    if packet.haslayer(scapy.IP) or packet.haslayer('IPv6'):
        if packet.haslayer(scapy.UDP):
            packet[scapy.UDP].remove_payload()   
        if packet.haslayer(scapy.TCP):
            packet[scapy.TCP].remove_payload()    
    
    return packet

# get how many features/ip flags/tcp flags/.. in the dataset

pass_fields = ['src', 'dst', 'sport', 'dport'] # ignore these fields
field_set = set()
ip_flags_set = set()
tcp_flags_set = set()

def get_all_features(packet):
    protocol = None
    for line in packet.show2(dump=True).split('\n'): 
        layer, _, key, val = get_key_val(line)

        if layer is not None:
                protocol = layer
        else:
            if key not in pass_fields and key is not None:   
                if key == 'options': # options is a list, there are two new fields
                    if len(val) == 0:
                        continue
                    for option in eval(val):
                            if option[0] == 'NOP': # ignore NOP (No Operation)
                                continue
                            elif option[0] == 'Timestamp': # Timestamp and Echo are a pair
                                field_set.add(f'{protocol}_{option[0]}')
                                field_set.add(f'{protocol}_echo_{option[0]}')
                            elif option[0] == 'SAck': # SAckOK is a flag
                                field_set.add(f'{protocol}_{option[0]}')
                                field_set.add(f'{protocol}_echo_{option[0]}')
                                continue

                            field_set.add(f'{protocol}_{option[0]}')
                    continue     

                # distinguish ip flags and tcp flags
                if key == 'flags': 
                    if protocol == 'IP':
                        ip_flags_set.add(f'{val}')
                    elif protocol == 'TCP':
                        tcp_flags_set.add(f'{val}')  

                if key == 'chksum' and protocol in ['TCP', 'UDP']:   # merge tcp and udp checksum
                    field_set.add('TL_chksum')
                elif f'{protocol}_{key}'== 'IP_tos' or f'{protocol}_{key}' == 'IPv6_tc': # merge tos and traffic class
                    field_set.add('IP_tos')
                elif key == 'version': # merge ip version and ipv6 version
                    field_set.add('IP_version')
                elif f'{protocol}_{key}'== 'IP_ttl' or f'{protocol}_{key}' == 'IPv6_hlim': # merge ttl and hot limit
                    field_set.add('IP_ttl')
                elif f'{protocol}_{key}'== 'IP_len' or f'{protocol}_{key}' == 'IPv6_plen': # merge len and payload len
                    field_set.add('IP_len')
                elif f'{protocol}_{key}'== 'IP_proto' or f'{protocol}_{key}' == 'IPv6_nh': # merge proto and next header
                    field_set.add('IP_proto')
                else:
                    field_set.add(f'{protocol}_{key}')

    return field_set

# %%
# file/test/class/flow.pcap or file/train_val_split_0/{train/val}/class/flow.pcap
for type in os.listdir(dataset_path):
    logger.info(f'Processing {type}')

    if type == 'test':
        for class_id, class_name in enumerate(os.listdir(f'{dataset_path}/{type}')):
            logger.info(f'Processing {type} {class_name}')
            for file_name in os.listdir(f'{dataset_path}/{type}/{class_name}'):
                with scapy.PcapReader(f'{dataset_path}/{type}/{class_name}/{file_name}') as packets:
                    for id, packet in enumerate(packets):
                        if id >= num_of_pkts:
                            break
                        # only require ip header and transportaion layer
                        packet = clean_packet(packet)
                        get_all_features(packet)
    else:
        for class_id, folder in enumerate(os.listdir(f'{dataset_path}/{type}')):
            logger.info(f'Processing {type} {folder}')
            
            for class_name in os.listdir(f'{dataset_path}/{type}/{folder}'):
                logger.info(f'Processing {type} {folder} {class_name}')
                for file_name in os.listdir(f'{dataset_path}/{type}/{folder}/{class_name}'):
                    with scapy.PcapReader(f'{dataset_path}/{type}/{folder}/{class_name}/{file_name}') as packets:
                        for id, packet in enumerate(packets):
                            if id >= num_of_pkts:
                                break
                            # only require ip header and transportaion layer
                            packet = clean_packet(packet)
                            get_all_features(packet)


print(field_set)
print(ip_flags_set)
print(tcp_flags_set)
print()
# Out:
# 2025-01-08 10:28:22,900 - root - INFO - Processing train_val_split_2
# 2025-01-08 10:28:22,902 - root - INFO - Processing train_val_split_2 train
# 2025-01-08 10:28:22,907 - root - INFO - Processing train_val_split_2 train azureedge.net
# 2025-01-08 10:28:23,454 - root - INFO - Processing train_val_split_2 train hubspot.com
# 2025-01-08 10:28:23,929 - root - INFO - Processing train_val_split_2 train pinduoduo.com
# 2025-01-08 10:28:24,414 - root - INFO - Processing train_val_split_2 train jd.com
# 2025-01-08 10:28:25,000 - root - INFO - Processing train_val_split_2 train snapchat.com
# 2025-01-08 10:28:25,570 - root - INFO - Processing train_val_split_2 train qcloud.com
# 2025-01-08 10:28:26,012 - root - INFO - Processing train_val_split_2 train 51.la
# 2025-01-08 10:28:26,561 - root - INFO - Processing train_val_split_2 train arxiv.org
# 2025-01-08 10:28:27,052 - root - INFO - Processing train_val_split_2 train onlinedown.net
# 2025-01-08 10:28:27,572 - root - INFO - Processing train_val_split_2 train grammarly.com
# 2025-01-08 10:28:28,131 - root - INFO - Processing train_val_split_2 train cloudfront.net
# 2025-01-08 10:28:28,493 - root - INFO - Processing train_val_split_2 train teads.tv
# 2025-01-08 10:28:29,018 - root - INFO - Processing train_val_split_2 train office.net
# 2025-01-08 10:28:29,693 - root - INFO - Processing train_val_split_2 train huawei.com
# 2025-01-08 10:28:30,521 - root - INFO - Processing train_val_split_2 train researchgate.net
# 2025-01-08 10:28:31,034 - root - INFO - Processing train_val_split_2 train elsevier.com
# 2025-01-08 10:28:31,496 - root - INFO - Processing train_val_split_2 train instagram.com
# 2025-01-08 10:28:31,927 - root - INFO - Processing train_val_split_2 train microsoft.com
# 2025-01-08 10:28:32,470 - root - INFO - Processing train_val_split_2 train criteo.com
# 2025-01-08 10:28:32,946 - root - INFO - Processing train_val_split_2 train apple.com
# 2025-01-08 10:28:33,370 - root - INFO - Processing train_val_split_2 train codepen.io
# 2025-01-08 10:28:33,917 - root - INFO - Processing train_val_split_2 train wikimedia.org
# 2025-01-08 10:28:34,470 - root - INFO - Processing train_val_split_2 train overleaf.com
# 2025-01-08 10:28:35,175 - root - INFO - Processing train_val_split_2 train dailymotion.com
# 2025-01-08 10:28:35,952 - root - INFO - Processing train_val_split_2 train 163.com
# 2025-01-08 10:28:36,422 - root - INFO - Processing train_val_split_2 train semanticscholar.org
# 2025-01-08 10:28:37,062 - root - INFO - Processing train_val_split_2 train booking.com
# 2025-01-08 10:28:37,518 - root - INFO - Processing train_val_split_2 train sohu.com
# 2025-01-08 10:28:37,941 - root - INFO - Processing train_val_split_2 train twimg.com
# 2025-01-08 10:28:38,540 - root - INFO - Processing train_val_split_2 train github.com
# 2025-01-08 10:28:38,969 - root - INFO - Processing train_val_split_2 train nvidia.com
# 2025-01-08 10:28:39,419 - root - INFO - Processing train_val_split_2 train mozilla.org
# 2025-01-08 10:28:39,897 - root - INFO - Processing train_val_split_2 train cisco.com
# 2025-01-08 10:28:40,316 - root - INFO - Processing train_val_split_2 train alipay.com
# 2025-01-08 10:28:40,770 - root - INFO - Processing train_val_split_2 train digitaloceanspaces.com
# 2025-01-08 10:28:41,205 - root - INFO - Processing train_val_split_2 train amazonaws.com
# 2025-01-08 10:28:41,616 - root - INFO - Processing train_val_split_2 train biligame.com
# 2025-01-08 10:28:41,979 - root - INFO - Processing train_val_split_2 train icloud.com
# 2025-01-08 10:28:42,477 - root - INFO - Processing train_val_split_2 train cloudflare.com
# 2025-01-08 10:28:43,047 - root - INFO - Processing train_val_split_2 train statcounter.com
# 2025-01-08 10:28:43,517 - root - INFO - Processing train_val_split_2 train alibaba.com
# 2025-01-08 10:28:43,896 - root - INFO - Processing train_val_split_2 train unity3d.com
# 2025-01-08 10:28:44,363 - root - INFO - Processing train_val_split_2 train taboola.com
# 2025-01-08 10:28:44,887 - root - INFO - Processing train_val_split_2 train notion.so
# 2025-01-08 10:28:45,358 - root - INFO - Processing train_val_split_2 train spring.io
# 2025-01-08 10:28:45,769 - root - INFO - Processing train_val_split_2 train amap.com
# 2025-01-08 10:28:46,125 - root - INFO - Processing train_val_split_2 train vivo.com.cn
# 2025-01-08 10:28:46,668 - root - INFO - Processing train_val_split_2 train acm.org
# 2025-01-08 10:28:47,253 - root - INFO - Processing train_val_split_2 train guancha.cn
# 2025-01-08 10:28:47,672 - root - INFO - Processing train_val_split_2 train atlassian.net
# 2025-01-08 10:28:48,164 - root - INFO - Processing train_val_split_2 train nike.com
# 2025-01-08 10:28:48,933 - root - INFO - Processing train_val_split_2 train huanqiu.com
# 2025-01-08 10:28:49,411 - root - INFO - Processing train_val_split_2 train asus.com
# 2025-01-08 10:28:49,960 - root - INFO - Processing train_val_split_2 train python.org
# 2025-01-08 10:28:50,402 - root - INFO - Processing train_val_split_2 train thepaper.cn
# 2025-01-08 10:28:51,071 - root - INFO - Processing train_val_split_2 train goat.com
# 2025-01-08 10:28:51,725 - root - INFO - Processing train_val_split_2 train ibm.com
# 2025-01-08 10:28:52,205 - root - INFO - Processing train_val_split_2 train ximalaya.com
# 2025-01-08 10:28:52,706 - root - INFO - Processing train_val_split_2 train facebook.com
# 2025-01-08 10:28:53,147 - root - INFO - Processing train_val_split_2 train google.com
# 2025-01-08 10:28:53,522 - root - INFO - Processing train_val_split_2 train media.net
# 2025-01-08 10:28:53,929 - root - INFO - Processing train_val_split_2 train chia.net
# 2025-01-08 10:28:53,982 - root - INFO - Processing train_val_split_2 train oracle.com
# 2025-01-08 10:28:54,475 - root - INFO - Processing train_val_split_2 train leetcode-cn.com
# 2025-01-08 10:28:55,120 - root - INFO - Processing train_val_split_2 train wp.com
# 2025-01-08 10:28:55,663 - root - INFO - Processing train_val_split_2 train ctrip.com
# 2025-01-08 10:28:56,182 - root - INFO - Processing train_val_split_2 train yahoo.com
# 2025-01-08 10:28:56,573 - root - INFO - Processing train_val_split_2 train yandex.ru
# 2025-01-08 10:28:56,974 - root - INFO - Processing train_val_split_2 train kugou.com
# 2025-01-08 10:28:57,426 - root - INFO - Processing train_val_split_2 train deepl.com
# 2025-01-08 10:28:57,956 - root - INFO - Processing train_val_split_2 train paypal.com
# 2025-01-08 10:28:58,471 - root - INFO - Processing train_val_split_2 train gmail.com
# 2025-01-08 10:28:58,855 - root - INFO - Processing train_val_split_2 train zhihu.com
# 2025-01-08 10:28:59,347 - root - INFO - Processing train_val_split_2 train 51cto.com
# 2025-01-08 10:28:59,848 - root - INFO - Processing train_val_split_2 train sina.com.cn
# 2025-01-08 10:29:00,343 - root - INFO - Processing train_val_split_2 train msn.com
# 2025-01-08 10:29:00,760 - root - INFO - Processing train_val_split_2 train vmware.com
# 2025-01-08 10:29:01,202 - root - INFO - Processing train_val_split_2 train ggpht.com
# 2025-01-08 10:29:01,684 - root - INFO - Processing train_val_split_2 train vk.com
# 2025-01-08 10:29:02,103 - root - INFO - Processing train_val_split_2 train ieee.org
# 2025-01-08 10:29:02,635 - root - INFO - Processing train_val_split_2 train ampproject.org
# 2025-01-08 10:29:03,126 - root - INFO - Processing train_val_split_2 train xiaomi.com
# 2025-01-08 10:29:03,747 - root - INFO - Processing train_val_split_2 train baidu.com
# 2025-01-08 10:29:04,197 - root - INFO - Processing train_val_split_2 train tiktok.com
# 2025-01-08 10:29:04,650 - root - INFO - Processing train_val_split_2 train wikipedia.org
# 2025-01-08 10:29:05,235 - root - INFO - Processing train_val_split_2 train walmart.com
# 2025-01-08 10:29:05,654 - root - INFO - Processing train_val_split_2 train toutiao.com
# 2025-01-08 10:29:06,042 - root - INFO - Processing train_val_split_2 train cnblogs.com
# 2025-01-08 10:29:06,468 - root - INFO - Processing train_val_split_2 train weibo.com
# 2025-01-08 10:29:07,077 - root - INFO - Processing train_val_split_2 train bilibili.com
# 2025-01-08 10:29:07,483 - root - INFO - Processing train_val_split_2 train runoob.com
# 2025-01-08 10:29:07,970 - root - INFO - Processing train_val_split_2 train steampowered.com
# 2025-01-08 10:29:08,410 - root - INFO - Processing train_val_split_2 train outbrain.com
# 2025-01-08 10:29:08,793 - root - INFO - Processing train_val_split_2 train qq.com
# 2025-01-08 10:29:09,165 - root - INFO - Processing train_val_split_2 train gravatar.com
# 2025-01-08 10:29:09,587 - root - INFO - Processing train_val_split_2 train eastmoney.com
# 2025-01-08 10:29:10,011 - root - INFO - Processing train_val_split_2 train feishu.cn
# 2025-01-08 10:29:10,462 - root - INFO - Processing train_val_split_2 train v2ex.com
# 2025-01-08 10:29:10,930 - root - INFO - Processing train_val_split_2 train chinatax.gov.cn
# 2025-01-08 10:29:11,437 - root - INFO - Processing train_val_split_2 train opera.com
# 2025-01-08 10:29:11,915 - root - INFO - Processing train_val_split_2 train naver.com
# 2025-01-08 10:29:12,446 - root - INFO - Processing train_val_split_2 train alicdn.com
# 2025-01-08 10:29:12,973 - root - INFO - Processing train_val_split_2 train youtube.com
# 2025-01-08 10:29:13,395 - root - INFO - Processing train_val_split_2 train mi.com
# 2025-01-08 10:29:13,794 - root - INFO - Processing train_val_split_2 train smzdm.com
# 2025-01-08 10:29:14,268 - root - INFO - Processing train_val_split_2 train iqiyi.com
# 2025-01-08 10:29:14,693 - root - INFO - Processing train_val_split_2 train jb51.net
# 2025-01-08 10:29:15,139 - root - INFO - Processing train_val_split_2 train adobe.com
# 2025-01-08 10:29:15,585 - root - INFO - Processing train_val_split_2 train springer.com
# 2025-01-08 10:29:16,164 - root - INFO - Processing train_val_split_2 train duckduckgo.com
# 2025-01-08 10:29:16,541 - root - INFO - Processing train_val_split_2 train huya.com
# 2025-01-08 10:29:16,943 - root - INFO - Processing train_val_split_2 train crazyegg.com
# 2025-01-08 10:29:17,451 - root - INFO - Processing train_val_split_2 train gitlab.com
# 2025-01-08 10:29:18,076 - root - INFO - Processing train_val_split_2 train squarespace.com
# 2025-01-08 10:29:18,658 - root - INFO - Processing train_val_split_2 train yy.com
# 2025-01-08 10:29:19,148 - root - INFO - Processing train_val_split_2 train twitter.com
# 2025-01-08 10:29:19,574 - root - INFO - Processing train_val_split_2 train netflix.com
# 2025-01-08 10:29:19,949 - root - INFO - Processing train_val_split_2 train sciencedirect.com
# 2025-01-08 10:29:20,480 - root - INFO - Processing train_val_split_2 train eastday.com
# 2025-01-08 10:29:20,980 - root - INFO - Processing train_val_split_2 train t.co
# 2025-01-08 10:29:21,396 - root - INFO - Processing train_val_split_2 val
# 2025-01-08 10:29:21,401 - root - INFO - Processing train_val_split_2 val azureedge.net
# 2025-01-08 10:29:21,610 - root - INFO - Processing train_val_split_2 val hubspot.com
# 2025-01-08 10:29:21,783 - root - INFO - Processing train_val_split_2 val pinduoduo.com
# 2025-01-08 10:29:22,044 - root - INFO - Processing train_val_split_2 val jd.com
# 2025-01-08 10:29:22,252 - root - INFO - Processing train_val_split_2 val snapchat.com
# 2025-01-08 10:29:22,484 - root - INFO - Processing train_val_split_2 val qcloud.com
# 2025-01-08 10:29:22,689 - root - INFO - Processing train_val_split_2 val 51.la
# 2025-01-08 10:29:22,921 - root - INFO - Processing train_val_split_2 val arxiv.org
# 2025-01-08 10:29:23,190 - root - INFO - Processing train_val_split_2 val onlinedown.net
# 2025-01-08 10:29:23,503 - root - INFO - Processing train_val_split_2 val grammarly.com
# 2025-01-08 10:29:23,731 - root - INFO - Processing train_val_split_2 val cloudfront.net
# 2025-01-08 10:29:23,932 - root - INFO - Processing train_val_split_2 val teads.tv
# 2025-01-08 10:29:24,132 - root - INFO - Processing train_val_split_2 val office.net
# 2025-01-08 10:29:24,480 - root - INFO - Processing train_val_split_2 val huawei.com
# 2025-01-08 10:29:24,959 - root - INFO - Processing train_val_split_2 val researchgate.net
# 2025-01-08 10:29:25,359 - root - INFO - Processing train_val_split_2 val elsevier.com
# 2025-01-08 10:29:25,668 - root - INFO - Processing train_val_split_2 val instagram.com
# 2025-01-08 10:29:25,945 - root - INFO - Processing train_val_split_2 val microsoft.com
# 2025-01-08 10:29:26,209 - root - INFO - Processing train_val_split_2 val criteo.com
# 2025-01-08 10:29:26,484 - root - INFO - Processing train_val_split_2 val apple.com
# 2025-01-08 10:29:26,744 - root - INFO - Processing train_val_split_2 val codepen.io
# 2025-01-08 10:29:26,977 - root - INFO - Processing train_val_split_2 val wikimedia.org
# 2025-01-08 10:29:27,305 - root - INFO - Processing train_val_split_2 val overleaf.com
# 2025-01-08 10:29:27,746 - root - INFO - Processing train_val_split_2 val dailymotion.com
# 2025-01-08 10:29:28,110 - root - INFO - Processing train_val_split_2 val 163.com
# 2025-01-08 10:29:28,418 - root - INFO - Processing train_val_split_2 val semanticscholar.org
# 2025-01-08 10:29:28,650 - root - INFO - Processing train_val_split_2 val booking.com
# 2025-01-08 10:29:28,856 - root - INFO - Processing train_val_split_2 val sohu.com
# 2025-01-08 10:29:29,089 - root - INFO - Processing train_val_split_2 val twimg.com
# 2025-01-08 10:29:29,345 - root - INFO - Processing train_val_split_2 val github.com
# 2025-01-08 10:29:29,503 - root - INFO - Processing train_val_split_2 val nvidia.com
# 2025-01-08 10:29:29,734 - root - INFO - Processing train_val_split_2 val mozilla.org
# 2025-01-08 10:29:29,994 - root - INFO - Processing train_val_split_2 val cisco.com
# 2025-01-08 10:29:30,224 - root - INFO - Processing train_val_split_2 val alipay.com
# 2025-01-08 10:29:30,450 - root - INFO - Processing train_val_split_2 val digitaloceanspaces.com
# 2025-01-08 10:29:30,664 - root - INFO - Processing train_val_split_2 val amazonaws.com
# 2025-01-08 10:29:30,937 - root - INFO - Processing train_val_split_2 val biligame.com
# 2025-01-08 10:29:31,094 - root - INFO - Processing train_val_split_2 val icloud.com
# 2025-01-08 10:29:31,302 - root - INFO - Processing train_val_split_2 val cloudflare.com
# 2025-01-08 10:29:31,531 - root - INFO - Processing train_val_split_2 val statcounter.com
# 2025-01-08 10:29:31,816 - root - INFO - Processing train_val_split_2 val alibaba.com
# 2025-01-08 10:29:32,004 - root - INFO - Processing train_val_split_2 val unity3d.com
# 2025-01-08 10:29:32,258 - root - INFO - Processing train_val_split_2 val taboola.com
# 2025-01-08 10:29:32,509 - root - INFO - Processing train_val_split_2 val notion.so
# 2025-01-08 10:29:32,735 - root - INFO - Processing train_val_split_2 val spring.io
# 2025-01-08 10:29:32,963 - root - INFO - Processing train_val_split_2 val amap.com
# 2025-01-08 10:29:33,312 - root - INFO - Processing train_val_split_2 val vivo.com.cn
# 2025-01-08 10:29:33,594 - root - INFO - Processing train_val_split_2 val acm.org
# 2025-01-08 10:29:33,830 - root - INFO - Processing train_val_split_2 val guancha.cn
# 2025-01-08 10:29:34,030 - root - INFO - Processing train_val_split_2 val atlassian.net
# 2025-01-08 10:29:34,268 - root - INFO - Processing train_val_split_2 val nike.com
# 2025-01-08 10:29:34,483 - root - INFO - Processing train_val_split_2 val huanqiu.com
# 2025-01-08 10:29:34,724 - root - INFO - Processing train_val_split_2 val asus.com
# 2025-01-08 10:29:34,960 - root - INFO - Processing train_val_split_2 val python.org
# 2025-01-08 10:29:35,254 - root - INFO - Processing train_val_split_2 val thepaper.cn
# 2025-01-08 10:29:35,653 - root - INFO - Processing train_val_split_2 val goat.com
# 2025-01-08 10:29:36,045 - root - INFO - Processing train_val_split_2 val ibm.com
# 2025-01-08 10:29:36,345 - root - INFO - Processing train_val_split_2 val ximalaya.com
# 2025-01-08 10:29:36,582 - root - INFO - Processing train_val_split_2 val facebook.com
# 2025-01-08 10:29:36,886 - root - INFO - Processing train_val_split_2 val google.com
# 2025-01-08 10:29:37,126 - root - INFO - Processing train_val_split_2 val media.net
# 2025-01-08 10:29:37,341 - root - INFO - Processing train_val_split_2 val chia.net
# 2025-01-08 10:29:37,365 - root - INFO - Processing train_val_split_2 val oracle.com
# 2025-01-08 10:29:37,683 - root - INFO - Processing train_val_split_2 val leetcode-cn.com
# 2025-01-08 10:29:37,910 - root - INFO - Processing train_val_split_2 val wp.com
# 2025-01-08 10:29:38,158 - root - INFO - Processing train_val_split_2 val ctrip.com
# 2025-01-08 10:29:38,388 - root - INFO - Processing train_val_split_2 val yahoo.com
# 2025-01-08 10:29:38,640 - root - INFO - Processing train_val_split_2 val yandex.ru
# 2025-01-08 10:29:38,904 - root - INFO - Processing train_val_split_2 val kugou.com
# 2025-01-08 10:29:39,111 - root - INFO - Processing train_val_split_2 val deepl.com
# 2025-01-08 10:29:39,342 - root - INFO - Processing train_val_split_2 val paypal.com
# 2025-01-08 10:29:39,569 - root - INFO - Processing train_val_split_2 val gmail.com
# 2025-01-08 10:29:39,783 - root - INFO - Processing train_val_split_2 val zhihu.com
# 2025-01-08 10:29:39,998 - root - INFO - Processing train_val_split_2 val 51cto.com
# 2025-01-08 10:29:40,192 - root - INFO - Processing train_val_split_2 val sina.com.cn
# 2025-01-08 10:29:40,475 - root - INFO - Processing train_val_split_2 val msn.com
# 2025-01-08 10:29:40,725 - root - INFO - Processing train_val_split_2 val vmware.com
# 2025-01-08 10:29:40,968 - root - INFO - Processing train_val_split_2 val ggpht.com
# 2025-01-08 10:29:41,167 - root - INFO - Processing train_val_split_2 val vk.com
# 2025-01-08 10:29:41,360 - root - INFO - Processing train_val_split_2 val ieee.org
# 2025-01-08 10:29:41,589 - root - INFO - Processing train_val_split_2 val ampproject.org
# 2025-01-08 10:29:41,791 - root - INFO - Processing train_val_split_2 val xiaomi.com
# 2025-01-08 10:29:42,249 - root - INFO - Processing train_val_split_2 val baidu.com
# 2025-01-08 10:29:42,426 - root - INFO - Processing train_val_split_2 val tiktok.com
# 2025-01-08 10:29:42,636 - root - INFO - Processing train_val_split_2 val wikipedia.org
# 2025-01-08 10:29:42,915 - root - INFO - Processing train_val_split_2 val walmart.com
# 2025-01-08 10:29:43,113 - root - INFO - Processing train_val_split_2 val toutiao.com
# 2025-01-08 10:29:43,341 - root - INFO - Processing train_val_split_2 val cnblogs.com
# 2025-01-08 10:29:43,545 - root - INFO - Processing train_val_split_2 val weibo.com
# 2025-01-08 10:29:43,885 - root - INFO - Processing train_val_split_2 val bilibili.com
# 2025-01-08 10:29:44,145 - root - INFO - Processing train_val_split_2 val runoob.com
# 2025-01-08 10:29:44,372 - root - INFO - Processing train_val_split_2 val steampowered.com
# 2025-01-08 10:29:44,600 - root - INFO - Processing train_val_split_2 val outbrain.com
# 2025-01-08 10:29:44,808 - root - INFO - Processing train_val_split_2 val qq.com
# 2025-01-08 10:29:45,030 - root - INFO - Processing train_val_split_2 val gravatar.com
# 2025-01-08 10:29:45,379 - root - INFO - Processing train_val_split_2 val eastmoney.com
# 2025-01-08 10:29:45,595 - root - INFO - Processing train_val_split_2 val feishu.cn
# 2025-01-08 10:29:45,834 - root - INFO - Processing train_val_split_2 val v2ex.com
# 2025-01-08 10:29:46,172 - root - INFO - Processing train_val_split_2 val chinatax.gov.cn
# 2025-01-08 10:29:46,384 - root - INFO - Processing train_val_split_2 val opera.com
# 2025-01-08 10:29:46,654 - root - INFO - Processing train_val_split_2 val naver.com
# 2025-01-08 10:29:46,842 - root - INFO - Processing train_val_split_2 val alicdn.com
# 2025-01-08 10:29:47,023 - root - INFO - Processing train_val_split_2 val youtube.com
# 2025-01-08 10:29:47,196 - root - INFO - Processing train_val_split_2 val mi.com
# 2025-01-08 10:29:47,412 - root - INFO - Processing train_val_split_2 val smzdm.com
# 2025-01-08 10:29:47,731 - root - INFO - Processing train_val_split_2 val iqiyi.com
# 2025-01-08 10:29:47,939 - root - INFO - Processing train_val_split_2 val jb51.net
# 2025-01-08 10:29:48,202 - root - INFO - Processing train_val_split_2 val adobe.com
# 2025-01-08 10:29:48,411 - root - INFO - Processing train_val_split_2 val springer.com
# 2025-01-08 10:29:48,670 - root - INFO - Processing train_val_split_2 val duckduckgo.com
# 2025-01-08 10:29:48,860 - root - INFO - Processing train_val_split_2 val huya.com
# 2025-01-08 10:29:49,018 - root - INFO - Processing train_val_split_2 val crazyegg.com
# 2025-01-08 10:29:49,218 - root - INFO - Processing train_val_split_2 val gitlab.com
# 2025-01-08 10:29:49,699 - root - INFO - Processing train_val_split_2 val squarespace.com
# 2025-01-08 10:29:49,948 - root - INFO - Processing train_val_split_2 val yy.com
# 2025-01-08 10:29:50,218 - root - INFO - Processing train_val_split_2 val twitter.com
# 2025-01-08 10:29:50,419 - root - INFO - Processing train_val_split_2 val netflix.com
# 2025-01-08 10:29:50,665 - root - INFO - Processing train_val_split_2 val sciencedirect.com
# 2025-01-08 10:29:50,847 - root - INFO - Processing train_val_split_2 val eastday.com
# 2025-01-08 10:29:51,100 - root - INFO - Processing train_val_split_2 val t.co
# 2025-01-08 10:29:51,318 - root - INFO - Processing train_val_split_0
# 2025-01-08 10:29:51,320 - root - INFO - Processing train_val_split_0 train
# 2025-01-08 10:29:51,325 - root - INFO - Processing train_val_split_0 train azureedge.net
# 2025-01-08 10:29:51,740 - root - INFO - Processing train_val_split_0 train hubspot.com
# 2025-01-08 10:29:52,118 - root - INFO - Processing train_val_split_0 train pinduoduo.com
# 2025-01-08 10:29:52,524 - root - INFO - Processing train_val_split_0 train jd.com
# 2025-01-08 10:29:52,971 - root - INFO - Processing train_val_split_0 train snapchat.com
# 2025-01-08 10:29:53,399 - root - INFO - Processing train_val_split_0 train qcloud.com
# 2025-01-08 10:29:53,844 - root - INFO - Processing train_val_split_0 train 51.la
# 2025-01-08 10:29:54,267 - root - INFO - Processing train_val_split_0 train arxiv.org
# 2025-01-08 10:29:54,633 - root - INFO - Processing train_val_split_0 train onlinedown.net
# 2025-01-08 10:29:55,114 - root - INFO - Processing train_val_split_0 train grammarly.com
# 2025-01-08 10:29:55,581 - root - INFO - Processing train_val_split_0 train cloudfront.net
# 2025-01-08 10:29:55,948 - root - INFO - Processing train_val_split_0 train teads.tv
# 2025-01-08 10:29:56,417 - root - INFO - Processing train_val_split_0 train office.net
# 2025-01-08 10:29:56,880 - root - INFO - Processing train_val_split_0 train huawei.com
# 2025-01-08 10:29:57,957 - root - INFO - Processing train_val_split_0 train researchgate.net
# 2025-01-08 10:29:58,473 - root - INFO - Processing train_val_split_0 train elsevier.com
# 2025-01-08 10:29:58,885 - root - INFO - Processing train_val_split_0 train instagram.com
# 2025-01-08 10:29:59,270 - root - INFO - Processing train_val_split_0 train microsoft.com
# 2025-01-08 10:29:59,799 - root - INFO - Processing train_val_split_0 train criteo.com
# 2025-01-08 10:30:00,425 - root - INFO - Processing train_val_split_0 train apple.com
# 2025-01-08 10:30:00,961 - root - INFO - Processing train_val_split_0 train codepen.io
# 2025-01-08 10:30:01,613 - root - INFO - Processing train_val_split_0 train wikimedia.org
# 2025-01-08 10:30:02,075 - root - INFO - Processing train_val_split_0 train overleaf.com
# 2025-01-08 10:30:02,884 - root - INFO - Processing train_val_split_0 train dailymotion.com
# 2025-01-08 10:30:03,506 - root - INFO - Processing train_val_split_0 train 163.com
# 2025-01-08 10:30:03,945 - root - INFO - Processing train_val_split_0 train semanticscholar.org
# 2025-01-08 10:30:04,387 - root - INFO - Processing train_val_split_0 train booking.com
# 2025-01-08 10:30:04,995 - root - INFO - Processing train_val_split_0 train sohu.com
# 2025-01-08 10:30:05,627 - root - INFO - Processing train_val_split_0 train twimg.com
# 2025-01-08 10:30:06,285 - root - INFO - Processing train_val_split_0 train github.com
# 2025-01-08 10:30:06,716 - root - INFO - Processing train_val_split_0 train nvidia.com
# 2025-01-08 10:30:07,169 - root - INFO - Processing train_val_split_0 train mozilla.org
# 2025-01-08 10:30:07,566 - root - INFO - Processing train_val_split_0 train cisco.com
# 2025-01-08 10:30:08,116 - root - INFO - Processing train_val_split_0 train alipay.com
# 2025-01-08 10:30:08,473 - root - INFO - Processing train_val_split_0 train digitaloceanspaces.com
# 2025-01-08 10:30:08,932 - root - INFO - Processing train_val_split_0 train amazonaws.com
# 2025-01-08 10:30:09,409 - root - INFO - Processing train_val_split_0 train biligame.com
# 2025-01-08 10:30:09,821 - root - INFO - Processing train_val_split_0 train icloud.com
# 2025-01-08 10:30:10,269 - root - INFO - Processing train_val_split_0 train cloudflare.com
# 2025-01-08 10:30:10,716 - root - INFO - Processing train_val_split_0 train statcounter.com
# 2025-01-08 10:30:11,137 - root - INFO - Processing train_val_split_0 train alibaba.com
# 2025-01-08 10:30:11,521 - root - INFO - Processing train_val_split_0 train unity3d.com
# 2025-01-08 10:30:12,005 - root - INFO - Processing train_val_split_0 train taboola.com
# 2025-01-08 10:30:12,575 - root - INFO - Processing train_val_split_0 train notion.so
# 2025-01-08 10:30:13,040 - root - INFO - Processing train_val_split_0 train spring.io
# 2025-01-08 10:30:13,499 - root - INFO - Processing train_val_split_0 train amap.com
# 2025-01-08 10:30:13,962 - root - INFO - Processing train_val_split_0 train vivo.com.cn
# 2025-01-08 10:30:14,353 - root - INFO - Processing train_val_split_0 train acm.org
# 2025-01-08 10:30:14,941 - root - INFO - Processing train_val_split_0 train guancha.cn
# 2025-01-08 10:30:15,377 - root - INFO - Processing train_val_split_0 train atlassian.net
# 2025-01-08 10:30:15,815 - root - INFO - Processing train_val_split_0 train nike.com
# 2025-01-08 10:30:16,440 - root - INFO - Processing train_val_split_0 train huanqiu.com
# 2025-01-08 10:30:16,840 - root - INFO - Processing train_val_split_0 train asus.com
# 2025-01-08 10:30:17,253 - root - INFO - Processing train_val_split_0 train python.org
# 2025-01-08 10:30:17,675 - root - INFO - Processing train_val_split_0 train thepaper.cn
# 2025-01-08 10:30:18,270 - root - INFO - Processing train_val_split_0 train goat.com
# 2025-01-08 10:30:18,896 - root - INFO - Processing train_val_split_0 train ibm.com
# 2025-01-08 10:30:19,324 - root - INFO - Processing train_val_split_0 train ximalaya.com
# 2025-01-08 10:30:19,805 - root - INFO - Processing train_val_split_0 train facebook.com
# 2025-01-08 10:30:20,181 - root - INFO - Processing train_val_split_0 train google.com
# 2025-01-08 10:30:20,608 - root - INFO - Processing train_val_split_0 train media.net
# 2025-01-08 10:30:21,027 - root - INFO - Processing train_val_split_0 train chia.net
# 2025-01-08 10:30:21,085 - root - INFO - Processing train_val_split_0 train oracle.com
# 2025-01-08 10:30:21,577 - root - INFO - Processing train_val_split_0 train leetcode-cn.com
# 2025-01-08 10:30:22,042 - root - INFO - Processing train_val_split_0 train wp.com
# 2025-01-08 10:30:22,504 - root - INFO - Processing train_val_split_0 train ctrip.com
# 2025-01-08 10:30:22,965 - root - INFO - Processing train_val_split_0 train yahoo.com
# 2025-01-08 10:30:23,430 - root - INFO - Processing train_val_split_0 train yandex.ru
# 2025-01-08 10:30:23,937 - root - INFO - Processing train_val_split_0 train kugou.com
# 2025-01-08 10:30:24,424 - root - INFO - Processing train_val_split_0 train deepl.com
# 2025-01-08 10:30:24,964 - root - INFO - Processing train_val_split_0 train paypal.com
# 2025-01-08 10:30:25,404 - root - INFO - Processing train_val_split_0 train gmail.com
# 2025-01-08 10:30:25,841 - root - INFO - Processing train_val_split_0 train zhihu.com
# 2025-01-08 10:30:26,273 - root - INFO - Processing train_val_split_0 train 51cto.com
# 2025-01-08 10:30:26,848 - root - INFO - Processing train_val_split_0 train sina.com.cn
# 2025-01-08 10:30:27,318 - root - INFO - Processing train_val_split_0 train msn.com
# 2025-01-08 10:30:27,751 - root - INFO - Processing train_val_split_0 train vmware.com
# 2025-01-08 10:30:28,349 - root - INFO - Processing train_val_split_0 train ggpht.com
# 2025-01-08 10:30:28,845 - root - INFO - Processing train_val_split_0 train vk.com
# 2025-01-08 10:30:29,218 - root - INFO - Processing train_val_split_0 train ieee.org
# 2025-01-08 10:30:29,608 - root - INFO - Processing train_val_split_0 train ampproject.org
# 2025-01-08 10:30:30,102 - root - INFO - Processing train_val_split_0 train xiaomi.com
# 2025-01-08 10:30:30,638 - root - INFO - Processing train_val_split_0 train baidu.com
# 2025-01-08 10:30:31,131 - root - INFO - Processing train_val_split_0 train tiktok.com
# 2025-01-08 10:30:31,594 - root - INFO - Processing train_val_split_0 train wikipedia.org
# 2025-01-08 10:30:32,052 - root - INFO - Processing train_val_split_0 train walmart.com
# 2025-01-08 10:30:32,454 - root - INFO - Processing train_val_split_0 train toutiao.com
# 2025-01-08 10:30:32,879 - root - INFO - Processing train_val_split_0 train cnblogs.com
# 2025-01-08 10:30:33,341 - root - INFO - Processing train_val_split_0 train weibo.com
# 2025-01-08 10:30:33,908 - root - INFO - Processing train_val_split_0 train bilibili.com
# 2025-01-08 10:30:34,324 - root - INFO - Processing train_val_split_0 train runoob.com
# 2025-01-08 10:30:34,832 - root - INFO - Processing train_val_split_0 train steampowered.com
# 2025-01-08 10:30:35,287 - root - INFO - Processing train_val_split_0 train outbrain.com
# 2025-01-08 10:30:35,641 - root - INFO - Processing train_val_split_0 train qq.com
# 2025-01-08 10:30:36,095 - root - INFO - Processing train_val_split_0 train gravatar.com
# 2025-01-08 10:30:36,631 - root - INFO - Processing train_val_split_0 train eastmoney.com
# 2025-01-08 10:30:37,114 - root - INFO - Processing train_val_split_0 train feishu.cn
# 2025-01-08 10:30:37,522 - root - INFO - Processing train_val_split_0 train v2ex.com
# 2025-01-08 10:30:37,984 - root - INFO - Processing train_val_split_0 train chinatax.gov.cn
# 2025-01-08 10:30:38,534 - root - INFO - Processing train_val_split_0 train opera.com
# 2025-01-08 10:30:38,911 - root - INFO - Processing train_val_split_0 train naver.com
# 2025-01-08 10:30:39,341 - root - INFO - Processing train_val_split_0 train alicdn.com
# 2025-01-08 10:30:39,769 - root - INFO - Processing train_val_split_0 train youtube.com
# 2025-01-08 10:30:40,149 - root - INFO - Processing train_val_split_0 train mi.com
# 2025-01-08 10:30:40,569 - root - INFO - Processing train_val_split_0 train smzdm.com
# 2025-01-08 10:30:41,023 - root - INFO - Processing train_val_split_0 train iqiyi.com
# 2025-01-08 10:30:41,382 - root - INFO - Processing train_val_split_0 train jb51.net
# 2025-01-08 10:30:41,803 - root - INFO - Processing train_val_split_0 train adobe.com
# 2025-01-08 10:30:42,273 - root - INFO - Processing train_val_split_0 train springer.com
# 2025-01-08 10:30:42,878 - root - INFO - Processing train_val_split_0 train duckduckgo.com
# 2025-01-08 10:30:43,241 - root - INFO - Processing train_val_split_0 train huya.com
# 2025-01-08 10:30:43,687 - root - INFO - Processing train_val_split_0 train crazyegg.com
# 2025-01-08 10:30:44,150 - root - INFO - Processing train_val_split_0 train gitlab.com
# 2025-01-08 10:30:44,715 - root - INFO - Processing train_val_split_0 train squarespace.com
# 2025-01-08 10:30:45,158 - root - INFO - Processing train_val_split_0 train yy.com
# 2025-01-08 10:30:45,561 - root - INFO - Processing train_val_split_0 train twitter.com
# 2025-01-08 10:30:46,070 - root - INFO - Processing train_val_split_0 train netflix.com
# 2025-01-08 10:30:46,453 - root - INFO - Processing train_val_split_0 train sciencedirect.com
# 2025-01-08 10:30:46,948 - root - INFO - Processing train_val_split_0 train eastday.com
# 2025-01-08 10:30:47,470 - root - INFO - Processing train_val_split_0 train t.co
# 2025-01-08 10:30:47,868 - root - INFO - Processing train_val_split_0 val
# 2025-01-08 10:30:47,874 - root - INFO - Processing train_val_split_0 val azureedge.net
# 2025-01-08 10:30:48,042 - root - INFO - Processing train_val_split_0 val hubspot.com
# 2025-01-08 10:30:48,355 - root - INFO - Processing train_val_split_0 val pinduoduo.com
# 2025-01-08 10:30:48,532 - root - INFO - Processing train_val_split_0 val jd.com
# 2025-01-08 10:30:48,789 - root - INFO - Processing train_val_split_0 val snapchat.com
# 2025-01-08 10:30:48,989 - root - INFO - Processing train_val_split_0 val qcloud.com
# 2025-01-08 10:30:49,153 - root - INFO - Processing train_val_split_0 val 51.la
# 2025-01-08 10:30:49,376 - root - INFO - Processing train_val_split_0 val arxiv.org
# 2025-01-08 10:30:49,692 - root - INFO - Processing train_val_split_0 val onlinedown.net
# 2025-01-08 10:30:49,947 - root - INFO - Processing train_val_split_0 val grammarly.com
# 2025-01-08 10:30:50,153 - root - INFO - Processing train_val_split_0 val cloudfront.net
# 2025-01-08 10:30:50,391 - root - INFO - Processing train_val_split_0 val teads.tv
# 2025-01-08 10:30:50,603 - root - INFO - Processing train_val_split_0 val office.net
# 2025-01-08 10:30:50,851 - root - INFO - Processing train_val_split_0 val huawei.com
# 2025-01-08 10:30:51,167 - root - INFO - Processing train_val_split_0 val researchgate.net
# 2025-01-08 10:30:51,592 - root - INFO - Processing train_val_split_0 val elsevier.com
# 2025-01-08 10:30:51,820 - root - INFO - Processing train_val_split_0 val instagram.com
# 2025-01-08 10:30:52,051 - root - INFO - Processing train_val_split_0 val microsoft.com
# 2025-01-08 10:30:52,338 - root - INFO - Processing train_val_split_0 val criteo.com
# 2025-01-08 10:30:52,623 - root - INFO - Processing train_val_split_0 val apple.com
# 2025-01-08 10:30:52,863 - root - INFO - Processing train_val_split_0 val codepen.io
# 2025-01-08 10:30:53,084 - root - INFO - Processing train_val_split_0 val wikimedia.org
# 2025-01-08 10:30:53,357 - root - INFO - Processing train_val_split_0 val overleaf.com
# 2025-01-08 10:30:53,652 - root - INFO - Processing train_val_split_0 val dailymotion.com
# 2025-01-08 10:30:53,944 - root - INFO - Processing train_val_split_0 val 163.com
# 2025-01-08 10:30:54,151 - root - INFO - Processing train_val_split_0 val semanticscholar.org
# 2025-01-08 10:30:54,383 - root - INFO - Processing train_val_split_0 val booking.com
# 2025-01-08 10:30:54,664 - root - INFO - Processing train_val_split_0 val sohu.com
# 2025-01-08 10:30:54,900 - root - INFO - Processing train_val_split_0 val twimg.com
# 2025-01-08 10:30:55,184 - root - INFO - Processing train_val_split_0 val github.com
# 2025-01-08 10:30:55,374 - root - INFO - Processing train_val_split_0 val nvidia.com
# 2025-01-08 10:30:55,695 - root - INFO - Processing train_val_split_0 val mozilla.org
# 2025-01-08 10:30:55,930 - root - INFO - Processing train_val_split_0 val cisco.com
# 2025-01-08 10:30:56,116 - root - INFO - Processing train_val_split_0 val alipay.com
# 2025-01-08 10:30:56,314 - root - INFO - Processing train_val_split_0 val digitaloceanspaces.com
# 2025-01-08 10:30:56,524 - root - INFO - Processing train_val_split_0 val amazonaws.com
# 2025-01-08 10:30:56,725 - root - INFO - Processing train_val_split_0 val biligame.com
# 2025-01-08 10:30:56,886 - root - INFO - Processing train_val_split_0 val icloud.com
# 2025-01-08 10:30:57,128 - root - INFO - Processing train_val_split_0 val cloudflare.com
# 2025-01-08 10:30:57,319 - root - INFO - Processing train_val_split_0 val statcounter.com
# 2025-01-08 10:30:57,536 - root - INFO - Processing train_val_split_0 val alibaba.com
# 2025-01-08 10:30:57,753 - root - INFO - Processing train_val_split_0 val unity3d.com
# 2025-01-08 10:30:57,968 - root - INFO - Processing train_val_split_0 val taboola.com
# 2025-01-08 10:30:58,231 - root - INFO - Processing train_val_split_0 val notion.so
# 2025-01-08 10:30:58,490 - root - INFO - Processing train_val_split_0 val spring.io
# 2025-01-08 10:30:58,762 - root - INFO - Processing train_val_split_0 val amap.com
# 2025-01-08 10:30:58,963 - root - INFO - Processing train_val_split_0 val vivo.com.cn
# 2025-01-08 10:30:59,308 - root - INFO - Processing train_val_split_0 val acm.org
# 2025-01-08 10:30:59,585 - root - INFO - Processing train_val_split_0 val guancha.cn
# 2025-01-08 10:30:59,816 - root - INFO - Processing train_val_split_0 val atlassian.net
# 2025-01-08 10:31:00,059 - root - INFO - Processing train_val_split_0 val nike.com
# 2025-01-08 10:31:00,303 - root - INFO - Processing train_val_split_0 val huanqiu.com
# 2025-01-08 10:31:00,476 - root - INFO - Processing train_val_split_0 val asus.com
# 2025-01-08 10:31:00,700 - root - INFO - Processing train_val_split_0 val python.org
# 2025-01-08 10:31:00,994 - root - INFO - Processing train_val_split_0 val thepaper.cn
# 2025-01-08 10:31:01,324 - root - INFO - Processing train_val_split_0 val goat.com
# 2025-01-08 10:31:01,585 - root - INFO - Processing train_val_split_0 val ibm.com
# 2025-01-08 10:31:01,821 - root - INFO - Processing train_val_split_0 val ximalaya.com
# 2025-01-08 10:31:01,997 - root - INFO - Processing train_val_split_0 val facebook.com
# 2025-01-08 10:31:02,241 - root - INFO - Processing train_val_split_0 val google.com
# 2025-01-08 10:31:02,403 - root - INFO - Processing train_val_split_0 val media.net
# 2025-01-08 10:31:02,654 - root - INFO - Processing train_val_split_0 val chia.net
# 2025-01-08 10:31:02,688 - root - INFO - Processing train_val_split_0 val oracle.com
# 2025-01-08 10:31:02,904 - root - INFO - Processing train_val_split_0 val leetcode-cn.com
# 2025-01-08 10:31:03,166 - root - INFO - Processing train_val_split_0 val wp.com
# 2025-01-08 10:31:03,412 - root - INFO - Processing train_val_split_0 val ctrip.com
# 2025-01-08 10:31:03,616 - root - INFO - Processing train_val_split_0 val yahoo.com
# 2025-01-08 10:31:03,826 - root - INFO - Processing train_val_split_0 val yandex.ru
# 2025-01-08 10:31:04,002 - root - INFO - Processing train_val_split_0 val kugou.com
# 2025-01-08 10:31:04,234 - root - INFO - Processing train_val_split_0 val deepl.com
# 2025-01-08 10:31:04,465 - root - INFO - Processing train_val_split_0 val paypal.com
# 2025-01-08 10:31:04,698 - root - INFO - Processing train_val_split_0 val gmail.com
# 2025-01-08 10:31:04,861 - root - INFO - Processing train_val_split_0 val zhihu.com
# 2025-01-08 10:31:05,073 - root - INFO - Processing train_val_split_0 val 51cto.com
# 2025-01-08 10:31:05,330 - root - INFO - Processing train_val_split_0 val sina.com.cn
# 2025-01-08 10:31:05,550 - root - INFO - Processing train_val_split_0 val msn.com
# 2025-01-08 10:31:05,789 - root - INFO - Processing train_val_split_0 val vmware.com
# 2025-01-08 10:31:06,004 - root - INFO - Processing train_val_split_0 val ggpht.com
# 2025-01-08 10:31:06,198 - root - INFO - Processing train_val_split_0 val vk.com
# 2025-01-08 10:31:06,416 - root - INFO - Processing train_val_split_0 val ieee.org
# 2025-01-08 10:31:06,628 - root - INFO - Processing train_val_split_0 val ampproject.org
# 2025-01-08 10:31:06,864 - root - INFO - Processing train_val_split_0 val xiaomi.com
# 2025-01-08 10:31:07,153 - root - INFO - Processing train_val_split_0 val baidu.com
# 2025-01-08 10:31:07,357 - root - INFO - Processing train_val_split_0 val tiktok.com
# 2025-01-08 10:31:07,595 - root - INFO - Processing train_val_split_0 val wikipedia.org
# 2025-01-08 10:31:07,866 - root - INFO - Processing train_val_split_0 val walmart.com
# 2025-01-08 10:31:08,103 - root - INFO - Processing train_val_split_0 val toutiao.com
# 2025-01-08 10:31:08,277 - root - INFO - Processing train_val_split_0 val cnblogs.com
# 2025-01-08 10:31:08,571 - root - INFO - Processing train_val_split_0 val weibo.com
# 2025-01-08 10:31:08,801 - root - INFO - Processing train_val_split_0 val bilibili.com
# 2025-01-08 10:31:09,053 - root - INFO - Processing train_val_split_0 val runoob.com
# 2025-01-08 10:31:09,242 - root - INFO - Processing train_val_split_0 val steampowered.com
# 2025-01-08 10:31:09,401 - root - INFO - Processing train_val_split_0 val outbrain.com
# 2025-01-08 10:31:09,591 - root - INFO - Processing train_val_split_0 val qq.com
# 2025-01-08 10:31:09,800 - root - INFO - Processing train_val_split_0 val gravatar.com
# 2025-01-08 10:31:09,995 - root - INFO - Processing train_val_split_0 val eastmoney.com
# 2025-01-08 10:31:10,193 - root - INFO - Processing train_val_split_0 val feishu.cn
# 2025-01-08 10:31:10,370 - root - INFO - Processing train_val_split_0 val v2ex.com
# 2025-01-08 10:31:10,660 - root - INFO - Processing train_val_split_0 val chinatax.gov.cn
# 2025-01-08 10:31:10,913 - root - INFO - Processing train_val_split_0 val opera.com
# 2025-01-08 10:31:11,190 - root - INFO - Processing train_val_split_0 val naver.com
# 2025-01-08 10:31:11,426 - root - INFO - Processing train_val_split_0 val alicdn.com
# 2025-01-08 10:31:11,632 - root - INFO - Processing train_val_split_0 val youtube.com
# 2025-01-08 10:31:11,851 - root - INFO - Processing train_val_split_0 val mi.com
# 2025-01-08 10:31:12,038 - root - INFO - Processing train_val_split_0 val smzdm.com
# 2025-01-08 10:31:12,241 - root - INFO - Processing train_val_split_0 val iqiyi.com
# 2025-01-08 10:31:12,485 - root - INFO - Processing train_val_split_0 val jb51.net
# 2025-01-08 10:31:12,726 - root - INFO - Processing train_val_split_0 val adobe.com
# 2025-01-08 10:31:12,935 - root - INFO - Processing train_val_split_0 val springer.com
# 2025-01-08 10:31:13,166 - root - INFO - Processing train_val_split_0 val duckduckgo.com
# 2025-01-08 10:31:13,356 - root - INFO - Processing train_val_split_0 val huya.com
# 2025-01-08 10:31:13,593 - root - INFO - Processing train_val_split_0 val crazyegg.com
# 2025-01-08 10:31:13,786 - root - INFO - Processing train_val_split_0 val gitlab.com
# 2025-01-08 10:31:14,029 - root - INFO - Processing train_val_split_0 val squarespace.com
# 2025-01-08 10:31:14,201 - root - INFO - Processing train_val_split_0 val yy.com
# 2025-01-08 10:31:14,396 - root - INFO - Processing train_val_split_0 val twitter.com
# 2025-01-08 10:31:14,562 - root - INFO - Processing train_val_split_0 val netflix.com
# 2025-01-08 10:31:14,899 - root - INFO - Processing train_val_split_0 val sciencedirect.com
# 2025-01-08 10:31:15,147 - root - INFO - Processing train_val_split_0 val eastday.com
# 2025-01-08 10:31:15,349 - root - INFO - Processing train_val_split_0 val t.co
# 2025-01-08 10:31:15,595 - root - INFO - Processing test
# 2025-01-08 10:31:15,600 - root - INFO - Processing test azureedge.net
# 2025-01-08 10:31:16,618 - root - INFO - Processing test hubspot.com
# 2025-01-08 10:31:17,410 - root - INFO - Processing test pinduoduo.com
# 2025-01-08 10:31:18,242 - root - INFO - Processing test jd.com
# 2025-01-08 10:31:19,106 - root - INFO - Processing test snapchat.com
# 2025-01-08 10:31:20,062 - root - INFO - Processing test qcloud.com
# 2025-01-08 10:31:20,955 - root - INFO - Processing test 51.la
# 2025-01-08 10:31:21,188 - root - INFO - Processing test arxiv.org
# 2025-01-08 10:31:21,931 - root - INFO - Processing test onlinedown.net
# 2025-01-08 10:31:22,402 - root - INFO - Processing test grammarly.com
# 2025-01-08 10:31:22,777 - root - INFO - Processing test cloudfront.net
# 2025-01-08 10:31:23,560 - root - INFO - Processing test teads.tv
# 2025-01-08 10:31:24,388 - root - INFO - Processing test office.net
# 2025-01-08 10:31:25,071 - root - INFO - Processing test huawei.com
# 2025-01-08 10:31:25,568 - root - INFO - Processing test researchgate.net
# 2025-01-08 10:31:26,448 - root - INFO - Processing test elsevier.com
# 2025-01-08 10:31:26,876 - root - INFO - Processing test instagram.com
# 2025-01-08 10:31:27,285 - root - INFO - Processing test microsoft.com
# 2025-01-08 10:31:28,127 - root - INFO - Processing test criteo.com
# 2025-01-08 10:31:28,969 - root - INFO - Processing test apple.com
# 2025-01-08 10:31:30,006 - root - INFO - Processing test codepen.io
# 2025-01-08 10:31:30,636 - root - INFO - Processing test wikimedia.org
# 2025-01-08 10:31:31,345 - root - INFO - Processing test overleaf.com
# 2025-01-08 10:31:32,742 - root - INFO - Processing test dailymotion.com
# 2025-01-08 10:31:34,421 - root - INFO - Processing test 163.com
# 2025-01-08 10:31:35,373 - root - INFO - Processing test semanticscholar.org
# 2025-01-08 10:31:35,917 - root - INFO - Processing test booking.com
# 2025-01-08 10:31:36,160 - root - INFO - Processing test sohu.com
# 2025-01-08 10:31:36,977 - root - INFO - Processing test twimg.com
# 2025-01-08 10:31:38,181 - root - INFO - Processing test github.com
# 2025-01-08 10:31:39,201 - root - INFO - Processing test nvidia.com
# 2025-01-08 10:31:39,938 - root - INFO - Processing test mozilla.org
# 2025-01-08 10:31:40,788 - root - INFO - Processing test cisco.com
# 2025-01-08 10:31:41,719 - root - INFO - Processing test alipay.com
# 2025-01-08 10:31:42,568 - root - INFO - Processing test digitaloceanspaces.com
# 2025-01-08 10:31:43,403 - root - INFO - Processing test amazonaws.com
# 2025-01-08 10:31:44,291 - root - INFO - Processing test biligame.com
# 2025-01-08 10:31:45,208 - root - INFO - Processing test icloud.com
# 2025-01-08 10:31:46,068 - root - INFO - Processing test cloudflare.com
# 2025-01-08 10:31:46,898 - root - INFO - Processing test statcounter.com
# 2025-01-08 10:31:47,274 - root - INFO - Processing test alibaba.com
# 2025-01-08 10:31:47,756 - root - INFO - Processing test unity3d.com
# 2025-01-08 10:31:48,547 - root - INFO - Processing test taboola.com
# 2025-01-08 10:31:49,403 - root - INFO - Processing test notion.so
# 2025-01-08 10:31:50,223 - root - INFO - Processing test spring.io
# 2025-01-08 10:31:50,563 - root - INFO - Processing test amap.com
# 2025-01-08 10:31:51,469 - root - INFO - Processing test vivo.com.cn
# 2025-01-08 10:31:52,327 - root - INFO - Processing test acm.org
# 2025-01-08 10:31:53,167 - root - INFO - Processing test guancha.cn
# 2025-01-08 10:31:54,054 - root - INFO - Processing test atlassian.net
# 2025-01-08 10:31:54,346 - root - INFO - Processing test nike.com
# 2025-01-08 10:31:55,276 - root - INFO - Processing test huanqiu.com
# 2025-01-08 10:31:56,071 - root - INFO - Processing test asus.com
# 2025-01-08 10:31:56,812 - root - INFO - Processing test python.org
# 2025-01-08 10:31:57,633 - root - INFO - Processing test thepaper.cn
# 2025-01-08 10:31:57,965 - root - INFO - Processing test goat.com
# 2025-01-08 10:31:58,195 - root - INFO - Processing test ibm.com
# 2025-01-08 10:31:58,533 - root - INFO - Processing test ximalaya.com
# 2025-01-08 10:31:59,154 - root - INFO - Processing test facebook.com
# 2025-01-08 10:32:00,036 - root - INFO - Processing test google.com
# 2025-01-08 10:32:00,901 - root - INFO - Processing test media.net
# 2025-01-08 10:32:01,768 - root - INFO - Processing test chia.net
# 2025-01-08 10:32:01,790 - root - INFO - Processing test oracle.com
# 2025-01-08 10:32:02,161 - root - INFO - Processing test leetcode-cn.com
# 2025-01-08 10:32:03,111 - root - INFO - Processing test wp.com
# 2025-01-08 10:32:03,912 - root - INFO - Processing test ctrip.com
# 2025-01-08 10:32:04,756 - root - INFO - Processing test yahoo.com
# 2025-01-08 10:32:05,564 - root - INFO - Processing test yandex.ru
# 2025-01-08 10:32:06,511 - root - INFO - Processing test kugou.com
# 2025-01-08 10:32:07,429 - root - INFO - Processing test deepl.com
# 2025-01-08 10:32:07,796 - root - INFO - Processing test paypal.com
# 2025-01-08 10:32:08,080 - root - INFO - Processing test gmail.com
# 2025-01-08 10:32:08,857 - root - INFO - Processing test zhihu.com
# 2025-01-08 10:32:09,738 - root - INFO - Processing test 51cto.com
# 2025-01-08 10:32:10,581 - root - INFO - Processing test sina.com.cn
# 2025-01-08 10:32:11,412 - root - INFO - Processing test msn.com
# 2025-01-08 10:32:12,142 - root - INFO - Processing test vmware.com
# 2025-01-08 10:32:12,539 - root - INFO - Processing test ggpht.com
# 2025-01-08 10:32:13,493 - root - INFO - Processing test vk.com
# 2025-01-08 10:32:13,880 - root - INFO - Processing test ieee.org
# 2025-01-08 10:32:14,726 - root - INFO - Processing test ampproject.org
# 2025-01-08 10:32:15,642 - root - INFO - Processing test xiaomi.com
# 2025-01-08 10:32:16,004 - root - INFO - Processing test baidu.com
# 2025-01-08 10:32:16,976 - root - INFO - Processing test tiktok.com
# 2025-01-08 10:32:17,180 - root - INFO - Processing test wikipedia.org
# 2025-01-08 10:32:17,828 - root - INFO - Processing test walmart.com
# 2025-01-08 10:32:18,545 - root - INFO - Processing test toutiao.com
# 2025-01-08 10:32:19,304 - root - INFO - Processing test cnblogs.com
# 2025-01-08 10:32:20,092 - root - INFO - Processing test weibo.com
# 2025-01-08 10:32:21,336 - root - INFO - Processing test bilibili.com
# 2025-01-08 10:32:22,254 - root - INFO - Processing test runoob.com
# 2025-01-08 10:32:22,994 - root - INFO - Processing test steampowered.com
# 2025-01-08 10:32:23,728 - root - INFO - Processing test outbrain.com
# 2025-01-08 10:32:24,109 - root - INFO - Processing test qq.com
# 2025-01-08 10:32:24,960 - root - INFO - Processing test gravatar.com
# ...
# 2025-01-08 10:33:07,459 - root - INFO - Processing train_val_split_1 train facebook.com
# 2025-01-08 10:33:07,867 - root - INFO - Processing train_val_split_1 train google.com
# 2025-01-08 10:33:08,306 - root - INFO - Processing train_val_split_1 train media.net
# 2025-01-08 10:33:08,731 - root - INFO - Processing train_val_split_1 train chia.net
# 2025-01-08 10:33:08,776 - root - INFO - Processing train_val_split_1 train oracle.com
# 2025-01-08 10:33:09,251 - root - INFO - Processing train_val_split_1 train leetcode-cn.com
# 2025-01-08 10:33:09,647 - root - INFO - Processing train_val_split_1 train wp.com
# 2025-01-08 10:33:10,013 - root - INFO - Processing train_val_split_1 train ctrip.com
# 2025-01-08 10:33:10,387 - root - INFO - Processing train_val_split_1 train yahoo.com
# 2025-01-08 10:33:10,761 - root - INFO - Processing train_val_split_1 train yandex.ru
# 2025-01-08 10:33:11,156 - root - INFO - Processing train_val_split_1 train kugou.com
# 2025-01-08 10:33:11,503 - root - INFO - Processing train_val_split_1 train deepl.com
# 2025-01-08 10:33:11,939 - root - INFO - Processing train_val_split_1 train paypal.com
# 2025-01-08 10:33:12,309 - root - INFO - Processing train_val_split_1 train gmail.com
# 2025-01-08 10:33:12,651 - root - INFO - Processing train_val_split_1 train zhihu.com
# 2025-01-08 10:33:13,280 - root - INFO - Processing train_val_split_1 train 51cto.com
# 2025-01-08 10:33:13,712 - root - INFO - Processing train_val_split_1 train sina.com.cn
# 2025-01-08 10:33:14,191 - root - INFO - Processing train_val_split_1 train msn.com
# 2025-01-08 10:33:14,598 - root - INFO - Processing train_val_split_1 train vmware.com
# 2025-01-08 10:33:15,069 - root - INFO - Processing train_val_split_1 train ggpht.com
# 2025-01-08 10:33:15,487 - root - INFO - Processing train_val_split_1 train vk.com
# 2025-01-08 10:33:15,913 - root - INFO - Processing train_val_split_1 train ieee.org
# 2025-01-08 10:33:16,316 - root - INFO - Processing train_val_split_1 train ampproject.org
# 2025-01-08 10:33:16,787 - root - INFO - Processing train_val_split_1 train xiaomi.com
# 2025-01-08 10:33:17,314 - root - INFO - Processing train_val_split_1 train baidu.com
# 2025-01-08 10:33:17,787 - root - INFO - Processing train_val_split_1 train tiktok.com
# 2025-01-08 10:33:18,234 - root - INFO - Processing train_val_split_1 train wikipedia.org
# 2025-01-08 10:33:18,739 - root - INFO - Processing train_val_split_1 train walmart.com
# 2025-01-08 10:33:19,086 - root - INFO - Processing train_val_split_1 train toutiao.com
# 2025-01-08 10:33:19,448 - root - INFO - Processing train_val_split_1 train cnblogs.com
# 2025-01-08 10:33:19,877 - root - INFO - Processing train_val_split_1 train weibo.com
# 2025-01-08 10:33:20,448 - root - INFO - Processing train_val_split_1 train bilibili.com
# 2025-01-08 10:33:20,837 - root - INFO - Processing train_val_split_1 train runoob.com
# 2025-01-08 10:33:21,328 - root - INFO - Processing train_val_split_1 train steampowered.com
# 2025-01-08 10:33:21,723 - root - INFO - Processing train_val_split_1 train outbrain.com
# 2025-01-08 10:33:22,087 - root - INFO - Processing train_val_split_1 train qq.com
# 2025-01-08 10:33:22,567 - root - INFO - Processing train_val_split_1 train gravatar.com
# 2025-01-08 10:33:23,519 - root - INFO - Processing train_val_split_1 train eastmoney.com
# 2025-01-08 10:33:23,926 - root - INFO - Processing train_val_split_1 train feishu.cn
# 2025-01-08 10:33:24,241 - root - INFO - Processing train_val_split_1 train v2ex.com
# 2025-01-08 10:33:24,855 - root - INFO - Processing train_val_split_1 train chinatax.gov.cn
# 2025-01-08 10:33:25,229 - root - INFO - Processing train_val_split_1 train opera.com
# 2025-01-08 10:33:25,625 - root - INFO - Processing train_val_split_1 train naver.com
# 2025-01-08 10:33:26,027 - root - INFO - Processing train_val_split_1 train alicdn.com
# 2025-01-08 10:33:26,472 - root - INFO - Processing train_val_split_1 train youtube.com
# 2025-01-08 10:33:27,005 - root - INFO - Processing train_val_split_1 train mi.com
# 2025-01-08 10:33:27,397 - root - INFO - Processing train_val_split_1 train smzdm.com
# 2025-01-08 10:33:27,811 - root - INFO - Processing train_val_split_1 train iqiyi.com
# 2025-01-08 10:33:28,197 - root - INFO - Processing train_val_split_1 train jb51.net
# 2025-01-08 10:33:28,547 - root - INFO - Processing train_val_split_1 train adobe.com
# 2025-01-08 10:33:28,926 - root - INFO - Processing train_val_split_1 train springer.com
# 2025-01-08 10:33:29,465 - root - INFO - Processing train_val_split_1 train duckduckgo.com
# 2025-01-08 10:33:29,777 - root - INFO - Processing train_val_split_1 train huya.com
# 2025-01-08 10:33:30,167 - root - INFO - Processing train_val_split_1 train crazyegg.com
# 2025-01-08 10:33:30,521 - root - INFO - Processing train_val_split_1 train gitlab.com
# 2025-01-08 10:33:30,981 - root - INFO - Processing train_val_split_1 train squarespace.com
# 2025-01-08 10:33:31,367 - root - INFO - Processing train_val_split_1 train yy.com
# 2025-01-08 10:33:31,784 - root - INFO - Processing train_val_split_1 train twitter.com
# 2025-01-08 10:33:32,200 - root - INFO - Processing train_val_split_1 train netflix.com
# 2025-01-08 10:33:32,613 - root - INFO - Processing train_val_split_1 train sciencedirect.com
# 2025-01-08 10:33:32,970 - root - INFO - Processing train_val_split_1 train eastday.com
# 2025-01-08 10:33:33,377 - root - INFO - Processing train_val_split_1 train t.co
# 2025-01-08 10:33:33,695 - root - INFO - Processing train_val_split_1 val
# 2025-01-08 10:33:33,697 - root - INFO - Processing train_val_split_1 val azureedge.net
# 2025-01-08 10:33:33,874 - root - INFO - Processing train_val_split_1 val hubspot.com
# 2025-01-08 10:33:34,091 - root - INFO - Processing train_val_split_1 val pinduoduo.com
# 2025-01-08 10:33:34,311 - root - INFO - Processing train_val_split_1 val jd.com
# 2025-01-08 10:33:34,505 - root - INFO - Processing train_val_split_1 val snapchat.com
# 2025-01-08 10:33:34,681 - root - INFO - Processing train_val_split_1 val qcloud.com
# 2025-01-08 10:33:34,880 - root - INFO - Processing train_val_split_1 val 51.la
# 2025-01-08 10:33:35,075 - root - INFO - Processing train_val_split_1 val arxiv.org
# 2025-01-08 10:33:35,294 - root - INFO - Processing train_val_split_1 val onlinedown.net
# 2025-01-08 10:33:35,645 - root - INFO - Processing train_val_split_1 val grammarly.com
# 2025-01-08 10:33:35,860 - root - INFO - Processing train_val_split_1 val cloudfront.net
# 2025-01-08 10:33:36,053 - root - INFO - Processing train_val_split_1 val teads.tv
# 2025-01-08 10:33:36,258 - root - INFO - Processing train_val_split_1 val office.net
# 2025-01-08 10:33:36,560 - root - INFO - Processing train_val_split_1 val huawei.com
# 2025-01-08 10:33:36,896 - root - INFO - Processing train_val_split_1 val researchgate.net
# 2025-01-08 10:33:37,153 - root - INFO - Processing train_val_split_1 val elsevier.com
# 2025-01-08 10:33:37,384 - root - INFO - Processing train_val_split_1 val instagram.com
# 2025-01-08 10:33:37,585 - root - INFO - Processing train_val_split_1 val microsoft.com
# 2025-01-08 10:33:37,809 - root - INFO - Processing train_val_split_1 val criteo.com
# 2025-01-08 10:33:37,994 - root - INFO - Processing train_val_split_1 val apple.com
# 2025-01-08 10:33:38,189 - root - INFO - Processing train_val_split_1 val codepen.io
# 2025-01-08 10:33:38,402 - root - INFO - Processing train_val_split_1 val wikimedia.org
# 2025-01-08 10:33:38,603 - root - INFO - Processing train_val_split_1 val overleaf.com
# 2025-01-08 10:33:38,900 - root - INFO - Processing train_val_split_1 val dailymotion.com
# 2025-01-08 10:33:39,287 - root - INFO - Processing train_val_split_1 val 163.com
# 2025-01-08 10:33:39,489 - root - INFO - Processing train_val_split_1 val semanticscholar.org
# 2025-01-08 10:33:39,707 - root - INFO - Processing train_val_split_1 val booking.com
# 2025-01-08 10:33:40,004 - root - INFO - Processing train_val_split_1 val sohu.com
# 2025-01-08 10:33:40,194 - root - INFO - Processing train_val_split_1 val twimg.com
# 2025-01-08 10:33:40,490 - root - INFO - Processing train_val_split_1 val github.com
# 2025-01-08 10:33:40,692 - root - INFO - Processing train_val_split_1 val nvidia.com
# 2025-01-08 10:33:40,880 - root - INFO - Processing train_val_split_1 val mozilla.org
# 2025-01-08 10:33:41,079 - root - INFO - Processing train_val_split_1 val cisco.com
# 2025-01-08 10:33:41,260 - root - INFO - Processing train_val_split_1 val alipay.com
# 2025-01-08 10:33:41,488 - root - INFO - Processing train_val_split_1 val digitaloceanspaces.com
# 2025-01-08 10:33:41,709 - root - INFO - Processing train_val_split_1 val amazonaws.com
# 2025-01-08 10:33:41,932 - root - INFO - Processing train_val_split_1 val biligame.com
# 2025-01-08 10:33:42,134 - root - INFO - Processing train_val_split_1 val icloud.com
# 2025-01-08 10:33:42,298 - root - INFO - Processing train_val_split_1 val cloudflare.com
# 2025-01-08 10:33:42,465 - root - INFO - Processing train_val_split_1 val statcounter.com
# 2025-01-08 10:33:42,724 - root - INFO - Processing train_val_split_1 val alibaba.com
# 2025-01-08 10:33:42,926 - root - INFO - Processing train_val_split_1 val unity3d.com
# 2025-01-08 10:33:43,230 - root - INFO - Processing train_val_split_1 val taboola.com
# 2025-01-08 10:33:43,401 - root - INFO - Processing train_val_split_1 val notion.so
# 2025-01-08 10:33:43,570 - root - INFO - Processing train_val_split_1 val spring.io
# 2025-01-08 10:33:43,764 - root - INFO - Processing train_val_split_1 val amap.com
# 2025-01-08 10:33:43,948 - root - INFO - Processing train_val_split_1 val vivo.com.cn
# 2025-01-08 10:33:44,214 - root - INFO - Processing train_val_split_1 val acm.org
# 2025-01-08 10:33:44,470 - root - INFO - Processing train_val_split_1 val guancha.cn
# 2025-01-08 10:33:44,667 - root - INFO - Processing train_val_split_1 val atlassian.net
# 2025-01-08 10:33:44,901 - root - INFO - Processing train_val_split_1 val nike.com
# 2025-01-08 10:33:45,125 - root - INFO - Processing train_val_split_1 val huanqiu.com
# 2025-01-08 10:33:45,291 - root - INFO - Processing train_val_split_1 val asus.com
# 2025-01-08 10:33:45,500 - root - INFO - Processing train_val_split_1 val python.org
# 2025-01-08 10:33:45,659 - root - INFO - Processing train_val_split_1 val thepaper.cn
# 2025-01-08 10:33:45,926 - root - INFO - Processing train_val_split_1 val goat.com
# 2025-01-08 10:33:46,139 - root - INFO - Processing train_val_split_1 val ibm.com
# 2025-01-08 10:33:46,381 - root - INFO - Processing train_val_split_1 val ximalaya.com
# 2025-01-08 10:33:46,578 - root - INFO - Processing train_val_split_1 val facebook.com
# 2025-01-08 10:33:46,781 - root - INFO - Processing train_val_split_1 val google.com
# 2025-01-08 10:33:46,952 - root - INFO - Processing train_val_split_1 val media.net
# 2025-01-08 10:33:47,117 - root - INFO - Processing train_val_split_1 val chia.net
# 2025-01-08 10:33:47,146 - root - INFO - Processing train_val_split_1 val oracle.com
# 2025-01-08 10:33:47,393 - root - INFO - Processing train_val_split_1 val leetcode-cn.com
# 2025-01-08 10:33:47,593 - root - INFO - Processing train_val_split_1 val wp.com
# 2025-01-08 10:33:47,794 - root - INFO - Processing train_val_split_1 val ctrip.com
# 2025-01-08 10:33:48,023 - root - INFO - Processing train_val_split_1 val yahoo.com
# 2025-01-08 10:33:48,219 - root - INFO - Processing train_val_split_1 val yandex.ru
# 2025-01-08 10:33:48,370 - root - INFO - Processing train_val_split_1 val kugou.com
# 2025-01-08 10:33:48,505 - root - INFO - Processing train_val_split_1 val deepl.com
# 2025-01-08 10:33:48,644 - root - INFO - Processing train_val_split_1 val paypal.com
# 2025-01-08 10:33:48,783 - root - INFO - Processing train_val_split_1 val gmail.com
# 2025-01-08 10:33:48,923 - root - INFO - Processing train_val_split_1 val zhihu.com
# 2025-01-08 10:33:49,057 - root - INFO - Processing train_val_split_1 val 51cto.com
# 2025-01-08 10:33:49,189 - root - INFO - Processing train_val_split_1 val sina.com.cn
# 2025-01-08 10:33:49,319 - root - INFO - Processing train_val_split_1 val msn.com
# 2025-01-08 10:33:49,448 - root - INFO - Processing train_val_split_1 val vmware.com
# 2025-01-08 10:33:49,584 - root - INFO - Processing train_val_split_1 val ggpht.com
# 2025-01-08 10:33:49,718 - root - INFO - Processing train_val_split_1 val vk.com
# 2025-01-08 10:33:49,856 - root - INFO - Processing train_val_split_1 val ieee.org
# 2025-01-08 10:33:49,988 - root - INFO - Processing train_val_split_1 val ampproject.org
# 2025-01-08 10:33:50,122 - root - INFO - Processing train_val_split_1 val xiaomi.com
# 2025-01-08 10:33:50,257 - root - INFO - Processing train_val_split_1 val baidu.com
# 2025-01-08 10:33:50,393 - root - INFO - Processing train_val_split_1 val tiktok.com
# 2025-01-08 10:33:50,536 - root - INFO - Processing train_val_split_1 val wikipedia.org
# 2025-01-08 10:33:50,878 - root - INFO - Processing train_val_split_1 val walmart.com
# 2025-01-08 10:33:51,008 - root - INFO - Processing train_val_split_1 val toutiao.com
# 2025-01-08 10:33:51,141 - root - INFO - Processing train_val_split_1 val cnblogs.com
# 2025-01-08 10:33:51,270 - root - INFO - Processing train_val_split_1 val weibo.com
# 2025-01-08 10:33:51,402 - root - INFO - Processing train_val_split_1 val bilibili.com
# 2025-01-08 10:33:51,534 - root - INFO - Processing train_val_split_1 val runoob.com
# 2025-01-08 10:33:51,667 - root - INFO - Processing train_val_split_1 val steampowered.com
# 2025-01-08 10:33:51,795 - root - INFO - Processing train_val_split_1 val outbrain.com
# 2025-01-08 10:33:51,923 - root - INFO - Processing train_val_split_1 val qq.com
# 2025-01-08 10:33:52,051 - root - INFO - Processing train_val_split_1 val gravatar.com
# 2025-01-08 10:33:52,181 - root - INFO - Processing train_val_split_1 val eastmoney.com
# 2025-01-08 10:33:52,314 - root - INFO - Processing train_val_split_1 val feishu.cn
# 2025-01-08 10:33:52,443 - root - INFO - Processing train_val_split_1 val v2ex.com
# 2025-01-08 10:33:52,572 - root - INFO - Processing train_val_split_1 val chinatax.gov.cn
# 2025-01-08 10:33:52,708 - root - INFO - Processing train_val_split_1 val opera.com
# 2025-01-08 10:33:52,847 - root - INFO - Processing train_val_split_1 val naver.com
# 2025-01-08 10:33:52,983 - root - INFO - Processing train_val_split_1 val alicdn.com
# 2025-01-08 10:33:53,112 - root - INFO - Processing train_val_split_1 val youtube.com
# 2025-01-08 10:33:53,247 - root - INFO - Processing train_val_split_1 val mi.com
# 2025-01-08 10:33:53,377 - root - INFO - Processing train_val_split_1 val smzdm.com
# 2025-01-08 10:33:53,511 - root - INFO - Processing train_val_split_1 val iqiyi.com
# 2025-01-08 10:33:53,639 - root - INFO - Processing train_val_split_1 val jb51.net
# 2025-01-08 10:33:53,774 - root - INFO - Processing train_val_split_1 val adobe.com
# 2025-01-08 10:33:53,905 - root - INFO - Processing train_val_split_1 val springer.com
# 2025-01-08 10:33:54,038 - root - INFO - Processing train_val_split_1 val duckduckgo.com
# 2025-01-08 10:33:54,168 - root - INFO - Processing train_val_split_1 val huya.com
# 2025-01-08 10:33:54,297 - root - INFO - Processing train_val_split_1 val crazyegg.com
# 2025-01-08 10:33:54,425 - root - INFO - Processing train_val_split_1 val gitlab.com
# 2025-01-08 10:33:54,575 - root - INFO - Processing train_val_split_1 val squarespace.com
# 2025-01-08 10:33:54,705 - root - INFO - Processing train_val_split_1 val yy.com
# 2025-01-08 10:33:54,841 - root - INFO - Processing train_val_split_1 val twitter.com
# 2025-01-08 10:33:54,974 - root - INFO - Processing train_val_split_1 val netflix.com
# 2025-01-08 10:33:55,106 - root - INFO - Processing train_val_split_1 val sciencedirect.com
# 2025-01-08 10:33:55,237 - root - INFO - Processing train_val_split_1 val eastday.com
# 2025-01-08 10:33:55,364 - root - INFO - Processing train_val_split_1 val t.co
# {'IP_chksum', 'TCP_echo_SAck', 'IP_frag', 'TCP_WScale', 'TCP_reserved', 'TCP_echo_Timestamp', 'TL_chksum', 'TCP_flags', 'TCP_ack', 'IP_version', 'TCP_urgptr', 'TCP_Timestamp', 'TCP_MSS', 'TCP_SAck', 'IP_flags', 'IP_proto', 'TCP_SAckOK', 'TCP_EOL', 'TCP_seq', 'IP_tos', 'TCP_window', 'IP_len', 'IP_ttl', 'IP_id', 'IP_ihl', 'TCP_dataofs'}
# {'', 'DF'}
# {'FA', 'S', 'FPA', 'PA', 'SA', 'R', 'A', 'RA'}

# %%
# convert the flag to integer

ip_flags_map = {}
tcp_flags_map = {}
flow_fields_set = set()

for id, ip_flag in enumerate(ip_flags_set):
    if ip_flag != '':
        ip_flags_map[ip_flag] = id + 1

for id, tcp_flag in enumerate(tcp_flags_set):
    if tcp_flag != '':
        tcp_flags_map[tcp_flag] = id + 1

for id in range(num_of_pkts):
    for field in field_set:
        flow_fields_set.add(f'{field}_{id}')
    if id < num_of_pkts - 1:
        flow_fields_set.add(f'interval_{id}_{id+1}')

print(ip_flags_map)
print(tcp_flags_map)
print(flow_fields_set)
# Out:
# {'DF': 2}
# {'FA': 1, 'S': 2, 'FPA': 3, 'PA': 4, 'SA': 5, 'R': 6, 'A': 7, 'RA': 8}
# {'interval_4_5', 'TCP_Timestamp_1', 'IP_ihl_6', 'IP_id_5', 'TCP_SAckOK_2', 'TCP_Timestamp_4', 'IP_proto_6', 'TCP_flags_2', 'TCP_MSS_5', 'IP_chksum_3', 'TCP_reserved_6', 'IP_tos_2', 'IP_id_2', 'TCP_reserved_3', 'IP_proto_5', 'TCP_seq_6', 'IP_ttl_0', 'TL_chksum_1', 'TCP_EOL_2', 'TCP_echo_SAck_5', 'TCP_flags_4', 'TCP_MSS_0', 'TCP_SAck_1', 'TCP_reserved_0', 'TCP_SAck_5', 'IP_proto_0', 'IP_ttl_1', 'TCP_window_4', 'TCP_EOL_1', 'IP_version_1', 'TCP_seq_1', 'IP_id_4', 'TCP_reserved_1', 'TL_chksum_2', 'IP_frag_1', 'TCP_MSS_1', 'IP_frag_2', 'TCP_seq_4', 'IP_chksum_1', 'IP_flags_2', 'TCP_echo_SAck_6', 'IP_tos_4', 'TCP_MSS_6', 'TCP_flags_0', 'IP_version_0', 'IP_id_0', 'IP_len_0', 'TCP_seq_5', 'interval_3_4', 'IP_ihl_0', 'TCP_flags_3', 'TCP_SAck_4', 'TCP_reserved_5', 'IP_flags_6', 'TCP_echo_Timestamp_4', 'IP_len_4', 'TCP_window_6', 'IP_ttl_2', 'TCP_seq_3', 'IP_version_5', 'IP_version_6', 'TCP_SAck_6', 'TCP_SAckOK_3', 'TCP_echo_Timestamp_3', 'IP_tos_5', 'IP_version_2', 'IP_flags_0', 'IP_proto_2', 'TCP_reserved_2', 'TCP_SAckOK_6', 'TCP_Timestamp_0', 'IP_proto_3', 'IP_tos_3', 'TCP_WScale_5', 'TCP_SAckOK_4', 'TCP_WScale_0', 'TCP_EOL_4', 'TCP_EOL_3', 'IP_len_2', 'TCP_SAckOK_1', 'TCP_ack_3', 'TCP_urgptr_6', 'TCP_ack_4', 'TL_chksum_5', 'TL_chksum_3', 'IP_chksum_6', 'TCP_echo_SAck_2', 'TCP_WScale_3', 'TCP_urgptr_1', 'TCP_echo_SAck_3', 'TCP_SAckOK_0', 'TL_chksum_4', 'TCP_ack_6', 'interval_0_1', 'TCP_urgptr_4', 'interval_1_2', 'IP_ttl_3', 'TCP_flags_5', 'IP_ihl_3', 'TCP_MSS_3', 'IP_chksum_2', 'TCP_Timestamp_6', 'IP_ttl_6', 'IP_len_1', 'IP_chksum_4', 'TCP_ack_1', 'TCP_echo_Timestamp_5', 'TCP_dataofs_4', 'IP_frag_6', 'TCP_dataofs_2', 'TCP_ack_5', 'TCP_seq_2', 'IP_len_6', 'TCP_echo_Timestamp_0', 'TCP_MSS_2', 'TCP_urgptr_2', 'IP_proto_1', 'TCP_window_2', 'IP_frag_0', 'TCP_window_1', 'IP_flags_4', 'TCP_echo_SAck_4', 'IP_len_5', 'TCP_Timestamp_2', 'TCP_urgptr_0', 'TCP_echo_Timestamp_2', 'IP_ihl_2', 'IP_proto_4', 'TCP_EOL_5', 'TCP_dataofs_6', 'TCP_Timestamp_3', 'TCP_Timestamp_5', 'interval_5_6', 'TCP_WScale_1', 'IP_chksum_5', 'TCP_window_0', 'TCP_EOL_0', 'TCP_reserved_4', 'IP_ihl_5', 'IP_id_6', 'IP_flags_5', 'TCP_dataofs_0', 'IP_frag_4', 'TCP_urgptr_3', 'TCP_EOL_6', 'IP_chksum_0', 'IP_tos_6', 'TCP_flags_1', 'IP_tos_1', 'TCP_MSS_4', 'TCP_window_5', 'TL_chksum_6', 'TCP_ack_0', 'TCP_dataofs_1', 'IP_len_3', 'TCP_WScale_2', 'IP_flags_1', 'TCP_SAck_2', 'TCP_dataofs_5', 'TCP_SAck_3', 'IP_id_1', 'TCP_dataofs_3', 'TL_chksum_0', 'TCP_window_3', 'TCP_echo_SAck_0', 'IP_flags_3', 'IP_version_4', 'TCP_SAck_0', 'IP_frag_5', 'IP_ttl_4', 'IP_ttl_5', 'IP_version_3', 'TCP_echo_Timestamp_1', 'IP_frag_3', 'TCP_echo_SAck_1', 'TCP_seq_0', 'TCP_WScale_4', 'IP_ihl_4', 'TCP_ack_2', 'TCP_flags_6', 'IP_ihl_1', 'TCP_echo_Timestamp_6', 'TCP_urgptr_5', 'TCP_SAckOK_5', 'interval_2_3', 'IP_id_3', 'TCP_WScale_6', 'IP_tos_0'}

# %%
field_set = {'IP_chksum', 'TCP_echo_SAck', 'IP_frag', 'TCP_WScale', 'TCP_reserved', 'TCP_echo_Timestamp', 'TL_chksum', 'TCP_flags', 'TCP_ack', 'IP_version', 'TCP_urgptr', 'TCP_Timestamp', 'TCP_MSS', 'TCP_SAck', 'IP_flags', 'IP_proto', 'TCP_SAckOK', 'TCP_EOL', 'TCP_seq', 'IP_tos', 'TCP_window', 'IP_len', 'IP_ttl', 'IP_id', 'IP_ihl', 'TCP_dataofs'}
ip_flags_map = {'DF': 1}
{'FA': 1, 'S': 2, 'FPA': 3, 'PA': 4, 'SA': 5, 'R': 6, 'A': 7, 'RA': 8}
ip_proto_map = {'tcp': 1, 'udp': 2, 'TCP': 1, 'UDP': 2}

# %%
pass_fields = ['src', 'dst', 'sport', 'dport']
map_features = {'TCP_flags', 'IP_flags', 'IP_proto'}
hex_features = {'IP_tos', 'IP_chksum', 'TL_chksum', 'UDP_chksum', 'TCP_chksum'}
equal_features = {'TCP_chksum', 'UDP_chksum', 'IPV6_tc', 'IPv6_version', 'IPv6_plen', 'IPv6_nh', 'IPv6_hlim'}

def hex2int(value):
    return int(value, 16)

def special_rules(field, value):
    if not value: # convert '' to 0
        return 0
    elif field == 'TCP_flags':     # convert flags to int
        return tcp_flags_map[value]
    elif field == 'IP_flags':     # convert flags to int
        return ip_flags_map[value]
    elif field == 'IP_proto': # convert protocol to int
        return ip_proto_map[value]
    
def equal_rules(field): # convert ipv6 fields name to ipv4 fields name
    if field == 'TCP_chksum' or field == 'UDP_chksum':
        return 'TL_chksum'
    elif field == 'IPv6_tc':
        return 'IP_tos'
    elif field == 'IPv6_version':
        return 'IP_version'
    elif field == 'IPv6_plen':
        return 'IP_len'
    elif field == 'IPv6_nh':
        return 'IP_proto'
    elif field == 'IPv6_hlim':
        return 'IP_ttl'
     
def packet2features(packet):
    protocol = None
    packet_key_val = {}
    for line in packet.show2(dump=True).split('\n'): 
        layer, _, key, val = get_key_val(line)
        if layer is not None:
                protocol = layer
        else:
            if key not in pass_fields and key is not None:   
                if key == 'options': # options is a list, there are two new fields
                    for option in eval(val):
                            if option[0] == 'NOP': # ignore NOP (No Operation)
                                continue
                            elif option[0] == 'Timestamp': # Timestamp and Echo are a pair, Echo is the second field
                                packet_key_val[f'{protocol}_{option[0]}'] = option[1][0]
                                packet_key_val[f'{protocol}_echo_{option[0]}'] = option[1][1]
                            elif option[0] == 'SAck': # The format of SAck is smiliar with timestamp and they are a pair, Echo is the second field
                                packet_key_val[f'{protocol}_{option[0]}'] = option[1][0]
                                packet_key_val[f'{protocol}_echo_{option[0]}'] = option[1][1]
                            elif option[0] == 'SAckOK': 
                                packet_key_val[f'{protocol}_{option[0]}'] = int(val == 1)
                            elif option[0] == 'EOL': # EOL is a flag, always 0
                                packet_key_val[f'{protocol}_{option[0]}'] = 0
                            else:
                                packet_key_val[f'{protocol}_{option[0]}'] = option[1]
                    continue   

                if f'{protocol}_{key}' in equal_features: # special rules for some fields
                    field = equal_rules(f'{protocol}_{key}')
                else:
                    field = f'{protocol}_{key}'


                if field in map_features: # special rules for some fields
                    packet_key_val[field] = special_rules(field, val)
                elif field in hex_features:
                    packet_key_val[field] = hex2int(val)
                else:
                    packet_key_val[field] = int(val) 
                
    return packet_key_val

def write2csv(type, data, label):
    os.makedirs(f'{output_path}/unclean', exist_ok=True)
    file_path = f'{output_path}/unclean/{type}.csv'

    if not os.path.isfile(file_path):
        with open(file_path, mode='w', newline='') as file:
            writer = csv.writer(file)
            print(list(flow_fields_set) + ['class'])
            writer.writerow(list(flow_fields_set) + ['class'])

    with open(file_path, mode='a', newline='') as file:
        writer = csv.writer(file)
        writer.writerow(data + [label])

def packet2flow_field(packet, id, flow_key_val):
    packet = clean_packet(packet)
    packet_key_val = packet2features(packet)

    for key, value in packet_key_val.items():
        flow_key_val[f'{key}_{id}'] = value

    return flow_key_val

def get_flow_interval(packet_timestamps, flow_key_val):
    for id in range(len(packet_timestamps) - 1):
        flow_key_val[f'interval_{id}_{id+1}'] = packet_timestamps[id+1] - packet_timestamps[id]
    return flow_key_val

# %%
# file/test/class/flow.pcap or file/train_val_split_0/{train/val}/class/flow.pcap

for type in os.listdir(dataset_path):
    logger.info(f'Processing {type}')

    if 'test' == type:
        for class_id, class_name in enumerate(os.listdir(f'{dataset_path}/{type}')):
            logger.info(f'Processing {type} {class_name}')
            for file_name in os.listdir(f'{dataset_path}/{type}/{class_name}'):
                flow_key_val = {}
                packet_timestamps = []
                with scapy.PcapReader(f'{dataset_path}/{type}/{class_name}/{file_name}') as packets:
                    for id, packet in enumerate(packets):
                        if id >= num_of_pkts:
                            break
                        flow_key_val = packet2flow_field(packet, id, flow_key_val)
                        packet_timestamps.append(packet.time)

                flow_key_val = get_flow_interval(packet_timestamps, flow_key_val)
                flow_array = [flow_key_val.get(key, 0) for key in flow_fields_set]
                write2csv(type, flow_array, class_name)
    else:
        for class_id, folder in enumerate(os.listdir(f'{dataset_path}/{type}')):
            logger.info(f'Processing {type} {folder}')
            for class_name in os.listdir(f'{dataset_path}/{type}/{folder}'):
                for file_name in os.listdir(f'{dataset_path}/{type}/{folder}/{class_name}'):
                    flow_key_val = {}
                    packet_timestamps = []
                    with scapy.PcapReader(f'{dataset_path}/{type}/{folder}/{class_name}/{file_name}') as packets:
                        for id, packet in enumerate(packets):
                            if id >= num_of_pkts:
                                break
                            flow_key_val = packet2flow_field(packet, id, flow_key_val)
                            packet_timestamps.append(packet.time)

                    flow_key_val = get_flow_interval(packet_timestamps, flow_key_val)
                    flow_array = [flow_key_val.get(key, 0) for key in flow_fields_set]
                    write2csv(f"{type}/{folder}", flow_array, class_name)
 
logger.info('Finished')
# Out:
# 2025-01-08 10:33:55,919 - root - INFO - Processing train_val_split_2
# 2025-01-08 10:33:55,920 - root - INFO - Processing train_val_split_2 train
# 2025-01-08 10:34:28,992 - root - INFO - Processing train_val_split_2 val
# 2025-01-08 10:34:45,523 - root - INFO - Processing train_val_split_0
# 2025-01-08 10:34:45,526 - root - INFO - Processing train_val_split_0 train
# 2025-01-08 10:35:18,692 - root - INFO - Processing train_val_split_0 val
# 2025-01-08 10:35:35,630 - root - INFO - Processing test
# 2025-01-08 10:35:35,631 - root - INFO - Processing test azureedge.net
# 2025-01-08 10:35:36,546 - root - INFO - Processing test hubspot.com
# 2025-01-08 10:35:37,022 - root - INFO - Processing test pinduoduo.com
# 2025-01-08 10:35:37,604 - root - INFO - Processing test jd.com
# 2025-01-08 10:35:38,189 - root - INFO - Processing test snapchat.com
# 2025-01-08 10:35:38,785 - root - INFO - Processing test qcloud.com
# 2025-01-08 10:35:39,381 - root - INFO - Processing test 51.la
# 2025-01-08 10:35:39,543 - root - INFO - Processing test arxiv.org
# 2025-01-08 10:35:40,056 - root - INFO - Processing test onlinedown.net
# 2025-01-08 10:35:40,306 - root - INFO - Processing test grammarly.com
# 2025-01-08 10:35:40,569 - root - INFO - Processing test cloudfront.net
# 2025-01-08 10:35:41,166 - root - INFO - Processing test teads.tv
# 2025-01-08 10:35:41,737 - root - INFO - Processing test office.net
# 2025-01-08 10:35:42,216 - root - INFO - Processing test huawei.com
# 2025-01-08 10:35:42,389 - root - INFO - Processing test researchgate.net
# 2025-01-08 10:35:42,879 - root - INFO - Processing test elsevier.com
# 2025-01-08 10:35:43,180 - root - INFO - Processing test instagram.com
# 2025-01-08 10:35:43,442 - root - INFO - Processing test microsoft.com
# 2025-01-08 10:35:44,017 - root - INFO - Processing test criteo.com
# 2025-01-08 10:35:44,590 - root - INFO - Processing test apple.com
# 2025-01-08 10:35:45,209 - root - INFO - Processing test codepen.io
# 2025-01-08 10:35:45,601 - root - INFO - Processing test wikimedia.org
# 2025-01-08 10:35:46,024 - root - INFO - Processing test overleaf.com
# 2025-01-08 10:35:46,625 - root - INFO - Processing test dailymotion.com
# 2025-01-08 10:35:47,252 - root - INFO - Processing test 163.com
# 2025-01-08 10:35:47,849 - root - INFO - Processing test semanticscholar.org
# 2025-01-08 10:35:48,066 - root - INFO - Processing test booking.com
# 2025-01-08 10:35:48,277 - root - INFO - Processing test sohu.com
# 2025-01-08 10:35:48,860 - root - INFO - Processing test twimg.com
# 2025-01-08 10:35:49,468 - root - INFO - Processing test github.com
# 2025-01-08 10:35:50,065 - root - INFO - Processing test nvidia.com
# 2025-01-08 10:35:50,536 - root - INFO - Processing test mozilla.org
# 2025-01-08 10:35:51,126 - root - INFO - Processing test cisco.com
# 2025-01-08 10:35:51,714 - root - INFO - Processing test alipay.com
# 2025-01-08 10:35:52,262 - root - INFO - Processing test digitaloceanspaces.com
# 2025-01-08 10:35:52,880 - root - INFO - Processing test amazonaws.com
# 2025-01-08 10:35:53,447 - root - INFO - Processing test biligame.com
# 2025-01-08 10:35:54,036 - root - INFO - Processing test icloud.com
# 2025-01-08 10:35:54,642 - root - INFO - Processing test cloudflare.com
# 2025-01-08 10:35:55,186 - root - INFO - Processing test statcounter.com
# 2025-01-08 10:35:55,498 - root - INFO - Processing test alibaba.com
# 2025-01-08 10:35:55,859 - root - INFO - Processing test unity3d.com
# 2025-01-08 10:35:56,443 - root - INFO - Processing test taboola.com
# 2025-01-08 10:35:57,012 - root - INFO - Processing test notion.so
# 2025-01-08 10:35:57,584 - root - INFO - Processing test spring.io
# 2025-01-08 10:35:57,781 - root - INFO - Processing test amap.com
# 2025-01-08 10:35:58,381 - root - INFO - Processing test vivo.com.cn
# 2025-01-08 10:35:58,984 - root - INFO - Processing test acm.org
# 2025-01-08 10:35:59,353 - root - INFO - Processing test guancha.cn
# 2025-01-08 10:35:59,939 - root - INFO - Processing test atlassian.net
# 2025-01-08 10:36:00,129 - root - INFO - Processing test nike.com
# 2025-01-08 10:36:00,739 - root - INFO - Processing test huanqiu.com
# 2025-01-08 10:36:01,211 - root - INFO - Processing test asus.com
# 2025-01-08 10:36:01,689 - root - INFO - Processing test python.org
# 2025-01-08 10:36:02,306 - root - INFO - Processing test thepaper.cn
# 2025-01-08 10:36:02,476 - root - INFO - Processing test goat.com
# 2025-01-08 10:36:02,636 - root - INFO - Processing test ibm.com
# 2025-01-08 10:36:02,854 - root - INFO - Processing test ximalaya.com
# 2025-01-08 10:36:03,253 - root - INFO - Processing test facebook.com
# 2025-01-08 10:36:03,862 - root - INFO - Processing test google.com
# 2025-01-08 10:36:04,434 - root - INFO - Processing test media.net
# 2025-01-08 10:36:04,932 - root - INFO - Processing test chia.net
# 2025-01-08 10:36:04,953 - root - INFO - Processing test oracle.com
# 2025-01-08 10:36:05,170 - root - INFO - Processing test leetcode-cn.com
# 2025-01-08 10:36:05,764 - root - INFO - Processing test wp.com
# 2025-01-08 10:36:06,281 - root - INFO - Processing test ctrip.com
# 2025-01-08 10:36:06,884 - root - INFO - Processing test yahoo.com
# 2025-01-08 10:36:07,488 - root - INFO - Processing test yandex.ru
# 2025-01-08 10:36:08,075 - root - INFO - Processing test kugou.com
# 2025-01-08 10:36:08,664 - root - INFO - Processing test deepl.com
# 2025-01-08 10:36:08,846 - root - INFO - Processing test paypal.com
# 2025-01-08 10:36:09,017 - root - INFO - Processing test gmail.com
# 2025-01-08 10:36:09,629 - root - INFO - Processing test zhihu.com
# 2025-01-08 10:36:10,218 - root - INFO - Processing test 51cto.com
# 2025-01-08 10:36:10,760 - root - INFO - Processing test sina.com.cn
# 2025-01-08 10:36:11,362 - root - INFO - Processing test msn.com
# 2025-01-08 10:36:11,925 - root - INFO - Processing test vmware.com
# 2025-01-08 10:36:12,170 - root - INFO - Processing test ggpht.com
# 2025-01-08 10:36:12,785 - root - INFO - Processing test vk.com
# 2025-01-08 10:36:13,058 - root - INFO - Processing test ieee.org
# 2025-01-08 10:36:13,656 - root - INFO - Processing test ampproject.org
# 2025-01-08 10:36:14,246 - root - INFO - Processing test xiaomi.com
# 2025-01-08 10:36:14,501 - root - INFO - Processing test baidu.com
# 2025-01-08 10:36:15,094 - root - INFO - Processing test tiktok.com
# 2025-01-08 10:36:15,250 - root - INFO - Processing test wikipedia.org
# 2025-01-08 10:36:15,641 - root - INFO - Processing test walmart.com
# 2025-01-08 10:36:16,171 - root - INFO - Processing test toutiao.com
# 2025-01-08 10:36:16,760 - root - INFO - Processing test cnblogs.com
# 2025-01-08 10:36:17,379 - root - INFO - Processing test weibo.com
# 2025-01-08 10:36:18,001 - root - INFO - Processing test bilibili.com
# 2025-01-08 10:36:18,603 - root - INFO - Processing test runoob.com
# 2025-01-08 10:36:19,139 - root - INFO - Processing test steampowered.com
# 2025-01-08 10:36:19,707 - root - INFO - Processing test outbrain.com
# 2025-01-08 10:36:19,939 - root - INFO - Processing test qq.com
# 2025-01-08 10:36:20,540 - root - INFO - Processing test gravatar.com
# 2025-01-08 10:36:21,130 - root - INFO - Processing test eastmoney.com
# 2025-01-08 10:36:21,749 - root - INFO - Processing test feishu.cn
# 2025-01-08 10:36:22,341 - root - INFO - Processing test v2ex.com
# 2025-01-08 10:36:22,502 - root - INFO - Processing test chinatax.gov.cn
# 2025-01-08 10:36:23,122 - root - INFO - Processing test opera.com
# 2025-01-08 10:36:23,579 - root - INFO - Processing test naver.com
# 2025-01-08 10:36:24,194 - root - INFO - Processing test alicdn.com
# 2025-01-08 10:36:24,786 - root - INFO - Processing test youtube.com
# 2025-01-08 10:36:25,406 - root - INFO - Processing test mi.com
# 2025-01-08 10:36:25,603 - root - INFO - Processing test smzdm.com
# 2025-01-08 10:36:26,215 - root - INFO - Processing test iqiyi.com
# 2025-01-08 10:36:26,811 - root - INFO - Processing test jb51.net
# 2025-01-08 10:36:27,372 - root - INFO - Processing test adobe.com
# 2025-01-08 10:36:27,654 - root - INFO - Processing test springer.com
# 2025-01-08 10:36:27,999 - root - INFO - Processing test duckduckgo.com
# 2025-01-08 10:36:28,567 - root - INFO - Processing test huya.com
# 2025-01-08 10:36:29,172 - root - INFO - Processing test crazyegg.com
# 2025-01-08 10:36:29,357 - root - INFO - Processing test gitlab.com
# 2025-01-08 10:36:29,677 - root - INFO - Processing test squarespace.com
# 2025-01-08 10:36:29,820 - root - INFO - Processing test yy.com
# 2025-01-08 10:36:30,440 - root - INFO - Processing test twitter.com
# 2025-01-08 10:36:30,803 - root - INFO - Processing test netflix.com
# 2025-01-08 10:36:31,328 - root - INFO - Processing test sciencedirect.com
# 2025-01-08 10:36:31,510 - root - INFO - Processing test eastday.com
# 2025-01-08 10:36:31,720 - root - INFO - Processing test t.co
# 2025-01-08 10:36:32,333 - root - INFO - Processing train_val_split_1
# 2025-01-08 10:36:32,335 - root - INFO - Processing train_val_split_1 train
# 2025-01-08 10:37:06,632 - root - INFO - Processing train_val_split_1 val
# 2025-01-08 10:37:23,654 - root - INFO - Finished

# %% [markdown]
# # for data clean
#
# normalization each row
#
# **train and test should use same distribution of normalization**

# %% [markdown]
# ### For USTCTFC2016
# field_set = {'TCP_window', 'TCP_chksum', 'TCP_reserved', 'TCP_ack', 'TCP_echo_SAck', 'TCP_flags', 'TCP_SAckOK', 'IP_id', 'IP_proto', 'IP_len', 'TCP_seq', 'TCP_WScale', 'TCP_EOL', 'UDP_chksum', 'UDP_len', 'TCP_dataofs', 'IP_version', 'TCP_SAck', 'TCP_MSS', 'IP_chksum', 'IP_flags', 'TCP_urgptr', 'IP_frag', 'IP_ttl', 'TCP_echo_Timestamp', 'TCP_Timestamp', 'IP_ihl', 'IP_tos'}
#
# ip_flags_map = {'DF': 1}
# tcp_flags_map = {'PA': 1, 'S': 2, 'FA': 3, 'A': 4, 'FPA': 5, 'R': 6, 'SA': 7, 'RA': 8}
# ip_proto_map = {'tcp': 1, 'udp': 2}
#
# normalize_set = {'TCP_window', 'TCP_chksum', 'TCP_ack', 'TCP_echo_SAck', 'IP_id', 'IP_len', 'TCP_seq', 'UDP_chksum', 'UDP_len','TCP_SAck', 'TCP_MSS', 'IP_chksum', 'TCP_echo_Timestamp', 'TCP_Timestamp', 'IP_tos'}

# %%
import pandas as pd
import numpy as np

normalize_set = {'TCP_window', 'TCP_chksum', 'TCP_ack', 'TCP_echo_SAck', 'IP_id', 'IP_len', 'TCP_seq', 'UDP_chksum', 'UDP_len','TCP_SAck', 'TCP_MSS', 'IP_chksum', 'TCP_echo_Timestamp', 'TCP_Timestamp', 'IP_tos'}
types = ['train_val_split_0', 'train_val_split_1', 'train_val_split_2', 'test.csv']

def log_normalize(value):
    return np.log1p(value)

for type in types:
    if type == 'test.csv':
        df = pd.read_csv(f'{output_path}/unclean/{type}')
        for field in normalize_set:
            for column in df.columns:
                if field in column:
                    df[column] = df[column].apply(log_normalize)
        df.to_csv(f'{output_path}/normalized/{type}', index=False)
    else:
        for file in os.listdir(f'{output_path}/unclean/{type}'):
            df = pd.read_csv(f'{output_path}/unclean/{type}/{file}')
            for field in normalize_set:
                for column in df.columns:
                    if field in column:
                        df[column] = df[column].apply(log_normalize)
            df.to_csv(f'{output_path}/normalized/{type}/{file}', index=False)
# Out:
# train_val_split_0 train.csv
# train_val_split_0 val.csv
# train_val_split_1 train.csv
# train_val_split_1 val.csv
# train_val_split_2 train.csv
# train_val_split_2 val.csv

# %% [markdown]
# ### For TLS
# field_set = {'TCP_window', 'TCP_chksum', 'TCP_reserved', 'TCP_ack', 'TCP_echo_SAck', 'TCP_flags', 'IP_id', 'IP_proto', 'IP_len', 'TCP_seq', 'TCP_dataofs', 'IP_version', 'TCP_SAck', 'IP_chksum', 'TCP_urgptr', 'IP_flags', 'IP_frag', 'IP_ttl', 'TCP_echo_Timestamp', 'TCP_Timestamp', 'IP_ihl', 'IP_tos'}
#
# ip_flags_map = {'DF': 1}
# tcp_flags_map = {'PA': 1, 'FA': 2, 'A': 3, 'FPA': 4, 'R': 5, 'PAC': 6, 'RA': 7}
# ip_proto_map = {'tcp': 1, 'udp': 2}
#
# normalize_set = {'TCP_window', 'TCP_chksum', 'TCP_ack', 'TCP_echo_SAck', 'IP_id', 'IP_len', 'TCP_seq', 'TCP_SAck', 'IP_chksum','TCP_echo_Timestamp', 'TCP_Timestamp', 'IP_tos'}

# %%
import pandas as pd
import numpy as np

normalize_set = {'TCP_window', 'TCP_chksum', 'TCP_ack', 'TCP_echo_SAck', 'IP_id', 'IP_len', 'TCP_seq', 'TCP_SAck', 'IP_chksum','TCP_echo_Timestamp', 'TCP_Timestamp', 'IP_tos'}
types = ['train_val_split_0', 'train_val_split_1', 'train_val_split_2', 'test.csv']

def log_normalize(value):
    return np.log1p(value)

for type in types:
    if type == 'test.csv':
        df = pd.read_csv(f'{output_path}/unclean/{type}')
        for field in normalize_set:
            for column in df.columns:
                if field in column:
                    df[column] = df[column].apply(log_normalize)
        df.to_csv(f'{output_path}/normalized/{type}', index=False)
    else:
        for file in os.listdir(f'{output_path}/unclean/{type}'):
            print(type, file)
            df = pd.read_csv(f'{output_path}/unclean/{type}/{file}')

            for field in normalize_set:
                for column in df.columns:
                    if field in column:
                        df[column] = df[column].apply(log_normalize)
            df.to_csv(f'{output_path}/normalized/{type}/{file}', index=False)
# Out:
# train_val_split_0 train.csv
# train_val_split_0 val.csv
# train_val_split_1 train.csv
# train_val_split_1 val.csv
# train_val_split_2 train.csv
# train_val_split_2 val.csv

# %% [markdown]
# # For VPN
# field_set = {'TCP_MSS', 'TCP_seq', 'IP_id', 'IP_chksum', 'TCP_urgptr', 'UDP_len', 'TCP_echo_SAck', 'UDP_chksum', 'TCP_echo_Timestamp', 'IP_version', 'TCP_window', 'IP_len', 'IP_flags', 'TCP_SAck', 'TCP_WScale', 'TCP_EOL', 'TCP_ack', 'TCP_chksum', 'IP_frag', 'TCP_flags', 'IP_ttl', 'IP_ihl', 'TCP_dataofs', 'TCP_Timestamp', 'IP_proto', 'IP_tos', 'TCP_reserved', 'TCP_SAckOK'}
#
# ip_flags_map = {'DF': 1}
# tcp_flags_map = {'R': 1, 'SA': 2, 'RA': 3, 'S': 4, 'PA': 5, 'FPA': 6, 'A': 7, 'FA': 8}
# ip_proto_map = {'tcp': 1, 'udp': 2}
#
#  normalize_set = {'TCP_MSS', 'TCP_seq', 'IP_id', 'IP_chksum','UDP_len', 'TCP_echo_SAck', 'UDP_chksum', 'TCP_echo_Timestamp','TCP_window', 'IP_len',  'TCP_SAck','TCP_ack', 'TCP_chksum', 'TCP_Timestamp', 'IP_tos'}

# %%
import pandas as pd
import numpy as np

normalize_set = {'TL_chksum', 'TCP_MSS', 'TCP_seq', 'IP_id', 'IP_chksum', 'UDP_len', 'TCP_echo_SAck', 'UDP_chksum', 'TCP_echo_Timestamp','TCP_window', 'IP_len',  'TCP_SAck','TCP_ack', 'TCP_chksum', 'TCP_Timestamp', 'IP_tos'}
types = ['train_val_split_0', 'train_val_split_1', 'train_val_split_2', 'test.csv']

def log_normalize(value):
    return np.log1p(value)

for type in types:
    if type == 'test.csv':
        df = pd.read_csv(f'{output_path}/unclean/{type}')
        for field in normalize_set:
            for column in df.columns:
                if field in column:
                    df[column] = df[column].apply(log_normalize)
        df.to_csv(f'{output_path}/normalized/{type}', index=False)
    else:
        for file in os.listdir(f'{output_path}/unclean/{type}'):
            df = pd.read_csv(f'{output_path}/unclean/{type}/{file}')
            for field in normalize_set:
                for column in df.columns:
                    if field in column:
                        df[column] = df[column].apply(log_normalize)
            df.to_csv(f'{output_path}/normalized/{type}/{file}', index=False)
