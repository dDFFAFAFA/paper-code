# %% [markdown]
# # Description
# process pcap data for get traditional baseline
# label.pcap -> feature alignment Matrix/csv

# %%
import os
import logging
import scapy.all as scapy
from multiprocessing import Pool, cpu_count
import csv
import pandas as pd

os.chdir('LLM4Traffic/code/Traditional')

logging.basicConfig(       
    level=logging.INFO,            
    format='%(asctime)s - %(name)s - %(levelname)s - %(message)s',  
    handlers=[
        logging.FileHandler('logs/feature_alignment.log', mode='w'),  
        logging.StreamHandler()          
    ],
    force=True
)

logger = logging.getLogger()

# %%
dataset_path = 'LLM4Traffic/pipeline/polishednsLen/tls'
output_path = 'LLM4Traffic/code/Traditional/datasets/polishednsLen/tls'

# %%
def get_key_val(line):
    layer = None
    sublayer = None
    key = None
    val = None

    if '###' in line:             
        if '|###' in line:                
            sublayer = line.strip('|#[] ')  
            print(f'sublayer ### {sublayer}')    
        else:                
            layer = line.strip('#[] ')      

    if '=' in line:            
        if '|' in line and 'sublayer' in locals():                
            key, val = line.strip('| ').split('=', 1)        
            key, val = key.strip(), val.strip('\' ')          
            print(f'sublayer ||| {sublayer}')  
        else:                 
            key, val = line.split('=', 1)   
            key, val = key.strip(), val.strip('\' ')    
            
    return layer, sublayer, key, val

def clean_packet(packet):
    if packet.haslayer(scapy.Ether):
        packet = packet[scapy.Ether].payload

    if packet.haslayer(scapy.IP) or packet.haslayer('IPv6'):
        if packet.haslayer(scapy.UDP):
            packet[scapy.UDP].remove_payload()   
        if packet.haslayer(scapy.TCP):
            packet[scapy.TCP].remove_payload()    
    
    return packet

# get how many features/ip flags/tcp flags/.. in the dataset

pass_fields = ['src', 'dst', 'sport', 'dport'] # ignore these fields
field_set = set()
ip_flags_set = set()
tcp_flags_set = set()

def get_all_features(packet):
    protocol = None
    for line in packet.show2(dump=True).split('\n'): 
        layer, sub, key, val = get_key_val(line)

        if layer is not None:
                protocol = layer
        else:
            if key not in pass_fields and key is not None:   
                if key == 'options': # options is a list, there are two new fields
                    if len(val) == 0:
                        continue
                    for option in eval(val):
                            if option[0] == 'NOP': # ignore NOP (No Operation)
                                continue
                            elif option[0] == 'Timestamp': # Timestamp and Echo are a pair
                                field_set.add(f'{protocol}_{option[0]}')
                                field_set.add(f'{protocol}_echo_{option[0]}')
                            elif option[0] == 'SAck': # SAckOK is a flag
                                field_set.add(f'{protocol}_{option[0]}')
                                field_set.add(f'{protocol}_echo_{option[0]}')
                                continue

                            field_set.add(f'{protocol}_{option[0]}')
                    continue     

                # distinguish ip flags and tcp flags
                if key == 'flags': 
                    if protocol == 'IP':
                        ip_flags_set.add(f'{val}')
                    elif protocol == 'TCP':
                        tcp_flags_set.add(f'{val}')  

                if key == 'chksum' and protocol in ['TCP', 'UDP']:   # merge tcp and udp checksum
                    field_set.add('TL_chksum')
                elif f'{protocol}_{key}'== 'IP_tos' or f'{protocol}_{key}' == 'IPv6_tc': # merge tos and traffic class
                    field_set.add('IP_tos')
                elif key == 'version': # merge ip version and ipv6 version
                    field_set.add('IP_version')
                elif f'{protocol}_{key}'== 'IP_ttl' or f'{protocol}_{key}' == 'IPv6_hlim': # merge ttl and hot limit
                    field_set.add('IP_ttl')
                elif f'{protocol}_{key}'== 'IP_len' or f'{protocol}_{key}' == 'IPv6_plen': # merge len and payload len
                    field_set.add('IP_len')
                elif f'{protocol}_{key}'== 'IP_proto' or f'{protocol}_{key}' == 'IPv6_nh': # merge proto and next header
                    field_set.add('IP_proto')
                else:
                    field_set.add(f'{protocol}_{key}')

    return field_set

# %%
# file/{test.pcap} or file/{train_val_split_0}/{train.pcap}
for type in os.listdir(dataset_path):
    logger.info(f'Processing {type}')

    if 'test' in type:
        if 'pcap' in type:
            packets =  scapy.PcapReader(f'{dataset_path}/{type}')
            for id, packet in enumerate(packets):
                # only require ip header and transportaion layer
                packet = clean_packet(packet)
                get_all_features(packet)
        continue

    for class_id, file_name in enumerate(os.listdir(f'{dataset_path}/{type}')):
        logger.info(f'Processing {type} {file_name}')
        if 'pcap' not in file_name:
            continue

        packets =  scapy.PcapReader(f'{dataset_path}/{type}/{file_name}')
        for id, packet in enumerate(packets):
            # only require ip header and transportaion layer
            packet = clean_packet(packet)
            get_all_features(packet)

print(field_set)
print(ip_flags_set)
print(tcp_flags_set)
print()

# %%
# file/test/{test.pcap} or file/train_val_split_0/{train/val}/.pcap
for type in os.listdir(dataset_path):
    logger.info(f'Processing {type}')

    if type == 'test':
        for class_id, file_name in enumerate(os.listdir(f'{dataset_path}/{type}')):
            if 'pcap' in file_name:
                logger.info(f'Processing {type} {file_name}')

                packets =  scapy.PcapReader(f'{dataset_path}/{type}/{file_name}')
                for id, packet in enumerate(packets):
                    # only require ip header and transportaion layer
                    packet = clean_packet(packet)
                    get_all_features(packet)
                
    else:
        for class_id, folder in enumerate(os.listdir(f'{dataset_path}/{type}')):
            logger.info(f'Processing {type} {folder}')
            
            for file_name in os.listdir(f'{dataset_path}/{type}/{folder}'):
                logger.info(f'Processing {type} {folder} {file_name}')
                if 'pcap' in file_name:
                    packets =  scapy.PcapReader(f'{dataset_path}/{type}/{folder}/{file_name}')
                    for id, packet in enumerate(packets):
                        
                        # only require ip header and transportaion layer
                        packet = clean_packet(packet)
                        get_all_features(packet)
                        
                
                    
print(field_set)
print(ip_flags_set)
print(tcp_flags_set)
print()
# Out:
# 2025-01-23 14:24:44,116 - root - INFO - Processing train_val_split_2
# 2025-01-23 14:24:44,138 - root - INFO - Processing train_val_split_2 train
# 2025-01-23 14:24:44,152 - root - INFO - Processing train_val_split_2 train 51cto.pcap
# 2025-01-23 14:24:44,786 - root - INFO - Processing train_val_split_2 train sina.pcap
# 2025-01-23 14:24:45,360 - root - INFO - Processing train_val_split_2 train overleaf.pcap
# 2025-01-23 14:24:45,926 - root - INFO - Processing train_val_split_2 train youtube.pcap
# 2025-01-23 14:24:46,442 - root - INFO - Processing train_val_split_2 train alibaba.pcap
# 2025-01-23 14:24:46,840 - root - INFO - Processing train_val_split_2 train instagram.pcap
# 2025-01-23 14:24:47,363 - root - INFO - Processing train_val_split_2 train iqiyi.pcap
# 2025-01-23 14:24:47,865 - root - INFO - Processing train_val_split_2 train ibm.pcap
# 2025-01-23 14:24:48,405 - root - INFO - Processing train_val_split_2 train dailymotion.pcap
# 2025-01-23 14:24:49,010 - root - INFO - Processing train_val_split_2 train smzdm.pcap
# 2025-01-23 14:24:49,670 - root - INFO - Processing train_val_split_2 train gravatar.pcap
# 2025-01-23 14:24:50,204 - root - INFO - Processing train_val_split_2 train microsoft.pcap
# 2025-01-23 14:24:50,737 - root - INFO - Processing train_val_split_2 train cloudfront.pcap
# 2025-01-23 14:24:51,251 - root - INFO - Processing train_val_split_2 train jb51.pcap
# 2025-01-23 14:24:51,857 - root - INFO - Processing train_val_split_2 train pinduoduo.pcap
# 2025-01-23 14:24:52,416 - root - INFO - Processing train_val_split_2 train vmware.pcap
# 2025-01-23 14:24:53,053 - root - INFO - Processing train_val_split_2 train wikimedia.pcap
# 2025-01-23 14:24:53,646 - root - INFO - Processing train_val_split_2 train sohu.pcap
# 2025-01-23 14:24:54,213 - root - INFO - Processing train_val_split_2 train apple.pcap
# 2025-01-23 14:24:54,785 - root - INFO - Processing train_val_split_2 train twimg.pcap
# 2025-01-23 14:24:55,388 - root - INFO - Processing train_val_split_2 train onlinedown.pcap
# 2025-01-23 14:24:56,002 - root - INFO - Processing train_val_split_2 train booking.pcap
# 2025-01-23 14:24:56,493 - root - INFO - Processing train_val_split_2 train digitaloceanspaces.pcap
# 2025-01-23 14:24:56,921 - root - INFO - Processing train_val_split_2 train netflix.pcap
# 2025-01-23 14:24:57,405 - root - INFO - Processing train_val_split_2 train gitlab.pcap
# 2025-01-23 14:24:57,991 - root - INFO - Processing train_val_split_2 train criteo.pcap
# 2025-01-23 14:24:58,470 - root - INFO - Processing train_val_split_2 train v2ex.pcap
# 2025-01-23 14:24:59,148 - root - INFO - Processing train_val_split_2 train icloud.pcap
# 2025-01-23 14:24:59,627 - root - INFO - Processing train_val_split_2 train yahoo.pcap
# 2025-01-23 14:25:00,210 - root - INFO - Processing train_val_split_2 train runoob.pcap
# 2025-01-23 14:25:00,790 - root - INFO - Processing train_val_split_2 train sciencedirect.pcap
# 2025-01-23 14:25:01,379 - root - INFO - Processing train_val_split_2 train huya.pcap
# 2025-01-23 14:25:01,852 - root - INFO - Processing train_val_split_2 train xiaomi.pcap
# 2025-01-23 14:25:02,452 - root - INFO - Processing train_val_split_2 train huanqiu.pcap
# 2025-01-23 14:25:03,013 - root - INFO - Processing train_val_split_2 train eastmoney.pcap
# 2025-01-23 14:25:03,605 - root - INFO - Processing train_val_split_2 train elsevier.pcap
# 2025-01-23 14:25:04,068 - root - INFO - Processing train_val_split_2 train office.pcap
# 2025-01-23 14:25:04,647 - root - INFO - Processing train_val_split_2 train 51.pcap
# 2025-01-23 14:25:05,188 - root - INFO - Processing train_val_split_2 train semanticscholar.pcap
# 2025-01-23 14:25:05,790 - root - INFO - Processing train_val_split_2 train kugou.pcap
# 2025-01-23 14:25:06,317 - root - INFO - Processing train_val_split_2 train ximalaya.pcap
# 2025-01-23 14:25:06,747 - root - INFO - Processing train_val_split_2 train naver.pcap
# 2025-01-23 14:25:07,264 - root - INFO - Processing train_val_split_2 train cisco.pcap
# 2025-01-23 14:25:07,756 - root - INFO - Processing train_val_split_2 train mi.pcap
# 2025-01-23 14:25:08,331 - root - INFO - Processing train_val_split_2 train leetcode-cn.pcap
# 2025-01-23 14:25:08,887 - root - INFO - Processing train_val_split_2 train arxiv.pcap
# 2025-01-23 14:25:09,426 - root - INFO - Processing train_val_split_2 train mozilla.pcap
# 2025-01-23 14:25:09,966 - root - INFO - Processing train_val_split_2 train walmart.pcap
# 2025-01-23 14:25:10,302 - root - INFO - Processing train_val_split_2 train feishu.pcap
# 2025-01-23 14:25:10,805 - root - INFO - Processing train_val_split_2 train wikipedia.pcap
# 2025-01-23 14:25:11,370 - root - INFO - Processing train_val_split_2 train vk.pcap
# 2025-01-23 14:25:11,912 - root - INFO - Processing train_val_split_2 train spring.pcap
# 2025-01-23 14:25:12,532 - root - INFO - Processing train_val_split_2 train notion.pcap
# 2025-01-23 14:25:12,993 - root - INFO - Processing train_val_split_2 train grammarly.pcap
# 2025-01-23 14:25:13,615 - root - INFO - Processing train_val_split_2 train nvidia.pcap
# 2025-01-23 14:25:14,211 - root - INFO - Processing train_val_split_2 train taboola.pcap
# 2025-01-23 14:25:14,778 - root - INFO - Processing train_val_split_2 train yy.pcap
# 2025-01-23 14:25:15,302 - root - INFO - Processing train_val_split_2 train atlassian.pcap
# 2025-01-23 14:25:15,786 - root - INFO - Processing train_val_split_2 train toutiao.pcap
# 2025-01-23 14:25:16,323 - root - INFO - Processing train_val_split_2 train amap.pcap
# 2025-01-23 14:25:16,663 - root - INFO - Processing train_val_split_2 train qq.pcap
# 2025-01-23 14:25:17,169 - root - INFO - Processing train_val_split_2 train bilibili.pcap
# 2025-01-23 14:25:17,630 - root - INFO - Processing train_val_split_2 train acm.pcap
# 2025-01-23 14:25:18,285 - root - INFO - Processing train_val_split_2 train adobe.pcap
# 2025-01-23 14:25:18,819 - root - INFO - Processing train_val_split_2 train google.pcap
# 2025-01-23 14:25:19,334 - root - INFO - Processing train_val_split_2 train chinatax.pcap
# 2025-01-23 14:25:19,846 - root - INFO - Processing train_val_split_2 train baidu.pcap
# 2025-01-23 14:25:20,404 - root - INFO - Processing train_val_split_2 train paypal.pcap
# 2025-01-23 14:25:20,959 - root - INFO - Processing train_val_split_2 train yandex.pcap
# 2025-01-23 14:25:21,494 - root - INFO - Processing train_val_split_2 train oracle.pcap
# 2025-01-23 14:25:22,076 - root - INFO - Processing train_val_split_2 train ctrip.pcap
# 2025-01-23 14:25:22,628 - root - INFO - Processing train_val_split_2 train codepen.pcap
# 2025-01-23 14:25:23,239 - root - INFO - Processing train_val_split_2 train cnblogs.pcap
# 2025-01-23 14:25:23,816 - root - INFO - Processing train_val_split_2 train steampowered.pcap
# 2025-01-23 14:25:24,337 - root - INFO - Processing train_val_split_2 train weibo.pcap
# 2025-01-23 14:25:24,919 - root - INFO - Processing train_val_split_2 train squarespace.pcap
# 2025-01-23 14:25:25,460 - root - INFO - Processing train_val_split_2 train zhihu.pcap
# 2025-01-23 14:25:25,984 - root - INFO - Processing train_val_split_2 train jd.pcap
# 2025-01-23 14:25:26,533 - root - INFO - Processing train_val_split_2 train t.pcap
# 2025-01-23 14:25:26,966 - root - INFO - Processing train_val_split_2 train biligame.pcap
# 2025-01-23 14:25:27,437 - root - INFO - Processing train_val_split_2 train eastday.pcap
# 2025-01-23 14:25:28,008 - root - INFO - Processing train_val_split_2 train qcloud.pcap
# 2025-01-23 14:25:28,408 - root - INFO - Processing train_val_split_2 train alipay.pcap
# 2025-01-23 14:25:28,923 - root - INFO - Processing train_val_split_2 train goat.pcap
# 2025-01-23 14:25:29,547 - root - INFO - Processing train_val_split_2 train guancha.pcap
# 2025-01-23 14:25:30,065 - root - INFO - Processing train_val_split_2 train gmail.pcap
# 2025-01-23 14:25:30,540 - root - INFO - Processing train_val_split_2 train python.pcap
# 2025-01-23 14:25:30,992 - root - INFO - Processing train_val_split_2 train chia.pcap
# 2025-01-23 14:25:31,619 - root - INFO - Processing train_val_split_2 train springer.pcap
# 2025-01-23 14:25:32,182 - root - INFO - Processing train_val_split_2 train github.pcap
# 2025-01-23 14:25:32,669 - root - INFO - Processing train_val_split_2 train 163.pcap
# 2025-01-23 14:25:33,238 - root - INFO - Processing train_val_split_2 train crazyegg.pcap
# 2025-01-23 14:25:33,855 - root - INFO - Processing train_val_split_2 train thepaper.pcap
# 2025-01-23 14:25:34,516 - root - INFO - Processing train_val_split_2 train ampproject.pcap
# 2025-01-23 14:25:35,068 - root - INFO - Processing train_val_split_2 train vivo.pcap
# 2025-01-23 14:25:35,530 - root - INFO - Processing train_val_split_2 train tiktok.pcap
# 2025-01-23 14:25:36,069 - root - INFO - Processing train_val_split_2 train wp.pcap
# 2025-01-23 14:25:36,641 - root - INFO - Processing train_val_split_2 train researchgate.pcap
# 2025-01-23 14:25:37,288 - root - INFO - Processing train_val_split_2 train asus.pcap
# 2025-01-23 14:25:37,734 - root - INFO - Processing train_val_split_2 train snapchat.pcap
# 2025-01-23 14:25:38,222 - root - INFO - Processing train_val_split_2 train huawei.pcap
# 2025-01-23 14:25:38,920 - root - INFO - Processing train_val_split_2 train ggpht.pcap
# 2025-01-23 14:25:39,449 - root - INFO - Processing train_val_split_2 train duckduckgo.pcap
# 2025-01-23 14:25:39,967 - root - INFO - Processing train_val_split_2 train unity3d.pcap
# 2025-01-23 14:25:40,422 - root - INFO - Processing train_val_split_2 train deepl.pcap
# 2025-01-23 14:25:41,017 - root - INFO - Processing train_val_split_2 train nike.pcap
# 2025-01-23 14:25:41,637 - root - INFO - Processing train_val_split_2 train alicdn.pcap
# 2025-01-23 14:25:42,186 - root - INFO - Processing train_val_split_2 train opera.pcap
# 2025-01-23 14:25:42,661 - root - INFO - Processing train_val_split_2 train cloudflare.pcap
# 2025-01-23 14:25:43,233 - root - INFO - Processing train_val_split_2 train twitter.pcap
# 2025-01-23 14:25:43,773 - root - INFO - Processing train_val_split_2 train facebook.pcap
# 2025-01-23 14:25:44,329 - root - INFO - Processing train_val_split_2 train statcounter.pcap
# 2025-01-23 14:25:44,825 - root - INFO - Processing train_val_split_2 train azureedge.pcap
# 2025-01-23 14:25:45,368 - root - INFO - Processing train_val_split_2 train msn.pcap
# 2025-01-23 14:25:45,807 - root - INFO - Processing train_val_split_2 train media.pcap
# 2025-01-23 14:25:46,325 - root - INFO - Processing train_val_split_2 train amazonaws.pcap
# 2025-01-23 14:25:46,842 - root - INFO - Processing train_val_split_2 train hubspot.pcap
# 2025-01-23 14:25:47,333 - root - INFO - Processing train_val_split_2 train ieee.pcap
# 2025-01-23 14:25:47,795 - root - INFO - Processing train_val_split_2 train outbrain.pcap
# 2025-01-23 14:25:48,322 - root - INFO - Processing train_val_split_2 train teads.pcap
# 2025-01-23 14:25:48,767 - root - INFO - Processing train_val_split_2 val
# 2025-01-23 14:25:48,773 - root - INFO - Processing train_val_split_2 val 51cto.pcap
# 2025-01-23 14:25:48,826 - root - INFO - Processing train_val_split_2 val sina.pcap
# 2025-01-23 14:25:48,922 - root - INFO - Processing train_val_split_2 val overleaf.pcap
# 2025-01-23 14:25:48,988 - root - INFO - Processing train_val_split_2 val youtube.pcap
# 2025-01-23 14:25:49,031 - root - INFO - Processing train_val_split_2 val alibaba.pcap
# 2025-01-23 14:25:49,074 - root - INFO - Processing train_val_split_2 val instagram.pcap
# 2025-01-23 14:25:49,221 - root - INFO - Processing train_val_split_2 val iqiyi.pcap
# 2025-01-23 14:25:49,270 - root - INFO - Processing train_val_split_2 val ibm.pcap
# 2025-01-23 14:25:49,338 - root - INFO - Processing train_val_split_2 val dailymotion.pcap
# 2025-01-23 14:25:49,369 - root - INFO - Processing train_val_split_2 val smzdm.pcap
# 2025-01-23 14:25:49,441 - root - INFO - Processing train_val_split_2 val gravatar.pcap
# 2025-01-23 14:25:49,488 - root - INFO - Processing train_val_split_2 val microsoft.pcap
# 2025-01-23 14:25:49,550 - root - INFO - Processing train_val_split_2 val cloudfront.pcap
# 2025-01-23 14:25:49,606 - root - INFO - Processing train_val_split_2 val jb51.pcap
# 2025-01-23 14:25:49,679 - root - INFO - Processing train_val_split_2 val pinduoduo.pcap
# 2025-01-23 14:25:49,738 - root - INFO - Processing train_val_split_2 val vmware.pcap
# 2025-01-23 14:25:49,769 - root - INFO - Processing train_val_split_2 val wikimedia.pcap
# 2025-01-23 14:25:49,799 - root - INFO - Processing train_val_split_2 val sohu.pcap
# 2025-01-23 14:25:49,861 - root - INFO - Processing train_val_split_2 val apple.pcap
# 2025-01-23 14:25:49,925 - root - INFO - Processing train_val_split_2 val twimg.pcap
# 2025-01-23 14:25:50,050 - root - INFO - Processing train_val_split_2 val onlinedown.pcap
# 2025-01-23 14:25:50,125 - root - INFO - Processing train_val_split_2 val booking.pcap
# 2025-01-23 14:25:50,245 - root - INFO - Processing train_val_split_2 val digitaloceanspaces.pcap
# 2025-01-23 14:25:50,308 - root - INFO - Processing train_val_split_2 val netflix.pcap
# 2025-01-23 14:25:50,391 - root - INFO - Processing train_val_split_2 val gitlab.pcap
# 2025-01-23 14:25:50,441 - root - INFO - Processing train_val_split_2 val criteo.pcap
# 2025-01-23 14:25:50,481 - root - INFO - Processing train_val_split_2 val v2ex.pcap
# 2025-01-23 14:25:50,579 - root - INFO - Processing train_val_split_2 val icloud.pcap
# 2025-01-23 14:25:50,607 - root - INFO - Processing train_val_split_2 val yahoo.pcap
# 2025-01-23 14:25:50,902 - root - INFO - Processing train_val_split_2 val runoob.pcap
# 2025-01-23 14:25:50,946 - root - INFO - Processing train_val_split_2 val sciencedirect.pcap
# 2025-01-23 14:25:51,004 - root - INFO - Processing train_val_split_2 val huya.pcap
# 2025-01-23 14:25:51,050 - root - INFO - Processing train_val_split_2 val xiaomi.pcap
# 2025-01-23 14:25:51,137 - root - INFO - Processing train_val_split_2 val huanqiu.pcap
# 2025-01-23 14:25:51,225 - root - INFO - Processing train_val_split_2 val eastmoney.pcap
# 2025-01-23 14:25:51,323 - root - INFO - Processing train_val_split_2 val elsevier.pcap
# 2025-01-23 14:25:51,392 - root - INFO - Processing train_val_split_2 val office.pcap
# 2025-01-23 14:25:51,451 - root - INFO - Processing train_val_split_2 val 51.pcap
# 2025-01-23 14:25:51,481 - root - INFO - Processing train_val_split_2 val semanticscholar.pcap
# 2025-01-23 14:25:51,553 - root - INFO - Processing train_val_split_2 val kugou.pcap
# 2025-01-23 14:25:51,630 - root - INFO - Processing train_val_split_2 val ximalaya.pcap
# 2025-01-23 14:25:51,681 - root - INFO - Processing train_val_split_2 val naver.pcap
# 2025-01-23 14:25:51,731 - root - INFO - Processing train_val_split_2 val cisco.pcap
# 2025-01-23 14:25:51,785 - root - INFO - Processing train_val_split_2 val mi.pcap
# 2025-01-23 14:25:51,896 - root - INFO - Processing train_val_split_2 val leetcode-cn.pcap
# 2025-01-23 14:25:51,957 - root - INFO - Processing train_val_split_2 val arxiv.pcap
# 2025-01-23 14:25:52,009 - root - INFO - Processing train_val_split_2 val mozilla.pcap
# 2025-01-23 14:25:52,101 - root - INFO - Processing train_val_split_2 val walmart.pcap
# 2025-01-23 14:25:52,154 - root - INFO - Processing train_val_split_2 val feishu.pcap
# 2025-01-23 14:25:52,196 - root - INFO - Processing train_val_split_2 val wikipedia.pcap
# 2025-01-23 14:25:52,271 - root - INFO - Processing train_val_split_2 val vk.pcap
# 2025-01-23 14:25:52,302 - root - INFO - Processing train_val_split_2 val spring.pcap
# 2025-01-23 14:25:52,346 - root - INFO - Processing train_val_split_2 val notion.pcap
# 2025-01-23 14:25:52,402 - root - INFO - Processing train_val_split_2 val grammarly.pcap
# 2025-01-23 14:25:52,429 - root - INFO - Processing train_val_split_2 val nvidia.pcap
# 2025-01-23 14:25:52,495 - root - INFO - Processing train_val_split_2 val taboola.pcap
# 2025-01-23 14:25:52,582 - root - INFO - Processing train_val_split_2 val yy.pcap
# 2025-01-23 14:25:52,644 - root - INFO - Processing train_val_split_2 val atlassian.pcap
# 2025-01-23 14:25:52,687 - root - INFO - Processing train_val_split_2 val toutiao.pcap
# 2025-01-23 14:25:52,735 - root - INFO - Processing train_val_split_2 val amap.pcap
# 2025-01-23 14:25:52,753 - root - INFO - Processing train_val_split_2 val qq.pcap
# 2025-01-23 14:25:52,813 - root - INFO - Processing train_val_split_2 val bilibili.pcap
# 2025-01-23 14:25:52,859 - root - INFO - Processing train_val_split_2 val acm.pcap
# 2025-01-23 14:25:52,890 - root - INFO - Processing train_val_split_2 val adobe.pcap
# 2025-01-23 14:25:53,008 - root - INFO - Processing train_val_split_2 val google.pcap
# 2025-01-23 14:25:53,047 - root - INFO - Processing train_val_split_2 val chinatax.pcap
# 2025-01-23 14:25:53,135 - root - INFO - Processing train_val_split_2 val baidu.pcap
# 2025-01-23 14:25:53,196 - root - INFO - Processing train_val_split_2 val paypal.pcap
# 2025-01-23 14:25:53,225 - root - INFO - Processing train_val_split_2 val yandex.pcap
# 2025-01-23 14:25:53,350 - root - INFO - Processing train_val_split_2 val oracle.pcap
# 2025-01-23 14:25:53,402 - root - INFO - Processing train_val_split_2 val ctrip.pcap
# 2025-01-23 14:25:53,513 - root - INFO - Processing train_val_split_2 val codepen.pcap
# 2025-01-23 14:25:53,573 - root - INFO - Processing train_val_split_2 val cnblogs.pcap
# 2025-01-23 14:25:53,686 - root - INFO - Processing train_val_split_2 val steampowered.pcap
# 2025-01-23 14:25:53,757 - root - INFO - Processing train_val_split_2 val weibo.pcap
# 2025-01-23 14:25:53,809 - root - INFO - Processing train_val_split_2 val squarespace.pcap
# 2025-01-23 14:25:53,856 - root - INFO - Processing train_val_split_2 val zhihu.pcap
# 2025-01-23 14:25:53,903 - root - INFO - Processing train_val_split_2 val jd.pcap
# 2025-01-23 14:25:54,002 - root - INFO - Processing train_val_split_2 val t.pcap
# 2025-01-23 14:25:54,047 - root - INFO - Processing train_val_split_2 val biligame.pcap
# 2025-01-23 14:25:54,104 - root - INFO - Processing train_val_split_2 val eastday.pcap
# 2025-01-23 14:25:54,174 - root - INFO - Processing train_val_split_2 val qcloud.pcap
# 2025-01-23 14:25:54,195 - root - INFO - Processing train_val_split_2 val alipay.pcap
# 2025-01-23 14:25:54,240 - root - INFO - Processing train_val_split_2 val goat.pcap
# 2025-01-23 14:25:54,275 - root - INFO - Processing train_val_split_2 val guancha.pcap
# 2025-01-23 14:25:54,305 - root - INFO - Processing train_val_split_2 val gmail.pcap
# 2025-01-23 14:25:54,336 - root - INFO - Processing train_val_split_2 val python.pcap
# 2025-01-23 14:25:54,385 - root - INFO - Processing train_val_split_2 val chia.pcap
# 2025-01-23 14:25:54,428 - root - INFO - Processing train_val_split_2 val springer.pcap
# 2025-01-23 14:25:54,534 - root - INFO - Processing train_val_split_2 val github.pcap
# 2025-01-23 14:25:54,605 - root - INFO - Processing train_val_split_2 val 163.pcap
# 2025-01-23 14:25:54,641 - root - INFO - Processing train_val_split_2 val crazyegg.pcap
# 2025-01-23 14:25:54,752 - root - INFO - Processing train_val_split_2 val thepaper.pcap
# 2025-01-23 14:25:54,792 - root - INFO - Processing train_val_split_2 val ampproject.pcap
# 2025-01-23 14:25:54,823 - root - INFO - Processing train_val_split_2 val vivo.pcap
# 2025-01-23 14:25:54,895 - root - INFO - Processing train_val_split_2 val tiktok.pcap
# 2025-01-23 14:25:54,936 - root - INFO - Processing train_val_split_2 val wp.pcap
# 2025-01-23 14:25:55,020 - root - INFO - Processing train_val_split_2 val researchgate.pcap
# 2025-01-23 14:25:55,062 - root - INFO - Processing train_val_split_2 val asus.pcap
# 2025-01-23 14:25:55,102 - root - INFO - Processing train_val_split_2 val snapchat.pcap
# 2025-01-23 14:25:55,217 - root - INFO - Processing train_val_split_2 val huawei.pcap
# 2025-01-23 14:25:55,278 - root - INFO - Processing train_val_split_2 val ggpht.pcap
# 2025-01-23 14:25:55,328 - root - INFO - Processing train_val_split_2 val duckduckgo.pcap
# 2025-01-23 14:25:55,375 - root - INFO - Processing train_val_split_2 val unity3d.pcap
# 2025-01-23 14:25:55,438 - root - INFO - Processing train_val_split_2 val deepl.pcap
# 2025-01-23 14:25:55,546 - root - INFO - Processing train_val_split_2 val nike.pcap
# 2025-01-23 14:25:55,607 - root - INFO - Processing train_val_split_2 val alicdn.pcap
# 2025-01-23 14:25:55,717 - root - INFO - Processing train_val_split_2 val opera.pcap
# 2025-01-23 14:25:55,766 - root - INFO - Processing train_val_split_2 val cloudflare.pcap
# 2025-01-23 14:25:55,854 - root - INFO - Processing train_val_split_2 val twitter.pcap
# 2025-01-23 14:25:55,906 - root - INFO - Processing train_val_split_2 val facebook.pcap
# 2025-01-23 14:25:56,009 - root - INFO - Processing train_val_split_2 val statcounter.pcap
# 2025-01-23 14:25:56,099 - root - INFO - Processing train_val_split_2 val azureedge.pcap
# 2025-01-23 14:25:56,132 - root - INFO - Processing train_val_split_2 val msn.pcap
# 2025-01-23 14:25:56,153 - root - INFO - Processing train_val_split_2 val media.pcap
# 2025-01-23 14:25:56,237 - root - INFO - Processing train_val_split_2 val amazonaws.pcap
# 2025-01-23 14:25:56,287 - root - INFO - Processing train_val_split_2 val hubspot.pcap
# 2025-01-23 14:25:56,319 - root - INFO - Processing train_val_split_2 val ieee.pcap
# 2025-01-23 14:25:56,394 - root - INFO - Processing train_val_split_2 val outbrain.pcap
# 2025-01-23 14:25:56,432 - root - INFO - Processing train_val_split_2 val teads.pcap
# 2025-01-23 14:25:56,490 - root - INFO - Processing train_val_split_0
# 2025-01-23 14:25:56,492 - root - INFO - Processing train_val_split_0 train
# 2025-01-23 14:25:56,498 - root - INFO - Processing train_val_split_0 train 51cto.pcap
# 2025-01-23 14:25:56,871 - root - INFO - Processing train_val_split_0 train sina.pcap
# 2025-01-23 14:25:57,223 - root - INFO - Processing train_val_split_0 train overleaf.pcap
# 2025-01-23 14:25:57,550 - root - INFO - Processing train_val_split_0 train youtube.pcap
# 2025-01-23 14:25:57,838 - root - INFO - Processing train_val_split_0 train alibaba.pcap
# 2025-01-23 14:25:58,098 - root - INFO - Processing train_val_split_0 train instagram.pcap
# 2025-01-23 14:25:58,427 - root - INFO - Processing train_val_split_0 train iqiyi.pcap
# 2025-01-23 14:25:58,754 - root - INFO - Processing train_val_split_0 train ibm.pcap
# 2025-01-23 14:25:59,156 - root - INFO - Processing train_val_split_0 train dailymotion.pcap
# 2025-01-23 14:25:59,555 - root - INFO - Processing train_val_split_0 train smzdm.pcap
# 2025-01-23 14:25:59,909 - root - INFO - Processing train_val_split_0 train gravatar.pcap
# 2025-01-23 14:26:00,252 - root - INFO - Processing train_val_split_0 train microsoft.pcap
# 2025-01-23 14:26:00,640 - root - INFO - Processing train_val_split_0 train cloudfront.pcap
# 2025-01-23 14:26:00,905 - root - INFO - Processing train_val_split_0 train jb51.pcap
# 2025-01-23 14:26:01,252 - root - INFO - Processing train_val_split_0 train pinduoduo.pcap
# 2025-01-23 14:26:01,583 - root - INFO - Processing train_val_split_0 train vmware.pcap
# 2025-01-23 14:26:01,958 - root - INFO - Processing train_val_split_0 train wikimedia.pcap
# 2025-01-23 14:26:02,319 - root - INFO - Processing train_val_split_0 train sohu.pcap
# 2025-01-23 14:26:02,639 - root - INFO - Processing train_val_split_0 train apple.pcap
# 2025-01-23 14:26:02,976 - root - INFO - Processing train_val_split_0 train twimg.pcap
# 2025-01-23 14:26:03,349 - root - INFO - Processing train_val_split_0 train onlinedown.pcap
# 2025-01-23 14:26:03,731 - root - INFO - Processing train_val_split_0 train booking.pcap
# 2025-01-23 14:26:04,026 - root - INFO - Processing train_val_split_0 train digitaloceanspaces.pcap
# 2025-01-23 14:26:04,364 - root - INFO - Processing train_val_split_0 train netflix.pcap
# 2025-01-23 14:26:04,641 - root - INFO - Processing train_val_split_0 train gitlab.pcap
# 2025-01-23 14:26:04,962 - root - INFO - Processing train_val_split_0 train criteo.pcap
# 2025-01-23 14:26:05,265 - root - INFO - Processing train_val_split_0 train v2ex.pcap
# 2025-01-23 14:26:05,640 - root - INFO - Processing train_val_split_0 train icloud.pcap
# 2025-01-23 14:26:05,941 - root - INFO - Processing train_val_split_0 train yahoo.pcap
# 2025-01-23 14:26:06,277 - root - INFO - Processing train_val_split_0 train runoob.pcap
# 2025-01-23 14:26:06,654 - root - INFO - Processing train_val_split_0 train sciencedirect.pcap
# 2025-01-23 14:26:06,943 - root - INFO - Processing train_val_split_0 train huya.pcap
# 2025-01-23 14:26:07,302 - root - INFO - Processing train_val_split_0 train xiaomi.pcap
# 2025-01-23 14:26:07,716 - root - INFO - Processing train_val_split_0 train huanqiu.pcap
# 2025-01-23 14:26:08,052 - root - INFO - Processing train_val_split_0 train eastmoney.pcap
# 2025-01-23 14:26:08,394 - root - INFO - Processing train_val_split_0 train elsevier.pcap
# 2025-01-23 14:26:08,758 - root - INFO - Processing train_val_split_0 train office.pcap
# 2025-01-23 14:26:09,141 - root - INFO - Processing train_val_split_0 train 51.pcap
# 2025-01-23 14:26:09,470 - root - INFO - Processing train_val_split_0 train semanticscholar.pcap
# 2025-01-23 14:26:09,802 - root - INFO - Processing train_val_split_0 train kugou.pcap
# 2025-01-23 14:26:10,135 - root - INFO - Processing train_val_split_0 train ximalaya.pcap
# 2025-01-23 14:26:10,391 - root - INFO - Processing train_val_split_0 train naver.pcap
# 2025-01-23 14:26:10,707 - root - INFO - Processing train_val_split_0 train cisco.pcap
# 2025-01-23 14:26:11,099 - root - INFO - Processing train_val_split_0 train mi.pcap
# 2025-01-23 14:26:11,465 - root - INFO - Processing train_val_split_0 train leetcode-cn.pcap
# 2025-01-23 14:26:11,864 - root - INFO - Processing train_val_split_0 train arxiv.pcap
# 2025-01-23 14:26:12,246 - root - INFO - Processing train_val_split_0 train mozilla.pcap
# 2025-01-23 14:26:12,640 - root - INFO - Processing train_val_split_0 train walmart.pcap
# 2025-01-23 14:26:12,855 - root - INFO - Processing train_val_split_0 train feishu.pcap
# 2025-01-23 14:26:13,245 - root - INFO - Processing train_val_split_0 train wikipedia.pcap
# 2025-01-23 14:26:13,650 - root - INFO - Processing train_val_split_0 train vk.pcap
# 2025-01-23 14:26:14,047 - root - INFO - Processing train_val_split_0 train spring.pcap
# 2025-01-23 14:26:14,440 - root - INFO - Processing train_val_split_0 train notion.pcap
# 2025-01-23 14:26:14,718 - root - INFO - Processing train_val_split_0 train grammarly.pcap
# 2025-01-23 14:26:15,070 - root - INFO - Processing train_val_split_0 train nvidia.pcap
# 2025-01-23 14:26:15,475 - root - INFO - Processing train_val_split_0 train taboola.pcap
# 2025-01-23 14:26:15,832 - root - INFO - Processing train_val_split_0 train yy.pcap
# 2025-01-23 14:26:16,187 - root - INFO - Processing train_val_split_0 train atlassian.pcap
# 2025-01-23 14:26:16,490 - root - INFO - Processing train_val_split_0 train toutiao.pcap
# 2025-01-23 14:26:16,773 - root - INFO - Processing train_val_split_0 train amap.pcap
# 2025-01-23 14:26:16,985 - root - INFO - Processing train_val_split_0 train qq.pcap
# 2025-01-23 14:26:17,317 - root - INFO - Processing train_val_split_0 train bilibili.pcap
# 2025-01-23 14:26:17,599 - root - INFO - Processing train_val_split_0 train acm.pcap
# 2025-01-23 14:26:17,989 - root - INFO - Processing train_val_split_0 train adobe.pcap
# 2025-01-23 14:26:18,394 - root - INFO - Processing train_val_split_0 train google.pcap
# 2025-01-23 14:26:18,773 - root - INFO - Processing train_val_split_0 train chinatax.pcap
# 2025-01-23 14:26:19,098 - root - INFO - Processing train_val_split_0 train baidu.pcap
# 2025-01-23 14:26:19,448 - root - INFO - Processing train_val_split_0 train paypal.pcap
# 2025-01-23 14:26:19,773 - root - INFO - Processing train_val_split_0 train yandex.pcap
# 2025-01-23 14:26:20,135 - root - INFO - Processing train_val_split_0 train oracle.pcap
# 2025-01-23 14:26:20,530 - root - INFO - Processing train_val_split_0 train ctrip.pcap
# 2025-01-23 14:26:20,897 - root - INFO - Processing train_val_split_0 train codepen.pcap
# 2025-01-23 14:26:21,269 - root - INFO - Processing train_val_split_0 train cnblogs.pcap
# 2025-01-23 14:26:21,677 - root - INFO - Processing train_val_split_0 train steampowered.pcap
# 2025-01-23 14:26:21,973 - root - INFO - Processing train_val_split_0 train weibo.pcap
# 2025-01-23 14:26:22,347 - root - INFO - Processing train_val_split_0 train squarespace.pcap
# 2025-01-23 14:26:22,690 - root - INFO - Processing train_val_split_0 train zhihu.pcap
# 2025-01-23 14:26:23,104 - root - INFO - Processing train_val_split_0 train jd.pcap
# 2025-01-23 14:26:23,388 - root - INFO - Processing train_val_split_0 train t.pcap
# 2025-01-23 14:26:23,681 - root - INFO - Processing train_val_split_0 train biligame.pcap
# 2025-01-23 14:26:23,957 - root - INFO - Processing train_val_split_0 train eastday.pcap
# 2025-01-23 14:26:24,293 - root - INFO - Processing train_val_split_0 train qcloud.pcap
# 2025-01-23 14:26:24,540 - root - INFO - Processing train_val_split_0 train alipay.pcap
# 2025-01-23 14:26:24,814 - root - INFO - Processing train_val_split_0 train goat.pcap
# 2025-01-23 14:26:25,202 - root - INFO - Processing train_val_split_0 train guancha.pcap
# 2025-01-23 14:26:25,559 - root - INFO - Processing train_val_split_0 train gmail.pcap
# 2025-01-23 14:26:25,849 - root - INFO - Processing train_val_split_0 train python.pcap
# 2025-01-23 14:26:26,143 - root - INFO - Processing train_val_split_0 train chia.pcap
# 2025-01-23 14:26:26,528 - root - INFO - Processing train_val_split_0 train springer.pcap
# 2025-01-23 14:26:26,943 - root - INFO - Processing train_val_split_0 train github.pcap
# 2025-01-23 14:26:27,304 - root - INFO - Processing train_val_split_0 train 163.pcap
# 2025-01-23 14:26:27,678 - root - INFO - Processing train_val_split_0 train crazyegg.pcap
# 2025-01-23 14:26:28,040 - root - INFO - Processing train_val_split_0 train thepaper.pcap
# 2025-01-23 14:26:28,439 - root - INFO - Processing train_val_split_0 train ampproject.pcap
# 2025-01-23 14:26:28,856 - root - INFO - Processing train_val_split_0 train vivo.pcap
# 2025-01-23 14:26:29,139 - root - INFO - Processing train_val_split_0 train tiktok.pcap
# 2025-01-23 14:26:29,410 - root - INFO - Processing train_val_split_0 train wp.pcap
# 2025-01-23 14:26:29,758 - root - INFO - Processing train_val_split_0 train researchgate.pcap
# 2025-01-23 14:26:30,097 - root - INFO - Processing train_val_split_0 train asus.pcap
# 2025-01-23 14:26:30,435 - root - INFO - Processing train_val_split_0 train snapchat.pcap
# 2025-01-23 14:26:30,735 - root - INFO - Processing train_val_split_0 train huawei.pcap
# 2025-01-23 14:26:31,139 - root - INFO - Processing train_val_split_0 train ggpht.pcap
# 2025-01-23 14:26:31,482 - root - INFO - Processing train_val_split_0 train duckduckgo.pcap
# 2025-01-23 14:26:31,788 - root - INFO - Processing train_val_split_0 train unity3d.pcap
# 2025-01-23 14:26:32,122 - root - INFO - Processing train_val_split_0 train deepl.pcap
# 2025-01-23 14:26:32,554 - root - INFO - Processing train_val_split_0 train nike.pcap
# 2025-01-23 14:26:32,887 - root - INFO - Processing train_val_split_0 train alicdn.pcap
# 2025-01-23 14:26:33,205 - root - INFO - Processing train_val_split_0 train opera.pcap
# 2025-01-23 14:26:33,588 - root - INFO - Processing train_val_split_0 train cloudflare.pcap
# 2025-01-23 14:26:33,888 - root - INFO - Processing train_val_split_0 train twitter.pcap
# 2025-01-23 14:26:34,292 - root - INFO - Processing train_val_split_0 train facebook.pcap
# 2025-01-23 14:26:34,592 - root - INFO - Processing train_val_split_0 train statcounter.pcap
# 2025-01-23 14:26:34,927 - root - INFO - Processing train_val_split_0 train azureedge.pcap
# 2025-01-23 14:26:35,274 - root - INFO - Processing train_val_split_0 train msn.pcap
# 2025-01-23 14:26:35,548 - root - INFO - Processing train_val_split_0 train media.pcap
# 2025-01-23 14:26:35,890 - root - INFO - Processing train_val_split_0 train amazonaws.pcap
# 2025-01-23 14:26:36,218 - root - INFO - Processing train_val_split_0 train hubspot.pcap
# 2025-01-23 14:26:36,539 - root - INFO - Processing train_val_split_0 train ieee.pcap
# 2025-01-23 14:26:36,838 - root - INFO - Processing train_val_split_0 train outbrain.pcap
# 2025-01-23 14:26:37,141 - root - INFO - Processing train_val_split_0 train teads.pcap
# 2025-01-23 14:26:37,413 - root - INFO - Processing train_val_split_0 val
# 2025-01-23 14:26:37,419 - root - INFO - Processing train_val_split_0 val 51cto.pcap
# 2025-01-23 14:26:37,616 - root - INFO - Processing train_val_split_0 val sina.pcap
# 2025-01-23 14:26:37,758 - root - INFO - Processing train_val_split_0 val overleaf.pcap
# 2025-01-23 14:26:37,901 - root - INFO - Processing train_val_split_0 val youtube.pcap
# 2025-01-23 14:26:38,014 - root - INFO - Processing train_val_split_0 val alibaba.pcap
# 2025-01-23 14:26:38,141 - root - INFO - Processing train_val_split_0 val instagram.pcap
# 2025-01-23 14:26:38,251 - root - INFO - Processing train_val_split_0 val iqiyi.pcap
# 2025-01-23 14:26:38,363 - root - INFO - Processing train_val_split_0 val ibm.pcap
# 2025-01-23 14:26:38,582 - root - INFO - Processing train_val_split_0 val dailymotion.pcap
# 2025-01-23 14:26:38,730 - root - INFO - Processing train_val_split_0 val smzdm.pcap
# 2025-01-23 14:26:38,879 - root - INFO - Processing train_val_split_0 val gravatar.pcap
# 2025-01-23 14:26:39,020 - root - INFO - Processing train_val_split_0 val microsoft.pcap
# 2025-01-23 14:26:39,149 - root - INFO - Processing train_val_split_0 val cloudfront.pcap
# 2025-01-23 14:26:39,299 - root - INFO - Processing train_val_split_0 val jb51.pcap
# 2025-01-23 14:26:39,437 - root - INFO - Processing train_val_split_0 val pinduoduo.pcap
# 2025-01-23 14:26:39,602 - root - INFO - Processing train_val_split_0 val vmware.pcap
# 2025-01-23 14:26:39,740 - root - INFO - Processing train_val_split_0 val wikimedia.pcap
# 2025-01-23 14:26:39,899 - root - INFO - Processing train_val_split_0 val sohu.pcap
# 2025-01-23 14:26:40,030 - root - INFO - Processing train_val_split_0 val apple.pcap
# 2025-01-23 14:26:40,207 - root - INFO - Processing train_val_split_0 val twimg.pcap
# 2025-01-23 14:26:40,372 - root - INFO - Processing train_val_split_0 val onlinedown.pcap
# 2025-01-23 14:26:40,532 - root - INFO - Processing train_val_split_0 val booking.pcap
# 2025-01-23 14:26:40,647 - root - INFO - Processing train_val_split_0 val digitaloceanspaces.pcap
# 2025-01-23 14:26:40,778 - root - INFO - Processing train_val_split_0 val netflix.pcap
# 2025-01-23 14:26:40,911 - root - INFO - Processing train_val_split_0 val gitlab.pcap
# 2025-01-23 14:26:41,075 - root - INFO - Processing train_val_split_0 val criteo.pcap
# 2025-01-23 14:26:41,217 - root - INFO - Processing train_val_split_0 val v2ex.pcap
# 2025-01-23 14:26:41,389 - root - INFO - Processing train_val_split_0 val icloud.pcap
# 2025-01-23 14:26:41,531 - root - INFO - Processing train_val_split_0 val yahoo.pcap
# 2025-01-23 14:26:41,644 - root - INFO - Processing train_val_split_0 val runoob.pcap
# 2025-01-23 14:26:41,798 - root - INFO - Processing train_val_split_0 val sciencedirect.pcap
# 2025-01-23 14:26:41,978 - root - INFO - Processing train_val_split_0 val huya.pcap
# 2025-01-23 14:26:42,123 - root - INFO - Processing train_val_split_0 val xiaomi.pcap
# 2025-01-23 14:26:42,295 - root - INFO - Processing train_val_split_0 val huanqiu.pcap
# 2025-01-23 14:26:42,446 - root - INFO - Processing train_val_split_0 val eastmoney.pcap
# 2025-01-23 14:26:42,601 - root - INFO - Processing train_val_split_0 val elsevier.pcap
# 2025-01-23 14:26:42,859 - root - INFO - Processing train_val_split_0 val office.pcap
# 2025-01-23 14:26:43,031 - root - INFO - Processing train_val_split_0 val 51.pcap
# 2025-01-23 14:26:43,196 - root - INFO - Processing train_val_split_0 val semanticscholar.pcap
# 2025-01-23 14:26:43,337 - root - INFO - Processing train_val_split_0 val kugou.pcap
# 2025-01-23 14:26:43,463 - root - INFO - Processing train_val_split_0 val ximalaya.pcap
# 2025-01-23 14:26:43,569 - root - INFO - Processing train_val_split_0 val naver.pcap
# 2025-01-23 14:26:43,711 - root - INFO - Processing train_val_split_0 val cisco.pcap
# 2025-01-23 14:26:43,814 - root - INFO - Processing train_val_split_0 val mi.pcap
# 2025-01-23 14:26:43,955 - root - INFO - Processing train_val_split_0 val leetcode-cn.pcap
# 2025-01-23 14:26:44,091 - root - INFO - Processing train_val_split_0 val arxiv.pcap
# 2025-01-23 14:26:44,217 - root - INFO - Processing train_val_split_0 val mozilla.pcap
# 2025-01-23 14:26:44,353 - root - INFO - Processing train_val_split_0 val walmart.pcap
# 2025-01-23 14:26:44,459 - root - INFO - Processing train_val_split_0 val feishu.pcap
# 2025-01-23 14:26:44,586 - root - INFO - Processing train_val_split_0 val wikipedia.pcap
# 2025-01-23 14:26:44,738 - root - INFO - Processing train_val_split_0 val vk.pcap
# 2025-01-23 14:26:44,904 - root - INFO - Processing train_val_split_0 val spring.pcap
# 2025-01-23 14:26:45,048 - root - INFO - Processing train_val_split_0 val notion.pcap
# 2025-01-23 14:26:45,207 - root - INFO - Processing train_val_split_0 val grammarly.pcap
# 2025-01-23 14:26:45,364 - root - INFO - Processing train_val_split_0 val nvidia.pcap
# 2025-01-23 14:26:45,515 - root - INFO - Processing train_val_split_0 val taboola.pcap
# 2025-01-23 14:26:45,716 - root - INFO - Processing train_val_split_0 val yy.pcap
# 2025-01-23 14:26:45,906 - root - INFO - Processing train_val_split_0 val atlassian.pcap
# 2025-01-23 14:26:46,010 - root - INFO - Processing train_val_split_0 val toutiao.pcap
# 2025-01-23 14:26:46,137 - root - INFO - Processing train_val_split_0 val amap.pcap
# 2025-01-23 14:26:46,226 - root - INFO - Processing train_val_split_0 val qq.pcap
# 2025-01-23 14:26:46,346 - root - INFO - Processing train_val_split_0 val bilibili.pcap
# 2025-01-23 14:26:46,484 - root - INFO - Processing train_val_split_0 val acm.pcap
# 2025-01-23 14:26:46,650 - root - INFO - Processing train_val_split_0 val adobe.pcap
# 2025-01-23 14:26:46,805 - root - INFO - Processing train_val_split_0 val google.pcap
# 2025-01-23 14:26:46,962 - root - INFO - Processing train_val_split_0 val chinatax.pcap
# 2025-01-23 14:26:47,089 - root - INFO - Processing train_val_split_0 val baidu.pcap
# 2025-01-23 14:26:47,224 - root - INFO - Processing train_val_split_0 val paypal.pcap
# 2025-01-23 14:26:47,353 - root - INFO - Processing train_val_split_0 val yandex.pcap
# 2025-01-23 14:26:47,476 - root - INFO - Processing train_val_split_0 val oracle.pcap
# 2025-01-23 14:26:47,606 - root - INFO - Processing train_val_split_0 val ctrip.pcap
# 2025-01-23 14:26:47,749 - root - INFO - Processing train_val_split_0 val codepen.pcap
# 2025-01-23 14:26:47,888 - root - INFO - Processing train_val_split_0 val cnblogs.pcap
# 2025-01-23 14:26:48,032 - root - INFO - Processing train_val_split_0 val steampowered.pcap
# 2025-01-23 14:26:48,253 - root - INFO - Processing train_val_split_0 val weibo.pcap
# 2025-01-23 14:26:48,398 - root - INFO - Processing train_val_split_0 val squarespace.pcap
# 2025-01-23 14:26:48,552 - root - INFO - Processing train_val_split_0 val zhihu.pcap
# 2025-01-23 14:26:48,666 - root - INFO - Processing train_val_split_0 val jd.pcap
# 2025-01-23 14:26:48,776 - root - INFO - Processing train_val_split_0 val t.pcap
# 2025-01-23 14:26:48,894 - root - INFO - Processing train_val_split_0 val biligame.pcap
# 2025-01-23 14:26:49,052 - root - INFO - Processing train_val_split_0 val eastday.pcap
# 2025-01-23 14:26:49,214 - root - INFO - Processing train_val_split_0 val qcloud.pcap
# 2025-01-23 14:26:49,304 - root - INFO - Processing train_val_split_0 val alipay.pcap
# 2025-01-23 14:26:49,431 - root - INFO - Processing train_val_split_0 val goat.pcap
# 2025-01-23 14:26:49,687 - root - INFO - Processing train_val_split_0 val guancha.pcap
# 2025-01-23 14:26:49,811 - root - INFO - Processing train_val_split_0 val gmail.pcap
# 2025-01-23 14:26:49,941 - root - INFO - Processing train_val_split_0 val python.pcap
# 2025-01-23 14:26:50,055 - root - INFO - Processing train_val_split_0 val chia.pcap
# 2025-01-23 14:26:50,230 - root - INFO - Processing train_val_split_0 val springer.pcap
# 2025-01-23 14:26:50,344 - root - INFO - Processing train_val_split_0 val github.pcap
# 2025-01-23 14:26:50,533 - root - INFO - Processing train_val_split_0 val 163.pcap
# 2025-01-23 14:26:50,678 - root - INFO - Processing train_val_split_0 val crazyegg.pcap
# 2025-01-23 14:26:50,802 - root - INFO - Processing train_val_split_0 val thepaper.pcap
# 2025-01-23 14:26:51,046 - root - INFO - Processing train_val_split_0 val ampproject.pcap
# 2025-01-23 14:26:51,217 - root - INFO - Processing train_val_split_0 val vivo.pcap
# 2025-01-23 14:26:51,337 - root - INFO - Processing train_val_split_0 val tiktok.pcap
# 2025-01-23 14:26:51,433 - root - INFO - Processing train_val_split_0 val wp.pcap
# 2025-01-23 14:26:51,585 - root - INFO - Processing train_val_split_0 val researchgate.pcap
# 2025-01-23 14:26:51,812 - root - INFO - Processing train_val_split_0 val asus.pcap
# 2025-01-23 14:26:51,904 - root - INFO - Processing train_val_split_0 val snapchat.pcap
# 2025-01-23 14:26:52,034 - root - INFO - Processing train_val_split_0 val huawei.pcap
# 2025-01-23 14:26:52,201 - root - INFO - Processing train_val_split_0 val ggpht.pcap
# 2025-01-23 14:26:52,320 - root - INFO - Processing train_val_split_0 val duckduckgo.pcap
# 2025-01-23 14:26:52,466 - root - INFO - Processing train_val_split_0 val unity3d.pcap
# 2025-01-23 14:26:52,628 - root - INFO - Processing train_val_split_0 val deepl.pcap
# 2025-01-23 14:26:52,800 - root - INFO - Processing train_val_split_0 val nike.pcap
# 2025-01-23 14:26:52,936 - root - INFO - Processing train_val_split_0 val alicdn.pcap
# 2025-01-23 14:26:53,100 - root - INFO - Processing train_val_split_0 val opera.pcap
# 2025-01-23 14:26:53,215 - root - INFO - Processing train_val_split_0 val cloudflare.pcap
# 2025-01-23 14:26:53,350 - root - INFO - Processing train_val_split_0 val twitter.pcap
# 2025-01-23 14:26:53,485 - root - INFO - Processing train_val_split_0 val facebook.pcap
# 2025-01-23 14:26:53,583 - root - INFO - Processing train_val_split_0 val statcounter.pcap
# 2025-01-23 14:26:53,709 - root - INFO - Processing train_val_split_0 val azureedge.pcap
# 2025-01-23 14:26:53,848 - root - INFO - Processing train_val_split_0 val msn.pcap
# 2025-01-23 14:26:53,944 - root - INFO - Processing train_val_split_0 val media.pcap
# 2025-01-23 14:26:54,054 - root - INFO - Processing train_val_split_0 val amazonaws.pcap
# 2025-01-23 14:26:54,173 - root - INFO - Processing train_val_split_0 val hubspot.pcap
# 2025-01-23 14:26:54,312 - root - INFO - Processing train_val_split_0 val ieee.pcap
# 2025-01-23 14:26:54,426 - root - INFO - Processing train_val_split_0 val outbrain.pcap
# 2025-01-23 14:26:54,573 - root - INFO - Processing train_val_split_0 val teads.pcap
# 2025-01-23 14:26:54,698 - root - INFO - Processing test
# 2025-01-23 14:26:54,703 - root - INFO - Processing test 51cto.pcap
# 2025-01-23 14:26:56,742 - root - INFO - Processing test sina.pcap
# 2025-01-23 14:26:58,902 - root - INFO - Processing test overleaf.pcap
# 2025-01-23 14:27:09,602 - root - INFO - Processing test youtube.pcap
# 2025-01-23 14:27:11,486 - root - INFO - Processing test alibaba.pcap
# 2025-01-23 14:27:11,707 - root - INFO - Processing test instagram.pcap
# 2025-01-23 14:27:12,743 - root - INFO - Processing test iqiyi.pcap
# 2025-01-23 14:27:14,057 - root - INFO - Processing test ibm.pcap
# 2025-01-23 14:27:15,305 - root - INFO - Processing test dailymotion.pcap
# 2025-01-23 14:27:24,013 - root - INFO - Processing test smzdm.pcap
# 2025-01-23 14:27:29,945 - root - INFO - Processing test gravatar.pcap
# 2025-01-23 14:27:30,944 - root - INFO - Processing test microsoft.pcap
# 2025-01-23 14:27:32,708 - root - INFO - Processing test cloudfront.pcap
# 2025-01-23 14:27:33,213 - root - INFO - Processing test jb51.pcap
# 2025-01-23 14:27:37,897 - root - INFO - Processing test pinduoduo.pcap
# 2025-01-23 14:27:39,674 - root - INFO - Processing test vmware.pcap
# 2025-01-23 14:27:40,418 - root - INFO - Processing test wikimedia.pcap
# 2025-01-23 14:27:44,164 - root - INFO - Processing test sohu.pcap
# 2025-01-23 14:27:45,053 - root - INFO - Processing test apple.pcap
# 2025-01-23 14:27:45,789 - root - INFO - Processing test twimg.pcap
# 2025-01-23 14:27:51,336 - root - INFO - Processing test onlinedown.pcap
# 2025-01-23 14:27:53,866 - root - INFO - Processing test booking.pcap
# 2025-01-23 14:27:54,472 - root - INFO - Processing test digitaloceanspaces.pcap
# 2025-01-23 14:27:54,866 - root - INFO - Processing test netflix.pcap
# 2025-01-23 14:27:56,778 - root - INFO - Processing test gitlab.pcap
# 2025-01-23 14:27:59,950 - root - INFO - Processing test criteo.pcap
# 2025-01-23 14:28:01,315 - root - INFO - Processing test v2ex.pcap
# 2025-01-23 14:28:03,621 - root - INFO - Processing test icloud.pcap
# 2025-01-23 14:28:04,782 - root - INFO - Processing test yahoo.pcap
# 2025-01-23 14:28:05,534 - root - INFO - Processing test runoob.pcap
# 2025-01-23 14:28:07,582 - root - INFO - Processing test sciencedirect.pcap
# 2025-01-23 14:28:07,905 - root - INFO - Processing test huya.pcap
# 2025-01-23 14:28:09,566 - root - INFO - Processing test xiaomi.pcap
# 2025-01-23 14:28:12,669 - root - INFO - Processing test huanqiu.pcap
# 2025-01-23 14:28:13,224 - root - INFO - Processing test eastmoney.pcap
# 2025-01-23 14:28:13,813 - root - INFO - Processing test elsevier.pcap
# 2025-01-23 14:28:14,628 - root - INFO - Processing test office.pcap
# 2025-01-23 14:28:16,838 - root - INFO - Processing test 51.pcap
# 2025-01-23 14:28:17,055 - root - INFO - Processing test semanticscholar.pcap
# 2025-01-23 14:28:19,279 - root - INFO - Processing test kugou.pcap
# 2025-01-23 14:28:20,954 - root - INFO - Processing test ximalaya.pcap
# 2025-01-23 14:28:21,584 - root - INFO - Processing test naver.pcap
# 2025-01-23 14:28:23,895 - root - INFO - Processing test cisco.pcap
# 2025-01-23 14:28:24,238 - root - INFO - Processing test mi.pcap
# 2025-01-23 14:28:25,257 - root - INFO - Processing test leetcode-cn.pcap
# 2025-01-23 14:28:30,229 - root - INFO - Processing test arxiv.pcap
# 2025-01-23 14:28:31,720 - root - INFO - Processing test mozilla.pcap
# 2025-01-23 14:28:33,011 - root - INFO - Processing test walmart.pcap
# 2025-01-23 14:28:33,489 - root - INFO - Processing test feishu.pcap
# 2025-01-23 14:28:35,277 - root - INFO - Processing test wikipedia.pcap
# 2025-01-23 14:28:39,001 - root - INFO - Processing test vk.pcap
# 2025-01-23 14:28:39,841 - root - INFO - Processing test spring.pcap
# 2025-01-23 14:28:40,413 - root - INFO - Processing test notion.pcap
# 2025-01-23 14:28:42,105 - root - INFO - Processing test grammarly.pcap
# 2025-01-23 14:28:42,924 - root - INFO - Processing test nvidia.pcap
# 2025-01-23 14:28:46,071 - root - INFO - Processing test taboola.pcap
# 2025-01-23 14:28:49,880 - root - INFO - Processing test yy.pcap
# 2025-01-23 14:28:52,197 - root - INFO - Processing test atlassian.pcap
# 2025-01-23 14:28:52,437 - root - INFO - Processing test toutiao.pcap
# 2025-01-23 14:28:52,958 - root - INFO - Processing test amap.pcap
# 2025-01-23 14:28:53,230 - root - INFO - Processing test qq.pcap
# 2025-01-23 14:28:54,442 - root - INFO - Processing test bilibili.pcap
# 2025-01-23 14:28:55,600 - root - INFO - Processing test acm.pcap
# 2025-01-23 14:29:02,720 - root - INFO - Processing test adobe.pcap
# 2025-01-23 14:29:04,099 - root - INFO - Processing test google.pcap
# 2025-01-23 14:29:05,064 - root - INFO - Processing test chinatax.pcap
# 2025-01-23 14:29:05,771 - root - INFO - Processing test baidu.pcap
# 2025-01-23 14:29:07,013 - root - INFO - Processing test paypal.pcap
# 2025-01-23 14:29:07,214 - root - INFO - Processing test yandex.pcap
# 2025-01-23 14:29:09,194 - root - INFO - Processing test oracle.pcap
# 2025-01-23 14:29:11,084 - root - INFO - Processing test ctrip.pcap
# 2025-01-23 14:29:12,889 - root - INFO - Processing test codepen.pcap
# 2025-01-23 14:29:13,975 - root - INFO - Processing test cnblogs.pcap
# 2025-01-23 14:29:17,299 - root - INFO - Processing test steampowered.pcap
# 2025-01-23 14:29:18,261 - root - INFO - Processing test weibo.pcap
# 2025-01-23 14:29:25,262 - root - INFO - Processing test squarespace.pcap
# 2025-01-23 14:29:25,658 - root - INFO - Processing test zhihu.pcap
# 2025-01-23 14:29:28,795 - root - INFO - Processing test jd.pcap
# 2025-01-23 14:29:29,612 - root - INFO - Processing test t.pcap
# 2025-01-23 14:29:30,124 - root - INFO - Processing test biligame.pcap
# 2025-01-23 14:29:30,748 - root - INFO - Processing test eastday.pcap
# 2025-01-23 14:29:31,194 - root - INFO - Processing test qcloud.pcap
# 2025-01-23 14:29:31,601 - root - INFO - Processing test alipay.pcap
# 2025-01-23 14:29:32,733 - root - INFO - Processing test goat.pcap
# 2025-01-23 14:29:34,836 - root - INFO - Processing test guancha.pcap
# 2025-01-23 14:29:36,353 - root - INFO - Processing test gmail.pcap
# 2025-01-23 14:29:37,090 - root - INFO - Processing test python.pcap
# ...
# 2025-01-23 14:30:47,174 - root - INFO - Processing train_val_split_1 train amap.pcap
# 2025-01-23 14:30:47,358 - root - INFO - Processing train_val_split_1 train qq.pcap
# 2025-01-23 14:30:47,599 - root - INFO - Processing train_val_split_1 train bilibili.pcap
# 2025-01-23 14:30:47,854 - root - INFO - Processing train_val_split_1 train acm.pcap
# 2025-01-23 14:30:48,168 - root - INFO - Processing train_val_split_1 train adobe.pcap
# 2025-01-23 14:30:48,442 - root - INFO - Processing train_val_split_1 train google.pcap
# 2025-01-23 14:30:48,692 - root - INFO - Processing train_val_split_1 train chinatax.pcap
# 2025-01-23 14:30:48,963 - root - INFO - Processing train_val_split_1 train baidu.pcap
# 2025-01-23 14:30:49,244 - root - INFO - Processing train_val_split_1 train paypal.pcap
# 2025-01-23 14:30:49,519 - root - INFO - Processing train_val_split_1 train yandex.pcap
# 2025-01-23 14:30:49,784 - root - INFO - Processing train_val_split_1 train oracle.pcap
# 2025-01-23 14:30:50,083 - root - INFO - Processing train_val_split_1 train ctrip.pcap
# 2025-01-23 14:30:50,373 - root - INFO - Processing train_val_split_1 train codepen.pcap
# 2025-01-23 14:30:50,637 - root - INFO - Processing train_val_split_1 train cnblogs.pcap
# 2025-01-23 14:30:50,903 - root - INFO - Processing train_val_split_1 train steampowered.pcap
# 2025-01-23 14:30:51,197 - root - INFO - Processing train_val_split_1 train weibo.pcap
# 2025-01-23 14:30:51,468 - root - INFO - Processing train_val_split_1 train squarespace.pcap
# 2025-01-23 14:30:51,754 - root - INFO - Processing train_val_split_1 train zhihu.pcap
# 2025-01-23 14:30:52,016 - root - INFO - Processing train_val_split_1 train jd.pcap
# 2025-01-23 14:30:52,286 - root - INFO - Processing train_val_split_1 train t.pcap
# 2025-01-23 14:30:52,488 - root - INFO - Processing train_val_split_1 train biligame.pcap
# 2025-01-23 14:30:52,792 - root - INFO - Processing train_val_split_1 train eastday.pcap
# 2025-01-23 14:30:53,073 - root - INFO - Processing train_val_split_1 train qcloud.pcap
# 2025-01-23 14:30:53,263 - root - INFO - Processing train_val_split_1 train alipay.pcap
# 2025-01-23 14:30:53,521 - root - INFO - Processing train_val_split_1 train goat.pcap
# 2025-01-23 14:30:53,832 - root - INFO - Processing train_val_split_1 train guancha.pcap
# 2025-01-23 14:30:54,100 - root - INFO - Processing train_val_split_1 train gmail.pcap
# 2025-01-23 14:30:54,327 - root - INFO - Processing train_val_split_1 train python.pcap
# 2025-01-23 14:30:54,545 - root - INFO - Processing train_val_split_1 train chia.pcap
# 2025-01-23 14:30:54,823 - root - INFO - Processing train_val_split_1 train springer.pcap
# 2025-01-23 14:30:55,131 - root - INFO - Processing train_val_split_1 train github.pcap
# 2025-01-23 14:30:55,432 - root - INFO - Processing train_val_split_1 train 163.pcap
# 2025-01-23 14:30:55,687 - root - INFO - Processing train_val_split_1 train crazyegg.pcap
# 2025-01-23 14:30:56,005 - root - INFO - Processing train_val_split_1 train thepaper.pcap
# 2025-01-23 14:30:56,303 - root - INFO - Processing train_val_split_1 train ampproject.pcap
# 2025-01-23 14:30:56,613 - root - INFO - Processing train_val_split_1 train vivo.pcap
# 2025-01-23 14:30:56,838 - root - INFO - Processing train_val_split_1 train tiktok.pcap
# 2025-01-23 14:30:57,089 - root - INFO - Processing train_val_split_1 train wp.pcap
# 2025-01-23 14:30:57,369 - root - INFO - Processing train_val_split_1 train researchgate.pcap
# 2025-01-23 14:30:57,654 - root - INFO - Processing train_val_split_1 train asus.pcap
# 2025-01-23 14:30:57,878 - root - INFO - Processing train_val_split_1 train snapchat.pcap
# 2025-01-23 14:30:58,157 - root - INFO - Processing train_val_split_1 train huawei.pcap
# 2025-01-23 14:30:58,469 - root - INFO - Processing train_val_split_1 train ggpht.pcap
# 2025-01-23 14:30:58,733 - root - INFO - Processing train_val_split_1 train duckduckgo.pcap
# 2025-01-23 14:30:59,042 - root - INFO - Processing train_val_split_1 train unity3d.pcap
# 2025-01-23 14:30:59,290 - root - INFO - Processing train_val_split_1 train deepl.pcap
# 2025-01-23 14:30:59,587 - root - INFO - Processing train_val_split_1 train nike.pcap
# 2025-01-23 14:30:59,839 - root - INFO - Processing train_val_split_1 train alicdn.pcap
# 2025-01-23 14:31:00,117 - root - INFO - Processing train_val_split_1 train opera.pcap
# 2025-01-23 14:31:00,343 - root - INFO - Processing train_val_split_1 train cloudflare.pcap
# 2025-01-23 14:31:00,626 - root - INFO - Processing train_val_split_1 train twitter.pcap
# 2025-01-23 14:31:00,931 - root - INFO - Processing train_val_split_1 train facebook.pcap
# 2025-01-23 14:31:01,161 - root - INFO - Processing train_val_split_1 train statcounter.pcap
# 2025-01-23 14:31:01,464 - root - INFO - Processing train_val_split_1 train azureedge.pcap
# 2025-01-23 14:31:01,728 - root - INFO - Processing train_val_split_1 train msn.pcap
# 2025-01-23 14:31:01,946 - root - INFO - Processing train_val_split_1 train media.pcap
# 2025-01-23 14:31:02,211 - root - INFO - Processing train_val_split_1 train amazonaws.pcap
# 2025-01-23 14:31:02,451 - root - INFO - Processing train_val_split_1 train hubspot.pcap
# 2025-01-23 14:31:02,716 - root - INFO - Processing train_val_split_1 train ieee.pcap
# 2025-01-23 14:31:02,958 - root - INFO - Processing train_val_split_1 train outbrain.pcap
# 2025-01-23 14:31:03,220 - root - INFO - Processing train_val_split_1 train teads.pcap
# 2025-01-23 14:31:03,452 - root - INFO - Processing train_val_split_1 val
# 2025-01-23 14:31:03,458 - root - INFO - Processing train_val_split_1 val 51cto.pcap
# 2025-01-23 14:31:03,628 - root - INFO - Processing train_val_split_1 val sina.pcap
# 2025-01-23 14:31:03,780 - root - INFO - Processing train_val_split_1 val overleaf.pcap
# 2025-01-23 14:31:03,956 - root - INFO - Processing train_val_split_1 val youtube.pcap
# 2025-01-23 14:31:04,072 - root - INFO - Processing train_val_split_1 val alibaba.pcap
# 2025-01-23 14:31:04,194 - root - INFO - Processing train_val_split_1 val instagram.pcap
# 2025-01-23 14:31:04,345 - root - INFO - Processing train_val_split_1 val iqiyi.pcap
# 2025-01-23 14:31:04,473 - root - INFO - Processing train_val_split_1 val ibm.pcap
# 2025-01-23 14:31:04,625 - root - INFO - Processing train_val_split_1 val dailymotion.pcap
# 2025-01-23 14:31:04,755 - root - INFO - Processing train_val_split_1 val smzdm.pcap
# 2025-01-23 14:31:04,896 - root - INFO - Processing train_val_split_1 val gravatar.pcap
# 2025-01-23 14:31:05,051 - root - INFO - Processing train_val_split_1 val microsoft.pcap
# 2025-01-23 14:31:05,186 - root - INFO - Processing train_val_split_1 val cloudfront.pcap
# 2025-01-23 14:31:05,326 - root - INFO - Processing train_val_split_1 val jb51.pcap
# 2025-01-23 14:31:05,480 - root - INFO - Processing train_val_split_1 val pinduoduo.pcap
# 2025-01-23 14:31:05,660 - root - INFO - Processing train_val_split_1 val vmware.pcap
# 2025-01-23 14:31:05,809 - root - INFO - Processing train_val_split_1 val wikimedia.pcap
# 2025-01-23 14:31:05,941 - root - INFO - Processing train_val_split_1 val sohu.pcap
# 2025-01-23 14:31:06,092 - root - INFO - Processing train_val_split_1 val apple.pcap
# 2025-01-23 14:31:06,231 - root - INFO - Processing train_val_split_1 val twimg.pcap
# 2025-01-23 14:31:06,431 - root - INFO - Processing train_val_split_1 val onlinedown.pcap
# 2025-01-23 14:31:06,594 - root - INFO - Processing train_val_split_1 val booking.pcap
# 2025-01-23 14:31:06,714 - root - INFO - Processing train_val_split_1 val digitaloceanspaces.pcap
# 2025-01-23 14:31:06,821 - root - INFO - Processing train_val_split_1 val netflix.pcap
# 2025-01-23 14:31:06,940 - root - INFO - Processing train_val_split_1 val gitlab.pcap
# 2025-01-23 14:31:07,074 - root - INFO - Processing train_val_split_1 val criteo.pcap
# 2025-01-23 14:31:07,179 - root - INFO - Processing train_val_split_1 val v2ex.pcap
# 2025-01-23 14:31:07,331 - root - INFO - Processing train_val_split_1 val icloud.pcap
# 2025-01-23 14:31:07,449 - root - INFO - Processing train_val_split_1 val yahoo.pcap
# 2025-01-23 14:31:07,602 - root - INFO - Processing train_val_split_1 val runoob.pcap
# 2025-01-23 14:31:07,718 - root - INFO - Processing train_val_split_1 val sciencedirect.pcap
# 2025-01-23 14:31:07,857 - root - INFO - Processing train_val_split_1 val huya.pcap
# 2025-01-23 14:31:07,955 - root - INFO - Processing train_val_split_1 val xiaomi.pcap
# 2025-01-23 14:31:08,108 - root - INFO - Processing train_val_split_1 val huanqiu.pcap
# 2025-01-23 14:31:08,252 - root - INFO - Processing train_val_split_1 val eastmoney.pcap
# 2025-01-23 14:31:08,407 - root - INFO - Processing train_val_split_1 val elsevier.pcap
# 2025-01-23 14:31:08,536 - root - INFO - Processing train_val_split_1 val office.pcap
# 2025-01-23 14:31:08,679 - root - INFO - Processing train_val_split_1 val 51.pcap
# 2025-01-23 14:31:08,811 - root - INFO - Processing train_val_split_1 val semanticscholar.pcap
# 2025-01-23 14:31:09,019 - root - INFO - Processing train_val_split_1 val kugou.pcap
# 2025-01-23 14:31:09,207 - root - INFO - Processing train_val_split_1 val ximalaya.pcap
# 2025-01-23 14:31:09,306 - root - INFO - Processing train_val_split_1 val naver.pcap
# 2025-01-23 14:31:09,434 - root - INFO - Processing train_val_split_1 val cisco.pcap
# 2025-01-23 14:31:09,562 - root - INFO - Processing train_val_split_1 val mi.pcap
# 2025-01-23 14:31:09,727 - root - INFO - Processing train_val_split_1 val leetcode-cn.pcap
# 2025-01-23 14:31:09,862 - root - INFO - Processing train_val_split_1 val arxiv.pcap
# 2025-01-23 14:31:10,008 - root - INFO - Processing train_val_split_1 val mozilla.pcap
# 2025-01-23 14:31:10,132 - root - INFO - Processing train_val_split_1 val walmart.pcap
# 2025-01-23 14:31:10,202 - root - INFO - Processing train_val_split_1 val feishu.pcap
# 2025-01-23 14:31:10,316 - root - INFO - Processing train_val_split_1 val wikipedia.pcap
# 2025-01-23 14:31:10,468 - root - INFO - Processing train_val_split_1 val vk.pcap
# 2025-01-23 14:31:10,616 - root - INFO - Processing train_val_split_1 val spring.pcap
# 2025-01-23 14:31:10,808 - root - INFO - Processing train_val_split_1 val notion.pcap
# 2025-01-23 14:31:10,909 - root - INFO - Processing train_val_split_1 val grammarly.pcap
# 2025-01-23 14:31:11,041 - root - INFO - Processing train_val_split_1 val nvidia.pcap
# 2025-01-23 14:31:11,242 - root - INFO - Processing train_val_split_1 val taboola.pcap
# 2025-01-23 14:31:11,415 - root - INFO - Processing train_val_split_1 val yy.pcap
# 2025-01-23 14:31:11,559 - root - INFO - Processing train_val_split_1 val atlassian.pcap
# 2025-01-23 14:31:11,679 - root - INFO - Processing train_val_split_1 val toutiao.pcap
# 2025-01-23 14:31:11,791 - root - INFO - Processing train_val_split_1 val amap.pcap
# 2025-01-23 14:31:11,898 - root - INFO - Processing train_val_split_1 val qq.pcap
# 2025-01-23 14:31:12,039 - root - INFO - Processing train_val_split_1 val bilibili.pcap
# 2025-01-23 14:31:12,140 - root - INFO - Processing train_val_split_1 val acm.pcap
# 2025-01-23 14:31:12,277 - root - INFO - Processing train_val_split_1 val adobe.pcap
# 2025-01-23 14:31:12,416 - root - INFO - Processing train_val_split_1 val google.pcap
# 2025-01-23 14:31:12,554 - root - INFO - Processing train_val_split_1 val chinatax.pcap
# 2025-01-23 14:31:12,688 - root - INFO - Processing train_val_split_1 val baidu.pcap
# 2025-01-23 14:31:12,855 - root - INFO - Processing train_val_split_1 val paypal.pcap
# 2025-01-23 14:31:12,981 - root - INFO - Processing train_val_split_1 val yandex.pcap
# 2025-01-23 14:31:13,124 - root - INFO - Processing train_val_split_1 val oracle.pcap
# 2025-01-23 14:31:13,289 - root - INFO - Processing train_val_split_1 val ctrip.pcap
# 2025-01-23 14:31:13,407 - root - INFO - Processing train_val_split_1 val codepen.pcap
# 2025-01-23 14:31:13,543 - root - INFO - Processing train_val_split_1 val cnblogs.pcap
# 2025-01-23 14:31:13,690 - root - INFO - Processing train_val_split_1 val steampowered.pcap
# 2025-01-23 14:31:13,793 - root - INFO - Processing train_val_split_1 val weibo.pcap
# 2025-01-23 14:31:13,946 - root - INFO - Processing train_val_split_1 val squarespace.pcap
# 2025-01-23 14:31:14,064 - root - INFO - Processing train_val_split_1 val zhihu.pcap
# 2025-01-23 14:31:14,258 - root - INFO - Processing train_val_split_1 val jd.pcap
# 2025-01-23 14:31:14,398 - root - INFO - Processing train_val_split_1 val t.pcap
# 2025-01-23 14:31:14,506 - root - INFO - Processing train_val_split_1 val biligame.pcap
# 2025-01-23 14:31:14,631 - root - INFO - Processing train_val_split_1 val eastday.pcap
# 2025-01-23 14:31:14,787 - root - INFO - Processing train_val_split_1 val qcloud.pcap
# 2025-01-23 14:31:14,903 - root - INFO - Processing train_val_split_1 val alipay.pcap
# 2025-01-23 14:31:15,008 - root - INFO - Processing train_val_split_1 val goat.pcap
# 2025-01-23 14:31:15,189 - root - INFO - Processing train_val_split_1 val guancha.pcap
# 2025-01-23 14:31:15,335 - root - INFO - Processing train_val_split_1 val gmail.pcap
# 2025-01-23 14:31:15,458 - root - INFO - Processing train_val_split_1 val python.pcap
# 2025-01-23 14:31:15,541 - root - INFO - Processing train_val_split_1 val chia.pcap
# 2025-01-23 14:31:15,706 - root - INFO - Processing train_val_split_1 val springer.pcap
# 2025-01-23 14:31:15,844 - root - INFO - Processing train_val_split_1 val github.pcap
# 2025-01-23 14:31:15,999 - root - INFO - Processing train_val_split_1 val 163.pcap
# 2025-01-23 14:31:16,133 - root - INFO - Processing train_val_split_1 val crazyegg.pcap
# 2025-01-23 14:31:16,237 - root - INFO - Processing train_val_split_1 val thepaper.pcap
# 2025-01-23 14:31:16,419 - root - INFO - Processing train_val_split_1 val ampproject.pcap
# 2025-01-23 14:31:16,594 - root - INFO - Processing train_val_split_1 val vivo.pcap
# 2025-01-23 14:31:16,737 - root - INFO - Processing train_val_split_1 val tiktok.pcap
# 2025-01-23 14:31:16,824 - root - INFO - Processing train_val_split_1 val wp.pcap
# 2025-01-23 14:31:16,971 - root - INFO - Processing train_val_split_1 val researchgate.pcap
# 2025-01-23 14:31:17,115 - root - INFO - Processing train_val_split_1 val asus.pcap
# 2025-01-23 14:31:17,237 - root - INFO - Processing train_val_split_1 val snapchat.pcap
# 2025-01-23 14:31:17,367 - root - INFO - Processing train_val_split_1 val huawei.pcap
# 2025-01-23 14:31:17,559 - root - INFO - Processing train_val_split_1 val ggpht.pcap
# 2025-01-23 14:31:17,700 - root - INFO - Processing train_val_split_1 val duckduckgo.pcap
# 2025-01-23 14:31:17,810 - root - INFO - Processing train_val_split_1 val unity3d.pcap
# 2025-01-23 14:31:17,921 - root - INFO - Processing train_val_split_1 val deepl.pcap
# 2025-01-23 14:31:18,081 - root - INFO - Processing train_val_split_1 val nike.pcap
# 2025-01-23 14:31:18,262 - root - INFO - Processing train_val_split_1 val alicdn.pcap
# 2025-01-23 14:31:18,408 - root - INFO - Processing train_val_split_1 val opera.pcap
# 2025-01-23 14:31:18,514 - root - INFO - Processing train_val_split_1 val cloudflare.pcap
# 2025-01-23 14:31:18,666 - root - INFO - Processing train_val_split_1 val twitter.pcap
# 2025-01-23 14:31:18,794 - root - INFO - Processing train_val_split_1 val facebook.pcap
# 2025-01-23 14:31:18,925 - root - INFO - Processing train_val_split_1 val statcounter.pcap
# 2025-01-23 14:31:19,046 - root - INFO - Processing train_val_split_1 val azureedge.pcap
# 2025-01-23 14:31:19,186 - root - INFO - Processing train_val_split_1 val msn.pcap
# 2025-01-23 14:31:19,318 - root - INFO - Processing train_val_split_1 val media.pcap
# 2025-01-23 14:31:19,440 - root - INFO - Processing train_val_split_1 val amazonaws.pcap
# 2025-01-23 14:31:19,570 - root - INFO - Processing train_val_split_1 val hubspot.pcap
# 2025-01-23 14:31:19,668 - root - INFO - Processing train_val_split_1 val ieee.pcap
# 2025-01-23 14:31:19,809 - root - INFO - Processing train_val_split_1 val outbrain.pcap
# 2025-01-23 14:31:19,954 - root - INFO - Processing train_val_split_1 val teads.pcap
# {'IP_id', 'TCP_flags', 'TL_chksum', 'TCP_urgptr', 'IP_chksum', 'TCP_echo_Timestamp', 'IP_frag', 'TCP_seq', 'IP_ttl', 'TCP_ack', 'IP_len', 'TCP_dataofs', 'IP_version', 'TCP_SAck', 'TCP_echo_SAck', 'TCP_Timestamp', 'TCP_reserved', 'IP_proto', 'IP_ihl', 'IP_tos', 'IP_flags', 'TCP_window'}
# {'', 'DF'}
# {'A', 'FPA', 'PA', 'PAC', 'FPAC', 'FA', 'AC'}

# %%
# convert the flag to integer

ip_flags_map = {}
tcp_flags_map = {}

for id, ip_flag in enumerate(ip_flags_set):
    if ip_flag != '':
        ip_flags_map[ip_flag] = id + 1

for id, tcp_flag in enumerate(tcp_flags_set):
    if tcp_flag != '':
        tcp_flags_map[tcp_flag] = id + 1

print(ip_flags_map)
print(tcp_flags_map)
print(field_set)
# Out:
# {'DF': 2}
# {'A': 1, 'FPA': 2, 'PA': 3, 'PAC': 4, 'FPAC': 5, 'FA': 6, 'AC': 7}
# {'IP_id', 'TCP_flags', 'TL_chksum', 'TCP_urgptr', 'IP_chksum', 'TCP_echo_Timestamp', 'IP_frag', 'TCP_seq', 'IP_ttl', 'TCP_ack', 'IP_len', 'TCP_dataofs', 'IP_version', 'TCP_SAck', 'TCP_echo_SAck', 'TCP_Timestamp', 'TCP_reserved', 'IP_proto', 'IP_ihl', 'IP_tos', 'IP_flags', 'TCP_window'}

# %%
field_set = {'IP_id', 'TCP_flags', 'TL_chksum', 'TCP_urgptr', 'IP_chksum', 'TCP_echo_Timestamp', 'IP_frag', 'TCP_seq', 'IP_ttl', 'TCP_ack', 'IP_len', 'TCP_dataofs', 'IP_version', 'TCP_SAck', 'TCP_echo_SAck', 'TCP_Timestamp', 'TCP_reserved', 'IP_proto', 'IP_ihl', 'IP_tos', 'IP_flags', 'TCP_window'}
ip_flags_map = {'DF': 1}
tcp_flags_map = {'A': 1, 'FPA': 2, 'PA': 3, 'PAC': 4, 'FPAC': 5, 'FA': 6, 'AC': 7}
ip_proto_map = {'tcp': 1, 'udp': 2, 'TCP': 1, 'UDP': 2}

# %%
pass_fields = ['src', 'dst', 'sport', 'dport']
map_features = {'TCP_flags', 'IP_flags', 'IP_proto'}
hex_features = {'IP_tos', 'IP_chksum', 'TL_chksum', 'UDP_chksum', 'TCP_chksum'}
equal_features = {'TCP_chksum', 'UDP_chksum', 'IPV6_tc', 'IPv6_version', 'IPv6_plen', 'IPv6_nh', 'IPv6_hlim'}

def hex2int(value):
    return int(value, 16)

def special_rules(field, value):
    if not value: # convert '' to 0
        return 0
    elif field == 'TCP_flags':     # convert flags to int
        return tcp_flags_map[value]
    elif field == 'IP_flags':     # convert flags to int
        return ip_flags_map[value]
    elif field == 'IP_proto': # convert protocol to int
        return ip_proto_map[value]
    
def equal_rules(field): # convert ipv6 fields name to ipv4 fields name
    if field == 'TCP_chksum' or field == 'UDP_chksum':
        return 'TL_chksum'
    elif field == 'IPv6_tc':
        return 'IP_tos'
    elif field == 'IPv6_version':
        return 'IP_version'
    elif field == 'IPv6_plen':
        return 'IP_len'
    elif field == 'IPv6_nh':
        return 'IP_proto'
    elif field == 'IPv6_hlim':
        return 'IP_ttl'
     
def packet2features(packet):
    protocol = None
    packet_key_val = {}
    for line in packet.show2(dump=True).split('\n'): 
        layer, _, key, val = get_key_val(line)
        if layer is not None:
                protocol = layer
        else:
            if key not in pass_fields and key is not None:   
                if key == 'options': # options is a list, there are two new fields
                    for option in eval(val):
                            if option[0] == 'NOP': # ignore NOP (No Operation)
                                continue
                            elif option[0] == 'Timestamp': # Timestamp and Echo are a pair, Echo is the second field
                                packet_key_val[f'{protocol}_{option[0]}'] = option[1][0]
                                packet_key_val[f'{protocol}_edcho_{option[0]}'] = option[1][1]
                            elif option[0] == 'SAck': # The format of SAck is smiliar with timestamp and they are a pair, Echo is the second field
                                packet_key_val[f'{protocol}_{option[0]}'] = option[1][0]
                                packet_key_val[f'{protocol}_echo_{option[0]}'] = option[1][1]
                            elif option[0] == 'SAckOK': 
                                packet_key_val[f'{protocol}_{option[0]}'] = int(val == 1)
                            elif option[0] == 'EOL': # EOL is a flag, always 0
                                packet_key_val[f'{protocol}_{option[0]}'] = 0
                            else:
                                packet_key_val[f'{protocol}_{option[0]}'] = option[1]
                    continue   

                if f'{protocol}_{key}' in equal_features: # special rules for some fields
                    field = equal_rules(f'{protocol}_{key}')
                else:
                    field = f'{protocol}_{key}'


                if field in map_features: # special rules for some fields
                    packet_key_val[field] = special_rules(field, val)
                elif field in hex_features:
                    packet_key_val[field] = hex2int(val)
                else:
                    packet_key_val[field] = int(val) 
                
    packet_array = [packet_key_val.get(key, 0) for key in field_set]

    return packet_array

def write2csv(type, data, label):
    file_path = f'{output_path}/unclean/{type}.csv'

    if not os.path.isfile(file_path):
        with open(file_path, mode='w', newline='') as file:
            writer = csv.writer(file)
            print(list(field_set) + ['class'])
            writer.writerow(list(field_set) + ['class'])

    with open(file_path, mode='a', newline='') as file:
        writer = csv.writer(file)
        writer.writerow(data + [label])

# %%
# file/{test.pcap} or file/{train_val_split_0}/{train.pcap}

for type in os.listdir(dataset_path):
    logger.info(f'Processing {type}')
    if 'test' in type: 
        if 'pcap' in type:
            packets =  scapy.PcapReader(f'{dataset_path}/{type}')
            data_frame = pd.read_parquet(f'{dataset_path}/{type[:-5]}.parquet')

            for id, packet in enumerate(packets):
                packet = clean_packet(packet)
                packet_array = packet2features(packet)
                write2csv(type[:-5], packet_array, data_frame.iloc[id]['class_str'])
    else:
        for class_id, file_name in enumerate(os.listdir(f'{dataset_path}/{type}')):
            logger.info(f'Processing {type} {file_name}')
            if 'pcap' in file_name:
                packets =  scapy.PcapReader(f'{dataset_path}/{type}/{file_name}')
                data_frame = pd.read_parquet(f'{dataset_path}/{type}/{file_name[:-5]}.parquet')

                for id, packet in enumerate(packets):
                    packet = clean_packet(packet)
                    packet_array = packet2features(packet)
                    write2csv(f'{type}/{file_name[:-5]}', packet_array, data_frame.iloc[id]['class_str'])
 
logger.info('Finished')

# %%
# file/test/{test.pcap} or file/train_val_split_0/{train/val}/.pcap

for type in os.listdir(dataset_path):
    logger.info(f'Processing {type}')

    if 'test' == type:
        for class_id, file_name in enumerate(os.listdir(f'{dataset_path}/{type}')):
            if 'pcap' in file_name:
                logger.info(f'Processing {type} {file_name}')

                packets =  scapy.PcapReader(f'{dataset_path}/{type}/{file_name}')
                for id, packet in enumerate(packets):
                    packet = clean_packet(packet)
                    packet_array = packet2features(packet)
                    write2csv(type, packet_array, file_name)
    else:
        for class_id, folder in enumerate(os.listdir(f'{dataset_path}/{type}')):
            logger.info(f'Processing {type} {folder}')

            for file_name in os.listdir(f'{dataset_path}/{type}/{folder}'):
                if 'pcap' in file_name:
                    packets =  scapy.PcapReader(f'{dataset_path}/{type}/{folder}/{file_name}')
                    
                    for id, packet in enumerate(packets):
                        packet = clean_packet(packet)
                        packet_array = packet2features(packet)
                        write2csv(f'{type}/{folder}', packet_array, file_name)
 
logger.info('Finished')
# Out:
# 2025-01-23 14:32:22,961 - root - INFO - Processing train_val_split_2
# 2025-01-23 14:32:22,963 - root - INFO - Processing train_val_split_2 train
# ['IP_id', 'TCP_SAck', 'TCP_echo_SAck', 'TCP_flags', 'TL_chksum', 'TCP_urgptr', 'IP_chksum', 'TCP_echo_Timestamp', 'TCP_Timestamp', 'TCP_reserved', 'IP_frag', 'TCP_seq', 'IP_ttl', 'IP_proto', 'TCP_ack', 'IP_ihl', 'IP_tos', 'IP_len', 'IP_flags', 'TCP_dataofs', 'IP_version', 'TCP_window', 'class']
# 2025-01-23 14:33:29,572 - root - INFO - Processing train_val_split_2 val
# ['IP_id', 'TCP_SAck', 'TCP_echo_SAck', 'TCP_flags', 'TL_chksum', 'TCP_urgptr', 'IP_chksum', 'TCP_echo_Timestamp', 'TCP_Timestamp', 'TCP_reserved', 'IP_frag', 'TCP_seq', 'IP_ttl', 'IP_proto', 'TCP_ack', 'IP_ihl', 'IP_tos', 'IP_len', 'IP_flags', 'TCP_dataofs', 'IP_version', 'TCP_window', 'class']
# 2025-01-23 14:33:33,176 - root - INFO - Processing train_val_split_0
# 2025-01-23 14:33:33,177 - root - INFO - Processing train_val_split_0 train
# ['IP_id', 'TCP_SAck', 'TCP_echo_SAck', 'TCP_flags', 'TL_chksum', 'TCP_urgptr', 'IP_chksum', 'TCP_echo_Timestamp', 'TCP_Timestamp', 'TCP_reserved', 'IP_frag', 'TCP_seq', 'IP_ttl', 'IP_proto', 'TCP_ack', 'IP_ihl', 'IP_tos', 'IP_len', 'IP_flags', 'TCP_dataofs', 'IP_version', 'TCP_window', 'class']
# 2025-01-23 14:34:13,964 - root - INFO - Processing train_val_split_0 val
# ['IP_id', 'TCP_SAck', 'TCP_echo_SAck', 'TCP_flags', 'TL_chksum', 'TCP_urgptr', 'IP_chksum', 'TCP_echo_Timestamp', 'TCP_Timestamp', 'TCP_reserved', 'IP_frag', 'TCP_seq', 'IP_ttl', 'IP_proto', 'TCP_ack', 'IP_ihl', 'IP_tos', 'IP_len', 'IP_flags', 'TCP_dataofs', 'IP_version', 'TCP_window', 'class']
# 2025-01-23 14:34:28,824 - root - INFO - Processing test
# 2025-01-23 14:34:28,825 - root - INFO - Processing test 51cto.pcap
# ['IP_id', 'TCP_SAck', 'TCP_echo_SAck', 'TCP_flags', 'TL_chksum', 'TCP_urgptr', 'IP_chksum', 'TCP_echo_Timestamp', 'TCP_Timestamp', 'TCP_reserved', 'IP_frag', 'TCP_seq', 'IP_ttl', 'IP_proto', 'TCP_ack', 'IP_ihl', 'IP_tos', 'IP_len', 'IP_flags', 'TCP_dataofs', 'IP_version', 'TCP_window', 'class']
# 2025-01-23 14:34:31,063 - root - INFO - Processing test sina.pcap
# 2025-01-23 14:34:33,469 - root - INFO - Processing test overleaf.pcap
# 2025-01-23 14:34:45,521 - root - INFO - Processing test youtube.pcap
# 2025-01-23 14:34:47,581 - root - INFO - Processing test alibaba.pcap
# 2025-01-23 14:34:47,830 - root - INFO - Processing test instagram.pcap
# 2025-01-23 14:34:48,887 - root - INFO - Processing test iqiyi.pcap
# 2025-01-23 14:34:50,299 - root - INFO - Processing test ibm.pcap
# 2025-01-23 14:34:51,674 - root - INFO - Processing test dailymotion.pcap
# 2025-01-23 14:35:01,519 - root - INFO - Processing test smzdm.pcap
# 2025-01-23 14:35:08,231 - root - INFO - Processing test gravatar.pcap
# 2025-01-23 14:35:09,297 - root - INFO - Processing test microsoft.pcap
# 2025-01-23 14:35:11,182 - root - INFO - Processing test cloudfront.pcap
# 2025-01-23 14:35:11,719 - root - INFO - Processing test jb51.pcap
# 2025-01-23 14:35:16,983 - root - INFO - Processing test pinduoduo.pcap
# 2025-01-23 14:35:18,952 - root - INFO - Processing test vmware.pcap
# 2025-01-23 14:35:19,752 - root - INFO - Processing test wikimedia.pcap
# 2025-01-23 14:35:24,001 - root - INFO - Processing test sohu.pcap
# 2025-01-23 14:35:24,949 - root - INFO - Processing test apple.pcap
# 2025-01-23 14:35:25,769 - root - INFO - Processing test twimg.pcap
# 2025-01-23 14:35:31,970 - root - INFO - Processing test onlinedown.pcap
# 2025-01-23 14:35:34,766 - root - INFO - Processing test booking.pcap
# 2025-01-23 14:35:35,414 - root - INFO - Processing test digitaloceanspaces.pcap
# 2025-01-23 14:35:35,855 - root - INFO - Processing test netflix.pcap
# 2025-01-23 14:35:38,000 - root - INFO - Processing test gitlab.pcap
# 2025-01-23 14:35:41,535 - root - INFO - Processing test criteo.pcap
# 2025-01-23 14:35:43,079 - root - INFO - Processing test v2ex.pcap
# 2025-01-23 14:35:45,625 - root - INFO - Processing test icloud.pcap
# 2025-01-23 14:35:46,882 - root - INFO - Processing test yahoo.pcap
# 2025-01-23 14:35:47,669 - root - INFO - Processing test runoob.pcap
# 2025-01-23 14:35:49,938 - root - INFO - Processing test sciencedirect.pcap
# 2025-01-23 14:35:50,283 - root - INFO - Processing test huya.pcap
# 2025-01-23 14:35:52,100 - root - INFO - Processing test xiaomi.pcap
# 2025-01-23 14:35:55,473 - root - INFO - Processing test huanqiu.pcap
# 2025-01-23 14:35:56,081 - root - INFO - Processing test eastmoney.pcap
# 2025-01-23 14:35:56,754 - root - INFO - Processing test elsevier.pcap
# 2025-01-23 14:35:57,626 - root - INFO - Processing test office.pcap
# 2025-01-23 14:36:00,087 - root - INFO - Processing test 51.pcap
# 2025-01-23 14:36:00,242 - root - INFO - Processing test semanticscholar.pcap
# 2025-01-23 14:36:02,734 - root - INFO - Processing test kugou.pcap
# 2025-01-23 14:36:04,656 - root - INFO - Processing test ximalaya.pcap
# 2025-01-23 14:36:05,265 - root - INFO - Processing test naver.pcap
# 2025-01-23 14:36:07,759 - root - INFO - Processing test cisco.pcap
# 2025-01-23 14:36:08,101 - root - INFO - Processing test mi.pcap
# 2025-01-23 14:36:09,246 - root - INFO - Processing test leetcode-cn.pcap
# 2025-01-23 14:36:14,774 - root - INFO - Processing test arxiv.pcap
# 2025-01-23 14:36:16,422 - root - INFO - Processing test mozilla.pcap
# 2025-01-23 14:36:17,818 - root - INFO - Processing test walmart.pcap
# 2025-01-23 14:36:18,304 - root - INFO - Processing test feishu.pcap
# 2025-01-23 14:36:20,321 - root - INFO - Processing test wikipedia.pcap
# 2025-01-23 14:36:24,431 - root - INFO - Processing test vk.pcap
# 2025-01-23 14:36:25,334 - root - INFO - Processing test spring.pcap
# 2025-01-23 14:36:25,929 - root - INFO - Processing test notion.pcap
# 2025-01-23 14:36:27,799 - root - INFO - Processing test grammarly.pcap
# 2025-01-23 14:36:28,674 - root - INFO - Processing test nvidia.pcap
# 2025-01-23 14:36:32,222 - root - INFO - Processing test taboola.pcap
# 2025-01-23 14:36:36,439 - root - INFO - Processing test yy.pcap
# 2025-01-23 14:36:38,978 - root - INFO - Processing test atlassian.pcap
# 2025-01-23 14:36:39,244 - root - INFO - Processing test toutiao.pcap
# 2025-01-23 14:36:39,779 - root - INFO - Processing test amap.pcap
# 2025-01-23 14:36:40,045 - root - INFO - Processing test qq.pcap
# 2025-01-23 14:36:41,355 - root - INFO - Processing test bilibili.pcap
# 2025-01-23 14:36:42,654 - root - INFO - Processing test acm.pcap
# 2025-01-23 14:36:50,645 - root - INFO - Processing test adobe.pcap
# 2025-01-23 14:36:52,128 - root - INFO - Processing test google.pcap
# 2025-01-23 14:36:53,210 - root - INFO - Processing test chinatax.pcap
# 2025-01-23 14:36:53,903 - root - INFO - Processing test baidu.pcap
# 2025-01-23 14:36:55,254 - root - INFO - Processing test paypal.pcap
# 2025-01-23 14:36:55,435 - root - INFO - Processing test yandex.pcap
# 2025-01-23 14:36:57,637 - root - INFO - Processing test oracle.pcap
# 2025-01-23 14:36:59,787 - root - INFO - Processing test ctrip.pcap
# 2025-01-23 14:37:01,797 - root - INFO - Processing test codepen.pcap
# 2025-01-23 14:37:02,964 - root - INFO - Processing test cnblogs.pcap
# 2025-01-23 14:37:06,685 - root - INFO - Processing test steampowered.pcap
# 2025-01-23 14:37:07,754 - root - INFO - Processing test weibo.pcap
# 2025-01-23 14:37:15,743 - root - INFO - Processing test squarespace.pcap
# 2025-01-23 14:37:16,163 - root - INFO - Processing test zhihu.pcap
# 2025-01-23 14:37:19,708 - root - INFO - Processing test jd.pcap
# 2025-01-23 14:37:20,594 - root - INFO - Processing test t.pcap
# 2025-01-23 14:37:21,102 - root - INFO - Processing test biligame.pcap
# 2025-01-23 14:37:21,792 - root - INFO - Processing test eastday.pcap
# 2025-01-23 14:37:22,219 - root - INFO - Processing test qcloud.pcap
# 2025-01-23 14:37:22,651 - root - INFO - Processing test alipay.pcap
# 2025-01-23 14:37:23,806 - root - INFO - Processing test goat.pcap
# 2025-01-23 14:37:26,154 - root - INFO - Processing test guancha.pcap
# 2025-01-23 14:37:27,853 - root - INFO - Processing test gmail.pcap
# 2025-01-23 14:37:28,702 - root - INFO - Processing test python.pcap
# 2025-01-23 14:37:29,073 - root - INFO - Processing test chia.pcap
# 2025-01-23 14:37:29,079 - root - INFO - Processing test springer.pcap
# 2025-01-23 14:37:31,599 - root - INFO - Processing test github.pcap
# 2025-01-23 14:37:32,467 - root - INFO - Processing test 163.pcap
# 2025-01-23 14:37:34,212 - root - INFO - Processing test crazyegg.pcap
# 2025-01-23 14:37:34,723 - root - INFO - Processing test thepaper.pcap
# 2025-01-23 14:37:37,307 - root - INFO - Processing test ampproject.pcap
# 2025-01-23 14:37:39,873 - root - INFO - Processing test vivo.pcap
# 2025-01-23 14:37:41,062 - root - INFO - Processing test tiktok.pcap
# 2025-01-23 14:37:41,327 - root - INFO - Processing test wp.pcap
# 2025-01-23 14:37:43,046 - root - INFO - Processing test researchgate.pcap
# 2025-01-23 14:37:48,744 - root - INFO - Processing test asus.pcap
# 2025-01-23 14:37:49,106 - root - INFO - Processing test snapchat.pcap
# 2025-01-23 14:37:50,151 - root - INFO - Processing test huawei.pcap
# 2025-01-23 14:37:56,021 - root - INFO - Processing test ggpht.pcap
# 2025-01-23 14:38:01,438 - root - INFO - Processing test duckduckgo.pcap
# 2025-01-23 14:38:01,979 - root - INFO - Processing test unity3d.pcap
# 2025-01-23 14:38:02,677 - root - INFO - Processing test deepl.pcap
# 2025-01-23 14:38:07,224 - root - INFO - Processing test nike.pcap
# 2025-01-23 14:38:12,507 - root - INFO - Processing test alicdn.pcap
# 2025-01-23 14:38:16,915 - root - INFO - Processing test opera.pcap
# 2025-01-23 14:38:17,194 - root - INFO - Processing test cloudflare.pcap
# 2025-01-23 14:38:17,984 - root - INFO - Processing test twitter.pcap
# 2025-01-23 14:38:19,804 - root - INFO - Processing test facebook.pcap
# 2025-01-23 14:38:21,675 - root - INFO - Processing test statcounter.pcap
# 2025-01-23 14:38:22,018 - root - INFO - Processing test azureedge.pcap
# 2025-01-23 14:38:22,918 - root - INFO - Processing test msn.pcap
# 2025-01-23 14:38:23,536 - root - INFO - Processing test media.pcap
# 2025-01-23 14:38:25,292 - root - INFO - Processing test amazonaws.pcap
# 2025-01-23 14:38:26,157 - root - INFO - Processing test hubspot.pcap
# 2025-01-23 14:38:27,443 - root - INFO - Processing test ieee.pcap
# 2025-01-23 14:38:27,938 - root - INFO - Processing test outbrain.pcap
# 2025-01-23 14:38:28,256 - root - INFO - Processing test teads.pcap
# 2025-01-23 14:38:29,245 - root - INFO - Processing train_val_split_1
# 2025-01-23 14:38:29,246 - root - INFO - Processing train_val_split_1 train
# ['IP_id', 'TCP_SAck', 'TCP_echo_SAck', 'TCP_flags', 'TL_chksum', 'TCP_urgptr', 'IP_chksum', 'TCP_echo_Timestamp', 'TCP_Timestamp', 'TCP_reserved', 'IP_frag', 'TCP_seq', 'IP_ttl', 'IP_proto', 'TCP_ack', 'IP_ihl', 'IP_tos', 'IP_len', 'IP_flags', 'TCP_dataofs', 'IP_version', 'TCP_window', 'class']
# 2025-01-23 14:39:01,830 - root - INFO - Processing train_val_split_1 val
# ['IP_id', 'TCP_SAck', 'TCP_echo_SAck', 'TCP_flags', 'TL_chksum', 'TCP_urgptr', 'IP_chksum', 'TCP_echo_Timestamp', 'TCP_Timestamp', 'TCP_reserved', 'IP_frag', 'TCP_seq', 'IP_ttl', 'IP_proto', 'TCP_ack', 'IP_ihl', 'IP_tos', 'IP_len', 'IP_flags', 'TCP_dataofs', 'IP_version', 'TCP_window', 'class']
# 2025-01-23 14:39:16,719 - root - INFO - Finished

# %% [markdown]
# # for data clean
#
# normalization each row
#
# **train and test should use same distribution of normalization**

# %% [markdown]
# ### For USTCTFC2016
# field_set = {'TCP_window', 'TCP_chksum', 'TCP_reserved', 'TCP_ack', 'TCP_echo_SAck', 'TCP_flags', 'TCP_SAckOK', 'IP_id', 'IP_proto', 'IP_len', 'TCP_seq', 'TCP_WScale', 'TCP_EOL', 'UDP_chksum', 'UDP_len', 'TCP_dataofs', 'IP_version', 'TCP_SAck', 'TCP_MSS', 'IP_chksum', 'IP_flags', 'TCP_urgptr', 'IP_frag', 'IP_ttl', 'TCP_echo_Timestamp', 'TCP_Timestamp', 'IP_ihl', 'IP_tos'}
#
# ip_flags_map = {'DF': 1}
# tcp_flags_map = {'PA': 1, 'S': 2, 'FA': 3, 'A': 4, 'FPA': 5, 'R': 6, 'SA': 7, 'RA': 8}
# ip_proto_map = {'tcp': 1, 'udp': 2}
#
# normalize_set = {'TCP_window', 'TCP_chksum', 'TCP_ack', 'TCP_echo_SAck', 'IP_id', 'IP_len', 'TCP_seq', 'UDP_chksum', 'UDP_len','TCP_SAck', 'TCP_MSS', 'IP_chksum', 'TCP_echo_Timestamp', 'TCP_Timestamp', 'IP_tos'}

# %%
import pandas as pd
import numpy as np

normalize_set = {'TCP_window', 'TCP_chksum', 'TCP_ack', 'TCP_echo_SAck', 'IP_id', 'IP_len', 'TCP_seq', 'UDP_chksum', 'UDP_len','TCP_SAck', 'TCP_MSS', 'IP_chksum', 'TCP_echo_Timestamp', 'TCP_Timestamp', 'IP_tos'}
types = ['train_val_split_0', 'train_val_split_1', 'train_val_split_2', 'test.csv']

def log_normalize(value):
    return np.log1p(value)

for type in types:
    if type == 'test.csv':
        df = pd.read_csv(f'{output_path}/unclean/{type}')
        for field in normalize_set:
            if field in df.columns:
                df[field] = df[field].apply(log_normalize)
        df.to_csv(f'{output_path}/normalized/{type}', index=False)
    else:
        for file in os.listdir(f'{output_path}/unclean/{type}'):
            df = pd.read_csv(f'{output_path}/unclean/{type}/{file}')
            print(type, file)
            for field in normalize_set:
                if field in df.columns:
                    df[field] = df[field].apply(log_normalize)
            df.to_csv(f'{output_path}/normalized/{type}/{file}', index=False)
# Out:
# train_val_split_0 train.csv
# train_val_split_0 val.csv
# train_val_split_1 train.csv
# train_val_split_1 val.csv
# train_val_split_2 train.csv
# train_val_split_2 val.csv

# %% [markdown]
# ### For TLS
# field_set = {'TCP_window', 'TCP_chksum', 'TCP_reserved', 'TCP_ack', 'TCP_echo_SAck', 'TCP_flags', 'IP_id', 'IP_proto', 'IP_len', 'TCP_seq', 'TCP_dataofs', 'IP_version', 'TCP_SAck', 'IP_chksum', 'TCP_urgptr', 'IP_flags', 'IP_frag', 'IP_ttl', 'TCP_echo_Timestamp', 'TCP_Timestamp', 'IP_ihl', 'IP_tos'}
#
# ip_flags_map = {'DF': 1}
# tcp_flags_map = {'PA': 1, 'FA': 2, 'A': 3, 'FPA': 4, 'R': 5, 'PAC': 6, 'RA': 7}
# ip_proto_map = {'tcp': 1, 'udp': 2}
#
# normalize_set = {'TCP_window', 'TCP_chksum', 'TCP_ack', 'TCP_echo_SAck', 'IP_id', 'IP_len', 'TCP_seq', 'TCP_SAck', 'IP_chksum','TCP_echo_Timestamp', 'TCP_Timestamp', 'IP_tos'}

# %%
import pandas as pd
import numpy as np

normalize_set = {'TCP_window', 'TCP_chksum', 'TCP_ack', 'TCP_echo_SAck', 'IP_id', 'IP_len', 'TCP_seq', 'TCP_SAck', 'IP_chksum','TCP_echo_Timestamp', 'TCP_Timestamp', 'IP_tos'}
types = ['train_val_split_0', 'train_val_split_1', 'train_val_split_2', 'test.csv']

def log_normalize(value):
    return np.log1p(value)

for type in types:
    if type == 'test.csv':
        df = pd.read_csv(f'{output_path}/unclean/{type}')
        for field in normalize_set:
            if field in df.columns:
                df[field] = df[field].apply(log_normalize)
        df.to_csv(f'{output_path}/normalized/{type}', index=False)
    else:
        for file in os.listdir(f'{output_path}/unclean/{type}'):
            df = pd.read_csv(f'{output_path}/unclean/{type}/{file}')
            if 'TCP_30' in df.columns:
                print('OK')
                df = df.drop(columns = ['TCP_30'])
            print(type, file)
            for field in normalize_set:
                if field in df.columns:
                    df[field] = df[field].apply(log_normalize)
            df.to_csv(f'{output_path}/normalized/{type}/{file}', index=False)
# Out:
# train_val_split_0 train.csv
# train_val_split_0 val.csv
# train_val_split_1 train.csv
# train_val_split_1 val.csv
# train_val_split_2 train.csv
# train_val_split_2 val.csv

# %% [markdown]
# # For VPN
# field_set = {'TCP_MSS', 'TCP_seq', 'IP_id', 'IP_chksum', 'TCP_urgptr', 'UDP_len', 'TCP_echo_SAck', 'UDP_chksum', 'TCP_echo_Timestamp', 'IP_version', 'TCP_window', 'IP_len', 'IP_flags', 'TCP_SAck', 'TCP_WScale', 'TCP_EOL', 'TCP_ack', 'TCP_chksum', 'IP_frag', 'TCP_flags', 'IP_ttl', 'IP_ihl', 'TCP_dataofs', 'TCP_Timestamp', 'IP_proto', 'IP_tos', 'TCP_reserved', 'TCP_SAckOK'}
#
# ip_flags_map = {'DF': 1}
# tcp_flags_map = {'R': 1, 'SA': 2, 'RA': 3, 'S': 4, 'PA': 5, 'FPA': 6, 'A': 7, 'FA': 8}
# ip_proto_map = {'tcp': 1, 'udp': 2}
#
#  normalize_set = {'TCP_MSS', 'TCP_seq', 'IP_id', 'IP_chksum','UDP_len', 'TCP_echo_SAck', 'UDP_chksum', 'TCP_echo_Timestamp','TCP_window', 'IP_len',  'TCP_SAck','TCP_ack', 'TCP_chksum', 'TCP_Timestamp', 'IP_tos'}

# %%
import pandas as pd
import numpy as np

normalize_set = {'TL_chksum', 'TCP_MSS', 'TCP_seq', 'IP_id', 'IP_chksum', 'UDP_len', 'TCP_echo_SAck', 'UDP_chksum', 'TCP_echo_Timestamp','TCP_window', 'IP_len',  'TCP_SAck','TCP_ack', 'TCP_chksum', 'TCP_Timestamp', 'IP_tos'}
types = ['train_val_split_0', 'train_val_split_1', 'train_val_split_2', 'test.csv']

def log_normalize(value):
    return np.log1p(value)

for type in types:
    if type == 'test.csv':
        df = pd.read_csv(f'{output_path}/unclean/{type}')
        for field in normalize_set:
            if field in df.columns:
                df[field] = df[field].apply(log_normalize)
        df.to_csv(f'{output_path}/normalized/{type}', index=False)
    else:
        for file in os.listdir(f'{output_path}/unclean/{type}'):
            df = pd.read_csv(f'{output_path}/unclean/{type}/{file}')
            for field in normalize_set:
                if field in df.columns:
                    df[field] = df[field].apply(log_normalize)
            df.to_csv(f'{output_path}/normalized/{type}/{file}', index=False)
